# %%
import pandas as pd

# %%
consist = pd.read_pickle('consistency')

# %%
consist
# Out:
#                  female      male
# atypical       0.180897  0.217632
# boring         0.384321  0.325526
# calm           0.243218  0.357629
# cold           0.478424  0.691765
# common         0.206644  0.244471
# confident      0.468654  0.512775
# egotistic      0.370574  0.432365
# emotUnstable   0.280277  0.474658
# forgettable    0.297731  0.209402
# intelligent    0.300502  0.493428
# introverted    0.445775  0.491638
# kind           0.450013  0.681743
# responsible    0.333388  0.553936
# trustworthy    0.374117  0.584728
# unattractive   0.618612  0.532997
# unemotional    0.354324  0.546077
# unfamiliar     0.095441  0.170515
# unfriendly     0.468970  0.699209
# unhappy        0.506911  0.723433
# weird          0.337542  0.464733
# aggressive     0.308712  0.616664
# attractive     0.715874  0.619018
# caring         0.403400  0.675588
# emotStable     0.274985  0.523445
# emotional      0.088475  0.227969
# familiar       0.101089  0.249661
# ...

# %%
ax = consist.plot.bar()

fig = ax.get_figure()
fig.savefig('consist.pdf')
