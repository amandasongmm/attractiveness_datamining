# %%
import numpy as np
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(context="paper", font="monospace")

# %matplotlib inline

__author__ = 'amanda'

# %%
tmp = np.load('../clean_data/feature_array')
# Compute the correlations of the dataframe
corrmat = tmp.corr()

# %%
# Plot the heat map.
f, ax = plt.subplots(figsize=(12, 9))

# Draw the heatmap using seaborn
sns.heatmap(corrmat, square=True, vmin=-1, vmax=1)
locs, labels = plt.xticks()
plt.setp(labels, rotation=90)
plt.tick_params(labelsize=10)
plt.savefig('../figs/social_fea_correlation_heatmap.png')
plt.show()

# %%
one_line = corrmat['attractive']

# %%
test = one_line.values

# %%
fields = one_line.index

# %%
list1, list2 = zip(*sorted(zip(test, fields)))

# %%
for i in range(len(list1)):
    print list2[i], list1[i]
# Out:
# unattractive -0.829278678964
# boring -0.588356445813
# weird -0.559892160164
# forgettable -0.514331902345
# introverted -0.486441543761
# unhappy -0.470579266152
# uncertain -0.467864212114
# mean -0.456959747955
# unintelligent -0.449049193172
# unfriendly -0.448902041071
# untrustworthy -0.431292987723
# cold -0.41831392792
# aggressive -0.399271552928
# emotUnstable -0.399098284194
# unemotional -0.394089643631
# unfamiliar -0.382180514405
# irresponsible -0.333541069535
# atypical -0.244519176834
# uncommon -0.188291985485
# egotistic -0.0968673938201
# common -0.00938618504544
# typical 0.181627810466
# humble 0.211552662338
# responsible 0.331419747308
# calm 0.346285159875
# emotional 0.356908560546
# trustworthy 0.400543721574
# intelligent 0.408420477017
# kind 0.435615268281
# familiar 0.450225922424
# caring 0.479639789987
# emotStable 0.485122161283
# happy 0.497061732255
# friendly 0.50693165903
# normal 0.531705703499
# confident 0.532915204731
# ...

# %%
tmp = np.load('../clean_data/feature_array')
# Compute the correlations of the dataframe
corrmat = tmp.corr()
corrmat.to_csv(path_or_buf='../clean_data/correlation_array')

# %%
import pandas as pd
p = pd.read_csv('../clean_data/correlation_array')

# %%
p
# Out:
#        Unnamed: 0  atypical    boring      calm      cold    common  \
# 0        atypical  1.000000  0.214869 -0.434825  0.533218 -0.487103
# 1          boring  0.214869  1.000000 -0.230331  0.514839  0.139354
# 2            calm -0.434825 -0.230331  1.000000 -0.598723  0.390797
# 3            cold  0.533218  0.514839 -0.598723  1.000000 -0.357930
# 4          common -0.487103  0.139354  0.390797 -0.357930  1.000000
# 5       confident -0.354879 -0.580057  0.456018 -0.533060  0.148615
# 6       egotistic  0.447223  0.196989 -0.492744  0.692925 -0.364299
# 7    emotUnstable  0.582402  0.426742 -0.679626  0.775081 -0.391980
# 8     forgettable  0.078195  0.712083 -0.148907  0.319754  0.306432
# 9     intelligent -0.438939 -0.348490  0.627381 -0.564855  0.273770
# 10    introverted  0.469564  0.651392 -0.363318  0.693272 -0.199395
# 11           kind -0.515066 -0.466127  0.676444 -0.905845  0.402311
# 12    responsible -0.549052 -0.290789  0.708638 -0.701049  0.423997
# ...
