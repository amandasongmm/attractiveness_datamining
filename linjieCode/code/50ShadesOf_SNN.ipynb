# %%
# Make sure that caffe is on the python path:
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pandas as pd

from sklearn.decomposition import PCA as sklearnPCA
landMarks = pd.read_csv('../../processing/landmarking/mit/mitLandmarks.csv',index_col = 0)
imageList = list(set(landMarks.index.tolist()))
imageList.sort()
imList = [im[3:] for im in imageList]
print len(imList)
Dataset = 'mit'
MODEL = 'geometric'
homePath = '/home/lli-ms/'
allGeometric = np.loadtxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_totalFeatures.csv', delimiter=',')
print allGeometric.shape

caffe_root = homePath+'caffe/'
pretrained_model_root = homePath+'caffe/'

# run this line one time only!
import sys
caffePython = pretrained_model_root + 'python'
if caffePython not in sys.path:
    sys.path.insert(0, caffePython)

import caffe
# Load mean
mu = np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy')
mu = mu.mean(1).mean(1)  # average over pixels to obtain the mean (BGR) pixel values
print 'mean-subtracted values:', zip('BGR', mu)

# Load the trained net
MODEL = 'faceSNN' #'caffeNet','vgg16','vggFace' or 'faceSNN'
    
MODEL = 'faceSNN'
MODEL_FILE = caffe_root +'models/sraonet/siamese_lecun_deploy.prototxt'
PRETRAINED_FILE = caffe_root + 'models/sraonet/snapshots/sraonet_lecun_gd_sub2_iter_100000.caffemodel'

caffe.set_device(1)
caffe.set_mode_gpu()
if not os.path.isfile(PRETRAINED_FILE):
    print("No caffemodel!!!")
elif not os.path.isfile(MODEL_FILE):
    print("No MODEL !!!")
else:
    print "Defining the net!"
    net = caffe.Net(MODEL_FILE,
                PRETRAINED_FILE,
                caffe.TEST)
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
if MODEL != 'faceSNN':
    # subtract the dataset-mean value in each channel
    transformer.set_mean('data', mu)
for layer_name, param in net.params.iteritems():
    print layer_name + '\t' + str(param[0].data.shape), str(param[1].data.shape)
transformer.set_transpose('data', (2,0,1))
# the reference model operates on images in [0,255] range instead of [0,1]
transformer.set_raw_scale('data', 255) 
# the reference model has channels in BGR order instead of RGB
transformer.set_channel_swap('data', (2,1,0))

imgeReshape = [56,46]
featureLayer = 'fc6'
if 'fc' in featureLayer:
    featureNum = net.params[featureLayer][1].data.shape[0]
else:
    featureNum = net.blobs[featureLayer].data.flatten().shape[0]/net.blobs[featureLayer].data.shape[0]
print featureNum
features = np.zeros([len(imList),featureNum])
totalNum = 0

# print len(imList)
for img in imList:
    imgName = os.path.basename(img)
    if imgName.endswith(('.jpg','.png')):
        input_image = caffe.io.load_image(img)
        net.blobs['data'].reshape(1,3,imgeReshape[0],imgeReshape[1])
        net.blobs['data'].data[...] = transformer.preprocess('data', input_image)
        out = net.forward()
        feat = net.blobs[featureLayer].data
        if Dataset =='twin':
            img_type = int(imgName[7:-4])/perImNum
            img_index = int(imgName[7:-4])%perImNum
            #print 'img_type:',img_type
            if img_type in img_type_num.keys():
                img_type_num[img_type] = img_type_num[img_type] + 1
                img_type_list[img_type][img_index] = img
            else:
                img_type_num[img_type] = 0
                img_type_list[img_type] = [None]*perImNum
                img_type_index[img_type] = type_index
                type_index +=1
            #print 'img_type_index:',img_type_index[img_type]
            features[img_type_index[img_type],img_type_num[img_type]] = feat.flatten()
        else:
            # need to be further revised!
            features[totalNum] = feat.flatten()
            #print features[totalNum]
        totalNum +=1
    else:
        print img
#print len(img_type_num)
print totalNum
faceSNN_Feature = features
# Out:
# 2207
# (2207, 4592)
# mean-subtracted values: [('B', 104.0069879317889), ('G', 116.66876761696767), ('R', 122.6789143406786)]
# Defining the net!
# conv1	(15, 3, 7, 7) (15,)
# conv2	(45, 15, 6, 6) (45,)
# conv3	(250, 45, 5, 5) (250,)
# fc6	(50, 250) (50,)
# 50
# 2207

# %%
for j in range(1,50): 
    import random
    featureMat = faceSNN_Feature
    randomInd = range(featureMat.shape[0])
    random.shuffle(randomInd)
    print max(randomInd)
    featureMat = featureMat[randomInd,:]
    nSamples = featureMat.shape[0]
    testRatio = 0.2
    valiRatio = 0.2
    testFeatures = featureMat[:int(nSamples*testRatio),:]
    trainFeatures = featureMat[int(nSamples*testRatio):,:]
    valiFeatures = featureMat[-int(trainFeatures.shape[0]*valiRatio):,:]
    trainFeatures = trainFeatures[:-int(trainFeatures.shape[0]*valiRatio),:]
    print valiFeatures.shape, trainFeatures.shape, testFeatures.shape
    explained_variance = 50
    sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
    trainfeature_transf = sklearn_pca.fit_transform(trainFeatures)
    print 'The number of PCs needed to retain %.3f variance is %d.' \
          % (explained_variance, trainfeature_transf.shape[1])
    print sklearn_pca.components_.shape
    print trainfeature_transf.shape
    testfeature_tansf = sklearn_pca.transform(testFeatures)
    print testfeature_tansf.shape
    valifeature_transf = sklearn_pca.transform(valiFeatures)

    radomImlist = np.asarray(imList)[randomInd]


    modelList = []
    optFeaNumList = []

    import sys
    import pandas as pd
    socialMeasures = '../Result/mit/socialMeasures.csv'
    socialMeasures = pd.read_csv(socialMeasures,index_col = 0)
    socialAttr = socialMeasures.columns.tolist()
    delElement = ['subage.1', 'submale.1', 'subrace.1','subage', 'submale',\
                  'subrace','catch', 'catchAns','catch.1','catchAns.1']
    social2Attr = [x for x in socialAttr if x not in delElement]

    PkgPath = homePath+'attractiveness_datamining/linjieCode/code'
    fName = "../Result/FaceSNN/regression_result_"+str(j)+".csv"
    text_file = open(fName, "w")
    d = 'Social Attributes, faceSNN_test, faceSNN_train, faceSNN_FeatureNum'+'\n'
    text_file.write(d)

    if PkgPath not in sys.path:
        sys.path.insert(0, PkgPath)
    #print sys.path
    from xVal_train_test import Train_Test

    import sklearn
    import numpy as np
    fullRating = np.zeros((2207,40))
    for attr in social2Attr:
        print attr
        #attr= social2Attr[9]，
        mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
                   if imList[i][31:] in socialMeasures.index]
        mean_rating = map(float, mean_rating)
        mean_rating = np.array(mean_rating)
        radomRating = mean_rating[randomInd]
        testRating = radomRating[:int(nSamples*testRatio)]
        trainRating = radomRating[int(nSamples*testRatio):]
        valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
        trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]

        baseLine = mean_rating.mean()
        print 'mean rating: ', baseLine

        predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
        myModel,optFeaNum,testC,trainC = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf, \
                                       testfeature_tansf,valifeature_transf,xVal = True,numTrain = 1,\
                                       pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                       plotPredActual = False,returnModel = True,returnValTrain = True)
        modelList.append(myModel)
        optFeaNumList.append(optFeaNum)
        
       
        d = attr+', '+ str(testC)+', '+str(trainC)+', '+str(optFeaNum)+'\n'
        text_file.write(d)
    text_file.close()
# Out:
# 2206
# (353, 50) (1413, 50) (441, 50)
# The number of PCs needed to retain 50.000 variance is 50.
# (50, 50)
# (1413, 50)
# (441, 50)
# atypical
# mean rating:  4.08446414454
# Correlation:  0.15597778303
# num of features:  50
# Spearman Correlation:  0.172467727994
# num of features:  50
# R^2 score:  0.00424874808465
# num of features:  33
# MSE:  0.443663163941
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.01
# Correlation between predicted ratings and actual ratings is: 0.1455
# Spearman Correlation between predicted ratings and actual ratings is: 0.1534
#
# On training set:
# Residual sum of squares: 0.43
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2847
# Spearman Correlation between predicted ratings and actual ratings is: 0.2919
# ****************************************************************************************
# boring
# mean rating:  4.28997636656
# Correlation:  0.312935031619
# num of features:  50
# Spearman Correlation:  0.300659976711
# num of features:  50
# R^2 score:  0.0977121789383
# num of features:  50
# MSE:  0.607754396073
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.65
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2318
# Spearman Correlation between predicted ratings and actual ratings is: 0.2361
#
# On training set:
# Residual sum of squares: 0.60
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3453
# Spearman Correlation between predicted ratings and actual ratings is: 0.3358
# ****************************************************************************************
# calm
# mean rating:  5.80624816221
# Correlation:  0.172948834829
# num of features:  17
# Spearman Correlation:  0.206274616373
# num of features:  33
# R^2 score:  0.0294978328508
# num of features:  17
# MSE:  0.519798749284
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 0.50
# Variance score is: -0.00
# Correlation between predicted ratings and actual ratings is: 0.0994
# Spearman Correlation between predicted ratings and actual ratings is: 0.0914
#
# On training set:
# Residual sum of squares: 0.49
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2032
# Spearman Correlation between predicted ratings and actual ratings is: 0.1924
# ****************************************************************************************
# cold
# mean rating:  3.71738235795
# Correlation:  0.295199534746
# num of features:  17
# Spearman Correlation:  0.307491271699
# num of features:  50
# R^2 score:  0.0854472109402
# num of features:  33
# MSE:  1.49888555468
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 1.40
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2160
# Spearman Correlation between predicted ratings and actual ratings is: 0.2323
#
# On training set:
# Residual sum of squares: 1.44
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2630
# Spearman Correlation between predicted ratings and actual ratings is: 0.2535
# ****************************************************************************************
# common
# mean rating:  5.32550588808
# Correlation:  0.171672884501
# num of features:  28
# Spearman Correlation:  0.17483632978
# num of features:  22
# R^2 score:  0.0237748050204
# num of features:  22
# MSE:  0.375623461488
# num of features:  22
# **************************Result of train and test**************************************
# number of features: 28
# On test set:
# Residual sum of squares: 0.41
# Variance score is: -0.01
# Correlation between predicted ratings and actual ratings is: 0.1081
# Spearman Correlation between predicted ratings and actual ratings is: 0.1200
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2326
# Spearman Correlation between predicted ratings and actual ratings is: 0.2282
# ****************************************************************************************
# confident
# mean rating:  5.92335749751
# Correlation:  0.195302432189
# num of features:  50
# Spearman Correlation:  0.202265860208
# num of features:  50
# R^2 score:  0.0221425456112
# num of features:  50
# MSE:  0.656766142494
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.68
# Variance score is: 0.01
# Correlation between predicted ratings and actual ratings is: 0.1666
# Spearman Correlation between predicted ratings and actual ratings is: 0.1700
#
# On training set:
# Residual sum of squares: 0.59
# Variance score is: 0.10
# Correlation between predicted ratings and actual ratings is: 0.3182
# Spearman Correlation between predicted ratings and actual ratings is: 0.3092
# ****************************************************************************************
# egotistic
# mean rating:  4.07662558269
# Correlation:  0.295005777269
# num of features:  50
# Spearman Correlation:  0.32640483897
# num of features:  44
# R^2 score:  0.0783553406005
# num of features:  50
# MSE:  0.795890377925
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.83
# Variance score is: 0.10
# Correlation between predicted ratings and actual ratings is: 0.3136
# Spearman Correlation between predicted ratings and actual ratings is: 0.3189
#
# On training set:
# Residual sum of squares: 0.79
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3489
# Spearman Correlation between predicted ratings and actual ratings is: 0.3380
# ****************************************************************************************
# emotUnstable
# mean rating:  3.63361718849
# Correlation:  0.158506116077
# num of features:  17
# Spearman Correlation:  0.170994890813
# num of features:  17
# R^2 score:  0.022394214053
# num of features:  17
# MSE:  0.84573411194
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 0.76
# Variance score is: 0.02
# Correlation between predicted ratings and actual ratings is: 0.1531
# Spearman Correlation between predicted ratings and actual ratings is: 0.1560
#
# On training set:
# Residual sum of squares: 0.78
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2226
# Spearman Correlation between predicted ratings and actual ratings is: 0.2042
# ****************************************************************************************
# forgettable
# mean rating:  4.54602870412
# Correlation:  0.278072146082
# num of features:  50
# Spearman Correlation:  0.255366098689
# num of features:  50
# R^2 score:  0.074985639958
# num of features:  50
# MSE:  0.442608559812
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.50
# Variance score is: 0.03
# Correlation between predicted ratings and actual ratings is: 0.2183
# Spearman Correlation between predicted ratings and actual ratings is: 0.1930
#
# On training set:
# Residual sum of squares: 0.47
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3395
# Spearman Correlation between predicted ratings and actual ratings is: 0.3102
# ****************************************************************************************
# intelligent
# mean rating:  5.83579811962
# Correlation:  0.272836547999
# num of features:  17
# Spearman Correlation:  0.273486135703
# num of features:  17
# R^2 score:  0.0667209015279
# num of features:  17
# MSE:  0.523504963592
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 0.56
# Variance score is: -0.01
# Correlation between predicted ratings and actual ratings is: 0.0736
# Spearman Correlation between predicted ratings and actual ratings is: 0.0639
#
# On training set:
# Residual sum of squares: 0.52
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2110
# Spearman Correlation between predicted ratings and actual ratings is: 0.1773
# ****************************************************************************************
# introverted
# mean rating:  3.9278672696
# Correlation:  0.26181773916
# num of features:  50
# Spearman Correlation:  0.29056261854
# num of features:  50
# R^2 score:  0.0629167004326
# num of features:  50
# MSE:  0.921043307997
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.80
# Variance score is: 0.02
# Correlation between predicted ratings and actual ratings is: 0.2007
# Spearman Correlation between predicted ratings and actual ratings is: 0.2095
#
# On training set:
# Residual sum of squares: 0.74
# Variance score is: 0.13
# Correlation between predicted ratings and actual ratings is: 0.3650
# Spearman Correlation between predicted ratings and actual ratings is: 0.3563
# ****************************************************************************************
# kind
# mean rating:  5.67934660807
# Correlation:  0.318860902721
# num of features:  17
# Spearman Correlation:  0.334962503829
# num of features:  17
# R^2 score:  0.0994178869714
# num of features:  17
# MSE:  1.10594315674
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 1.09
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2360
# Spearman Correlation between predicted ratings and actual ratings is: 0.2503
#
# On training set:
# Residual sum of squares: 1.07
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2902
# Spearman Correlation between predicted ratings and actual ratings is: 0.2798
# ****************************************************************************************
# responsible
# mean rating:  5.86209432941
# Correlation:  0.244465419366
# num of features:  33
# Spearman Correlation:  0.280178191113
# num of features:  33
# R^2 score:  0.0582852878058
# num of features:  33
# MSE:  0.746471376204
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 33
# On test set:
# Residual sum of squares: 0.74
# Variance score is: 0.03
# Correlation between predicted ratings and actual ratings is: 0.2134
# Spearman Correlation between predicted ratings and actual ratings is: 0.1872
#
# On training set:
# Residual sum of squares: 0.68
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3306
# Spearman Correlation between predicted ratings and actual ratings is: 0.3049
# ****************************************************************************************
# trustworthy
# mean rating:  5.60918211192
# Correlation:  0.288674116032
# num of features:  33
# Spearman Correlation:  0.325675558506
# num of features:  33
# R^2 score:  0.083137553667
# num of features:  33
# MSE:  0.825668483208
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 33
# On test set:
# Residual sum of squares: 0.78
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2910
# Spearman Correlation between predicted ratings and actual ratings is: 0.2750
#
# On training set:
# Residual sum of squares: 0.78
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3269
# Spearman Correlation between predicted ratings and actual ratings is: 0.3054
# ****************************************************************************************
# unattractive
# mean rating:  4.26128344314
# Correlation:  0.404867173795
# num of features:  50
# Spearman Correlation:  0.405866983747
# num of features:  50
# R^2 score:  0.163178771305
# num of features:  50
# MSE:  1.07609386374
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.22
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2999
# Spearman Correlation between predicted ratings and actual ratings is: 0.2917
#
# On training set:
# Residual sum of squares: 1.07
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4214
# Spearman Correlation between predicted ratings and actual ratings is: 0.4190
# ****************************************************************************************
# unemotional
# mean rating:  3.81009778659
# Correlation:  0.323240510865
# num of features:  50
# Spearman Correlation:  0.334553711569
# num of features:  50
# R^2 score:  0.0996789065195
# num of features:  50
# MSE:  0.8547289247
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.82
# Variance score is: 0.09
# Correlation between predicted ratings and actual ratings is: 0.3042
# Spearman Correlation between predicted ratings and actual ratings is: 0.2989
#
# On training set:
# Residual sum of squares: 0.79
# Variance score is: 0.16
# Correlation between predicted ratings and actual ratings is: 0.4060
# Spearman Correlation between predicted ratings and actual ratings is: 0.3965
# ****************************************************************************************
# unfamiliar
# mean rating:  4.39983614454
# Correlation:  0.179896939301
# num of features:  50
# Spearman Correlation:  0.184355239722
# num of features:  17
# R^2 score:  0.0294315104609
# num of features:  17
# MSE:  0.479312086554
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.48
# Variance score is: -0.01
# Correlation between predicted ratings and actual ratings is: 0.1315
# Spearman Correlation between predicted ratings and actual ratings is: 0.1483
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.09
# Correlation between predicted ratings and actual ratings is: 0.2940
# Spearman Correlation between predicted ratings and actual ratings is: 0.2879
# ****************************************************************************************
# unfriendly
# mean rating:  3.61636378885
# Correlation:  0.29989539857
# num of features:  50
# Spearman Correlation:  0.315129736142
# num of features:  50
# R^2 score:  0.0865830067665
# num of features:  50
# MSE:  1.53534185007
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.37
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2694
# Spearman Correlation between predicted ratings and actual ratings is: 0.2864
#
# On training set:
# Residual sum of squares: 1.27
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.3903
# Spearman Correlation between predicted ratings and actual ratings is: 0.3714
# ****************************************************************************************
# unhappy
# mean rating:  3.60946439556
# Correlation:  0.273323887783
# num of features:  50
# Spearman Correlation:  0.301364123279
# num of features:  50
# R^2 score:  0.0682075650301
# num of features:  50
# MSE:  1.76739737809
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.55
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2659
# Spearman Correlation between predicted ratings and actual ratings is: 0.2830
#
# On training set:
# Residual sum of squares: 1.37
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.3847
# Spearman Correlation between predicted ratings and actual ratings is: 0.3746
# ****************************************************************************************
# weird
# mean rating:  3.63519592705
# Correlation:  0.181880114528
# num of features:  17
# Spearman Correlation:  0.202390101662
# num of features:  17
# R^2 score:  0.0266860751449
# num of features:  17
# MSE:  0.845206296893
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 0.93
# Variance score is: 0.03
# Correlation between predicted ratings and actual ratings is: 0.1701
# Spearman Correlation between predicted ratings and actual ratings is: 0.1675
#
# On training set:
# Residual sum of squares: 0.90
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2247
# Spearman Correlation between predicted ratings and actual ratings is: 0.2328
# ****************************************************************************************
# aggressive
# mean rating:  3.68722056094
# Correlation:  0.326469745607
# num of features:  50
# Spearman Correlation:  0.352420057627
# num of features:  50
# R^2 score:  0.102738771507
# num of features:  50
# MSE:  1.16043560163
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.10
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.3056
# Spearman Correlation between predicted ratings and actual ratings is: 0.3089
#
# On training set:
# Residual sum of squares: 1.11
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.3830
# Spearman Correlation between predicted ratings and actual ratings is: 0.3687
# ****************************************************************************************
# attractive
# mean rating:  4.93915489035
# Correlation:  0.428410834501
# num of features:  50
# Spearman Correlation:  0.432895095412
# num of features:  50
# R^2 score:  0.183398519052
# num of features:  50
# MSE:  1.1449170682
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.24
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.3800
# Spearman Correlation between predicted ratings and actual ratings is: 0.3849
#
# On training set:
# Residual sum of squares: 1.16
# Variance score is: 0.20
# Correlation between predicted ratings and actual ratings is: 0.4513
# Spearman Correlation between predicted ratings and actual ratings is: 0.4371
# ****************************************************************************************
# caring
# mean rating:  5.54517054055
# Correlation:  0.357665838895
# num of features:  50
# Spearman Correlation:  0.36412631876
# num of features:  50
# R^2 score:  0.124388106597
# num of features:  50
# MSE:  0.935787263144
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.01
# Variance score is: 0.10
# Correlation between predicted ratings and actual ratings is: 0.3310
# Spearman Correlation between predicted ratings and actual ratings is: 0.3467
#
# On training set:
# Residual sum of squares: 0.95
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4204
# Spearman Correlation between predicted ratings and actual ratings is: 0.4189
# ****************************************************************************************
# emotStable
# mean rating:  5.72743004531
# Correlation:  0.310040558792
# num of features:  33
# Spearman Correlation:  0.321518914205
# num of features:  33
# R^2 score:  0.0929332025439
# num of features:  33
# MSE:  0.632307870622
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 33
# On test set:
# Residual sum of squares: 0.66
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2127
# Spearman Correlation between predicted ratings and actual ratings is: 0.2113
#
# On training set:
# Residual sum of squares: 0.67
# Variance score is: 0.09
# Correlation between predicted ratings and actual ratings is: 0.2956
# Spearman Correlation between predicted ratings and actual ratings is: 0.2674
# ****************************************************************************************
# emotional
# mean rating:  4.8545259343
# Correlation:  0.361094807003
# num of features:  50
# Spearman Correlation:  0.386429217723
# num of features:  50
# R^2 score:  0.128476372985
# num of features:  50
# MSE:  0.424942953552
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.3050
# Spearman Correlation between predicted ratings and actual ratings is: 0.3327
#
# On training set:
# Residual sum of squares: 0.42
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4159
# Spearman Correlation between predicted ratings and actual ratings is: 0.4335
# ****************************************************************************************
# familiar
# mean rating:  4.82427548618
# Correlation:  0.172655312333
# num of features:  17
# Spearman Correlation:  0.125172423408
# num of features:  17
# R^2 score:  0.027411337986
# num of features:  17
# MSE:  0.433471730933
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.01
# Correlation between predicted ratings and actual ratings is: 0.1219
# Spearman Correlation between predicted ratings and actual ratings is: 0.1078
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.1915
# Spearman Correlation between predicted ratings and actual ratings is: 0.1781
# ****************************************************************************************
# friendly
# mean rating:  5.82372672542
# Correlation:  0.343374996495
# num of features:  50
# Spearman Correlation:  0.357975512502
# num of features:  50
# R^2 score:  0.112162816962
# num of features:  50
# MSE:  1.28392317365
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.30
# Variance score is: 0.09
# Correlation between predicted ratings and actual ratings is: 0.3226
# Spearman Correlation between predicted ratings and actual ratings is: 0.3609
#
# On training set:
# Residual sum of squares: 1.28
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4170
# Spearman Correlation between predicted ratings and actual ratings is: 0.4080
# ****************************************************************************************
# happy
# mean rating:  5.76725519665
# Correlation:  0.355488303349
# num of features:  50
# Spearman Correlation:  0.375534558562
# num of features:  50
# R^2 score:  0.122056901952
# num of features:  50
# MSE:  1.6163156588
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.66
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2982
# Spearman Correlation between predicted ratings and actual ratings is: 0.3403
#
# On training set:
# Residual sum of squares: 1.61
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4190
# Spearman Correlation between predicted ratings and actual ratings is: 0.4239
# ****************************************************************************************
# humble
# mean rating:  5.26263057771
# Correlation:  0.280653871766
# num of features:  50
# Spearman Correlation:  0.294253997721
# num of features:  17
# R^2 score:  0.0704144025226
# num of features:  50
# MSE:  0.665358082912
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.70
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2394
# Spearman Correlation between predicted ratings and actual ratings is: 0.2652
#
# On training set:
# Residual sum of squares: 0.69
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3484
# Spearman Correlation between predicted ratings and actual ratings is: 0.3177
# ****************************************************************************************
# interesting
# mean rating:  5.19165798958
# Correlation:  0.222848722835
# num of features:  50
# Spearman Correlation:  0.196152226686
# num of features:  50
# R^2 score:  0.0407920951252
# num of features:  50
# MSE:  0.523946145055
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.46
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2381
# Spearman Correlation between predicted ratings and actual ratings is: 0.2258
#
# On training set:
# Residual sum of squares: 0.51
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3296
# Spearman Correlation between predicted ratings and actual ratings is: 0.3256
# ****************************************************************************************
# irresponsible
# mean rating:  3.49263116855
# Correlation:  0.274900678927
# num of features:  50
# Spearman Correlation:  0.285499123431
# num of features:  33
# R^2 score:  0.0721821776514
# num of features:  50
# MSE:  0.768967730773
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.69
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2871
# Spearman Correlation between predicted ratings and actual ratings is: 0.2792
#
# On training set:
# Residual sum of squares: 0.72
# Variance score is: 0.13
# Correlation between predicted ratings and actual ratings is: 0.3656
# Spearman Correlation between predicted ratings and actual ratings is: 0.3206
# ****************************************************************************************
# mean
# mean rating:  3.5064195034
# Correlation:  0.312866973206
# num of features:  50
# Spearman Correlation:  0.338127511248
# num of features:  50
# R^2 score:  0.0935459821257
# num of features:  50
# MSE:  1.20842138346
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.17
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2750
# Spearman Correlation between predicted ratings and actual ratings is: 0.2988
#
# On training set:
# Residual sum of squares: 1.14
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.3844
# Spearman Correlation between predicted ratings and actual ratings is: 0.3609
# ****************************************************************************************
# memorable
# mean rating:  4.9651826126
# Correlation:  0.230049643005
# num of features:  50
# Spearman Correlation:  0.202874296712
# num of features:  50
# R^2 score:  0.0365128952657
# num of features:  50
# MSE:  0.419599296549
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.41
# Variance score is: 0.01
# Correlation between predicted ratings and actual ratings is: 0.1891
# Spearman Correlation between predicted ratings and actual ratings is: 0.1975
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3319
# Spearman Correlation between predicted ratings and actual ratings is: 0.3172
# ****************************************************************************************
# normal
# mean rating:  6.00765605256
# Correlation:  0.233293175648
# num of features:  17
# Spearman Correlation:  0.261079665255
# num of features:  17
# R^2 score:  0.054393193275
# num of features:  17
# MSE:  0.545748922211
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 17
# On test set:
# Residual sum of squares: 0.70
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2226
# Spearman Correlation between predicted ratings and actual ratings is: 0.2117
#
# On training set:
# Residual sum of squares: 0.60
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2384
# Spearman Correlation between predicted ratings and actual ratings is: 0.2226
# ****************************************************************************************
# sociable
# mean rating:  5.82178301767
# Correlation:  0.337588037595
# num of features:  50
# Spearman Correlation:  0.341381631934
# num of features:  50
# R^2 score:  0.106281937602
# num of features:  50
# MSE:  1.07018102033
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.17
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2690
# Spearman Correlation between predicted ratings and actual ratings is: 0.2970
#
# On training set:
# Residual sum of squares: 1.03
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4101
# Spearman Correlation between predicted ratings and actual ratings is: 0.4065
# ****************************************************************************************
# typical
# mean rating:  5.28990378885
# Correlation:  0.202978485984
# num of features:  44
# Spearman Correlation:  0.211535982817
# num of features:  44
# R^2 score:  0.0300520065631
# num of features:  44
# MSE:  0.365718889841
# num of features:  44
# **************************Result of train and test**************************************
# number of features: 44
# On test set:
# Residual sum of squares: 0.48
# Variance score is: -0.01
# Correlation between predicted ratings and actual ratings is: 0.1144
# Spearman Correlation between predicted ratings and actual ratings is: 0.1143
#
# On training set:
# Residual sum of squares: 0.41
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2845
# Spearman Correlation between predicted ratings and actual ratings is: 0.2763
# ****************************************************************************************
# uncertain
# mean rating:  3.71752754508
# Correlation:  0.217321016673
# num of features:  50
# Spearman Correlation:  0.23384922117
# num of features:  44
# R^2 score:  0.0435371341675
# num of features:  33
# MSE:  0.655025906972
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2666
# Spearman Correlation between predicted ratings and actual ratings is: 0.2784
#
# On training set:
# Residual sum of squares: 0.59
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3433
# Spearman Correlation between predicted ratings and actual ratings is: 0.3360
# ****************************************************************************************
# uncommon
# mean rating:  3.8728980956
# Correlation:  0.112143698801
# num of features:  33
# Spearman Correlation:  0.136270444721
# num of features:  39
# R^2 score:  -0.0034355044652
# num of features:  17
# MSE:  0.458687743659
# num of features:  17
# **************************Result of train and test**************************************
# number of features: 33
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.02
# Correlation between predicted ratings and actual ratings is: 0.1494
# Spearman Correlation between predicted ratings and actual ratings is: 0.1654
#
# On training set:
# Residual sum of squares: 0.40
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2434
# Spearman Correlation between predicted ratings and actual ratings is: 0.2240
# ****************************************************************************************
# unintelligent
# mean rating:  3.41826166923
# Correlation:  0.172178955156
# num of features:  39
# Spearman Correlation:  0.147890056152
# num of features:  44
# R^2 score:  0.0118678505622
# num of features:  39
# MSE:  0.502739178602
# num of features:  39
# **************************Result of train and test**************************************
# number of features: 39
# On test set:
# Residual sum of squares: 0.59
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2690
# Spearman Correlation between predicted ratings and actual ratings is: 0.2443
#
# On training set:
# Residual sum of squares: 0.57
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2795
# Spearman Correlation between predicted ratings and actual ratings is: 0.2674
# ****************************************************************************************
# untrustworthy
# mean rating:  3.65110533077
# Correlation:  0.306539736982
# num of features:  50
# Spearman Correlation:  0.326316595413
# num of features:  50
# R^2 score:  0.0859317619453
# num of features:  50
# MSE:  0.885921074833
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.96
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.3070
# Spearman Correlation between predicted ratings and actual ratings is: 0.3044
#
# On training set:
# Residual sum of squares: 0.87
# Variance score is: 0.16
# Correlation between predicted ratings and actual ratings is: 0.3969
# Spearman Correlation between predicted ratings and actual ratings is: 0.3711
# ****************************************************************************************
# 2206
# (353, 50) (1413, 50) (441, 50)
# The number of PCs needed to retain 50.000 variance is 50.
# (50, 50)
# (1413, 50)
# (441, 50)
# atypical
# mean rating:  4.08446414454
# Correlation:  0.269676300366
# num of features:  33
# Spearman Correlation:  0.292157650325
# num of features:  28
# R^2 score:  0.0637021596182
# num of features:  33
# MSE:  0.517490105368
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 33
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.03
# Correlation between predicted ratings and actual ratings is: 0.1765
# Spearman Correlation between predicted ratings and actual ratings is: 0.1766
#
# On training set:
# Residual sum of squares: 0.42
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2049
# Spearman Correlation between predicted ratings and actual ratings is: 0.2134
# ****************************************************************************************
# boring
# mean rating:  4.28997636656
# Correlation:  0.246438641827
# num of features:  50
# Spearman Correlation:  0.231252848547
# num of features:  50
# R^2 score:  0.0570310103935
# num of features:  50
# MSE:  0.715217708918
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.68
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2808
# Spearman Correlation between predicted ratings and actual ratings is: 0.2860
#
# On training set:
# Residual sum of squares: 0.57
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3369
# Spearman Correlation between predicted ratings and actual ratings is: 0.3256
# ****************************************************************************************
# calm
# mean rating:  5.80624816221
# Correlation:  0.236186345441
# num of features:  33
# Spearman Correlation:  0.215976247738
# num of features:  33
# R^2 score:  0.0545836579392
# num of features:  33
# MSE:  0.511338814958
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 33
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.01
# Correlation between predicted ratings and actual ratings is: 0.1733
# Spearman Correlation between predicted ratings and actual ratings is: 0.1517
#
# On training set:
# Residual sum of squares: 0.50
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2409
# Spearman Correlation between predicted ratings and actual ratings is: 0.2381
# ****************************************************************************************
# cold
# mean rating:  3.71738235795
# Correlation:  0.279478516229
# num of features:  44
# Spearman Correlation:  0.275250878077
# num of features:  50
# R^2 score:  0.072732754542
# num of features:  44
# MSE:  1.54911660271
# num of features:  44
# **************************Result of train and test**************************************
# number of features: 44
# On test set:
# Residual sum of squares: 1.42
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2759
# Spearman Correlation between predicted ratings and actual ratings is: 0.2785
#
# On training set:
# Residual sum of squares: 1.35
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3390
# Spearman Correlation between predicted ratings and actual ratings is: 0.3274
# ****************************************************************************************
# common
# mean rating:  5.32550588808
# Correlation:  0.149265970408
# num of features:  1
# Spearman Correlation:  0.139839994032
# num of features:  6
# R^2 score:  0.0100852373943
# num of features:  6
# MSE:  0.417606155808
# num of features:  6
# **************************Result of train and test**************************************
# number of features: 1
# On test set:
# Residual sum of squares: 0.34
# Variance score is: -0.00
# Correlation between predicted ratings and actual ratings is: 0.0961
# Spearman Correlation between predicted ratings and actual ratings is: 0.0873
#
# On training set:
# Residual sum of squares: 0.41
# Variance score is: 0.00
# Correlation between predicted ratings and actual ratings is: 0.0121
# Spearman Correlation between predicted ratings and actual ratings is: 0.0288
# ****************************************************************************************
# confident
# mean rating:  5.92335749751
# Correlation:  0.241313916055
# num of features:  39
# Spearman Correlation:  0.23289028635
# num of features:  39
# R^2 score:  0.0578291712123
# num of features:  39
# MSE:  0.713383309355
# num of features:  39
# **************************Result of train and test**************************************
# number of features: 39
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.00
# Correlation between predicted ratings and actual ratings is: 0.1447
# Spearman Correlation between predicted ratings and actual ratings is: 0.1408
#
# On training set:
# Residual sum of squares: 0.61
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2715
# Spearman Correlation between predicted ratings and actual ratings is: 0.2586
# ****************************************************************************************
# egotistic
# mean rating:  4.07662558269
# Correlation:  0.286896239205
# num of features:  44
# Spearman Correlation:  0.296935873485
# num of features:  17
# R^2 score:  0.0771833353008
# num of features:  44
# MSE:  0.880450691888
# num of features:  44
# **************************Result of train and test**************************************
# number of features: 44
# On test set:
# Residual sum of squares: 0.76
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2849
# Spearman Correlation between predicted ratings and actual ratings is: 0.2873
#
# On training set:
# Residual sum of squares: 0.80
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3393
# Spearman Correlation between predicted ratings and actual ratings is: 0.3319
# ****************************************************************************************
# emotUnstable
# mean rating:  3.63361718849
# Correlation:  0.215707086863
# num of features:  22
# Spearman Correlation:  0.204109630046
# num of features:  28
# R^2 score:  0.0446925323687
# num of features:  22
# MSE:  0.80078246653
# num of features:  22
# **************************Result of train and test**************************************
# number of features: 22
# On test set:
# Residual sum of squares: 0.75
# Variance score is: 0.02
# Correlation between predicted ratings and actual ratings is: 0.1574
# Spearman Correlation between predicted ratings and actual ratings is: 0.1693
#
# On training set:
# Residual sum of squares: 0.79
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2383
# Spearman Correlation between predicted ratings and actual ratings is: 0.2310
# ****************************************************************************************
# forgettable
# mean rating:  4.54602870412
# Correlation:  0.221311841726
# num of features:  50
# Spearman Correlation:  0.215697240224
# num of features:  50
# R^2 score:  0.0410091108236
# num of features:  50
# MSE:  0.518155704626
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.09
# Correlation between predicted ratings and actual ratings is: 0.2967
# Spearman Correlation between predicted ratings and actual ratings is: 0.2658
#
# On training set:
# Residual sum of squares: 0.46
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3274
# Spearman Correlation between predicted ratings and actual ratings is: 0.2996
# ****************************************************************************************
# intelligent
# mean rating:  5.83579811962
# Correlation:  0.241348570192
# num of features:  44
# Spearman Correlation:  0.184811678908
# num of features:  39
# R^2 score:  0.0540358448758
# num of features:  44
# MSE:  0.593582396209
# num of features:  44
# **************************Result of train and test**************************************
# number of features: 44
# On test set:
# Residual sum of squares: 0.49
# Variance score is: -0.04
# Correlation between predicted ratings and actual ratings is: 0.1583
# Spearman Correlation between predicted ratings and actual ratings is: 0.1641
#
# On training set:
# Residual sum of squares: 0.50
# Variance score is: 0.10
# Correlation between predicted ratings and actual ratings is: 0.3164
# Spearman Correlation between predicted ratings and actual ratings is: 0.2820
# ****************************************************************************************
# introverted
# mean rating:  3.9278672696
# Correlation:  0.248123267153
# num of features:  22
# Spearman Correlation:  0.257505485229
# num of features:  50
# R^2 score:  0.0573530093585
# num of features:  22
# MSE:  0.918602962722
# num of features:  22
# **************************Result of train and test**************************************
# number of features: 22
# On test set:
# Residual sum of squares: 0.91
# Variance score is: 0.03
# Correlation between predicted ratings and actual ratings is: 0.1670
# Spearman Correlation between predicted ratings and actual ratings is: 0.1781
#
# On training set:
# Residual sum of squares: 0.78
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2155
# Spearman Correlation between predicted ratings and actual ratings is: 0.2246
# ****************************************************************************************
# kind
# mean rating:  5.67934660807
# Correlation:  0.316850100638
# num of features:  44
# Spearman Correlation:  0.30121863515
# num of features:  50
# R^2 score:  0.0932345241825
# num of features:  44
# MSE:  1.16476973536
# num of features:  44
# **************************Result of train and test**************************************
# number of features: 44
# On test set:
# Residual sum of squares: 0.98
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2863
# Spearman Correlation between predicted ratings and actual ratings is: 0.2951
#
# On training set:
# Residual sum of squares: 1.03
# Variance score is: 0.13
# Correlation between predicted ratings and actual ratings is: 0.3640
# Spearman Correlation between predicted ratings and actual ratings is: 0.3513
# ****************************************************************************************
# responsible
# mean rating:  5.86209432941
# Correlation:  0.255422435708
# num of features:  39
# Spearman Correlation:  0.189914983247
# num of features:  39
# R^2 score:  0.0602780148404
# num of features:  39
# MSE:  0.823591679462
# num of features:  39
# **************************Result of train and test**************************************
# number of features: 39
# On test set:
# Residual sum of squares: 0.63
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2503
# Spearman Correlation between predicted ratings and actual ratings is: 0.2344
#
# On training set:
# Residual sum of squares: 0.68
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3439
# Spearman Correlation between predicted ratings and actual ratings is: 0.3138
# ****************************************************************************************
# trustworthy
# mean rating:  5.60918211192
# Correlation:  0.299121488201
# num of features:  44
# Spearman Correlation:  0.285908443634
# num of features:  50
# R^2 score:  0.078614194727
# num of features:  44
# MSE:  0.846625386035
# num of features:  44
# **************************Result of train and test**************************************
# number of features: 44
# On test set:
# Residual sum of squares: 0.79
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2688
# Spearman Correlation between predicted ratings and actual ratings is: 0.2725
#
# On training set:
# Residual sum of squares: 0.76
# Variance score is: 0.13
# Correlation between predicted ratings and actual ratings is: 0.3586
# Spearman Correlation between predicted ratings and actual ratings is: 0.3421
# ****************************************************************************************
# unattractive
# mean rating:  4.26128344314
# Correlation:  0.319792250798
# num of features:  28
# Spearman Correlation:  0.349929925889
# num of features:  22
# R^2 score:  0.100865298127
# num of features:  28
# MSE:  1.23479942234
# num of features:  28
# **************************Result of train and test**************************************
# number of features: 28
# On test set:
# Residual sum of squares: 1.11
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3352
# Spearman Correlation between predicted ratings and actual ratings is: 0.3378
#
# On training set:
# Residual sum of squares: 1.13
# Variance score is: 0.13
# Correlation between predicted ratings and actual ratings is: 0.3585
# Spearman Correlation between predicted ratings and actual ratings is: 0.3628
# ****************************************************************************************
# unemotional
# ...
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3503
# Spearman Correlation between predicted ratings and actual ratings is: 0.3341
# ****************************************************************************************
# emotional
# mean rating:  4.8545259343
# Correlation:  0.3588805256
# num of features:  50
# Spearman Correlation:  0.381912289769
# num of features:  50
# R^2 score:  0.11536752691
# num of features:  50
# MSE:  0.415484535954
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.10
# Correlation between predicted ratings and actual ratings is: 0.3215
# Spearman Correlation between predicted ratings and actual ratings is: 0.3490
#
# On training set:
# Residual sum of squares: 0.42
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4096
# Spearman Correlation between predicted ratings and actual ratings is: 0.4294
# ****************************************************************************************
# familiar
# mean rating:  4.82427548618
# Correlation:  0.227669883762
# num of features:  50
# Spearman Correlation:  0.186956610192
# num of features:  50
# R^2 score:  0.0497294908261
# num of features:  50
# MSE:  0.421757895341
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.44
# Variance score is: -0.03
# Correlation between predicted ratings and actual ratings is: 0.0829
# Spearman Correlation between predicted ratings and actual ratings is: 0.0797
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2723
# Spearman Correlation between predicted ratings and actual ratings is: 0.2586
# ****************************************************************************************
# friendly
# mean rating:  5.82372672542
# Correlation:  0.364495541993
# num of features:  50
# Spearman Correlation:  0.358986882883
# num of features:  50
# R^2 score:  0.132170733458
# num of features:  50
# MSE:  1.32022579596
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.17
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3428
# Spearman Correlation between predicted ratings and actual ratings is: 0.3350
#
# On training set:
# Residual sum of squares: 1.31
# Variance score is: 0.16
# Correlation between predicted ratings and actual ratings is: 0.4000
# Spearman Correlation between predicted ratings and actual ratings is: 0.3986
# ****************************************************************************************
# happy
# mean rating:  5.76725519665
# Correlation:  0.33566559579
# num of features:  50
# Spearman Correlation:  0.34185038643
# num of features:  50
# R^2 score:  0.109044597565
# num of features:  50
# MSE:  1.72874459683
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.54
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3467
# Spearman Correlation between predicted ratings and actual ratings is: 0.3405
#
# On training set:
# Residual sum of squares: 1.63
# Variance score is: 0.16
# Correlation between predicted ratings and actual ratings is: 0.4042
# Spearman Correlation between predicted ratings and actual ratings is: 0.4087
# ****************************************************************************************
# humble
# mean rating:  5.26263057771
# Correlation:  0.263938360925
# num of features:  50
# Spearman Correlation:  0.228410700458
# num of features:  50
# R^2 score:  0.061586449773
# num of features:  28
# MSE:  0.745268888076
# num of features:  28
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.64
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2296
# Spearman Correlation between predicted ratings and actual ratings is: 0.2054
#
# On training set:
# Residual sum of squares: 0.69
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3486
# Spearman Correlation between predicted ratings and actual ratings is: 0.3397
# ****************************************************************************************
# interesting
# mean rating:  5.19165798958
# Correlation:  0.249413332545
# num of features:  50
# Spearman Correlation:  0.256632498385
# num of features:  50
# R^2 score:  0.0550222091829
# num of features:  50
# MSE:  0.489740677565
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.00
# Correlation between predicted ratings and actual ratings is: 0.1876
# Spearman Correlation between predicted ratings and actual ratings is: 0.1654
#
# On training set:
# Residual sum of squares: 0.51
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.3411
# Spearman Correlation between predicted ratings and actual ratings is: 0.3269
# ****************************************************************************************
# irresponsible
# mean rating:  3.49263116855
# Correlation:  0.240667481854
# num of features:  50
# Spearman Correlation:  0.243147969646
# num of features:  28
# R^2 score:  0.0477222703429
# num of features:  28
# MSE:  0.706163210968
# num of features:  28
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2862
# Spearman Correlation between predicted ratings and actual ratings is: 0.2622
#
# On training set:
# Residual sum of squares: 0.76
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.3692
# Spearman Correlation between predicted ratings and actual ratings is: 0.3346
# ****************************************************************************************
# mean
# mean rating:  3.5064195034
# Correlation:  0.316561078196
# num of features:  50
# Spearman Correlation:  0.332017416011
# num of features:  50
# R^2 score:  0.0982900793897
# num of features:  50
# MSE:  1.20019027104
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.04
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.3027
# Spearman Correlation between predicted ratings and actual ratings is: 0.2672
#
# On training set:
# Residual sum of squares: 1.18
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.3727
# Spearman Correlation between predicted ratings and actual ratings is: 0.3569
# ****************************************************************************************
# memorable
# mean rating:  4.9651826126
# Correlation:  0.246700329504
# num of features:  50
# Spearman Correlation:  0.251783987594
# num of features:  50
# R^2 score:  0.0560193546704
# num of features:  50
# MSE:  0.422056988581
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.02
# Correlation between predicted ratings and actual ratings is: 0.1976
# Spearman Correlation between predicted ratings and actual ratings is: 0.1690
#
# On training set:
# Residual sum of squares: 0.43
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3280
# Spearman Correlation between predicted ratings and actual ratings is: 0.3059
# ****************************************************************************************
# normal
# mean rating:  6.00765605256
# Correlation:  0.221591122374
# num of features:  50
# Spearman Correlation:  0.217786556371
# num of features:  50
# R^2 score:  0.0364709548751
# num of features:  11
# MSE:  0.600363746633
# num of features:  11
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.55
# Variance score is: 0.04
# Correlation between predicted ratings and actual ratings is: 0.2428
# Spearman Correlation between predicted ratings and actual ratings is: 0.2420
#
# On training set:
# Residual sum of squares: 0.60
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3322
# Spearman Correlation between predicted ratings and actual ratings is: 0.3271
# ****************************************************************************************
# sociable
# mean rating:  5.82178301767
# Correlation:  0.335434931393
# num of features:  50
# Spearman Correlation:  0.337508963457
# num of features:  50
# R^2 score:  0.110659825304
# num of features:  50
# MSE:  1.05156195633
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 1.03
# Variance score is: 0.07
# Correlation between predicted ratings and actual ratings is: 0.2963
# Spearman Correlation between predicted ratings and actual ratings is: 0.2861
#
# On training set:
# Residual sum of squares: 1.08
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.3917
# Spearman Correlation between predicted ratings and actual ratings is: 0.3884
# ****************************************************************************************
# typical
# mean rating:  5.28990378885
# Correlation:  0.187899218068
# num of features:  50
# Spearman Correlation:  0.189667723875
# num of features:  44
# R^2 score:  0.0264637967383
# num of features:  44
# MSE:  0.39027310353
# num of features:  44
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.02
# Correlation between predicted ratings and actual ratings is: 0.2024
# Spearman Correlation between predicted ratings and actual ratings is: 0.2082
#
# On training set:
# Residual sum of squares: 0.41
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2782
# Spearman Correlation between predicted ratings and actual ratings is: 0.2870
# ****************************************************************************************
# uncertain
# mean rating:  3.71752754508
# Correlation:  0.220082745465
# num of features:  50
# Spearman Correlation:  0.222029703139
# num of features:  50
# R^2 score:  0.037850725611
# num of features:  50
# MSE:  0.597986070489
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.56
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2735
# Spearman Correlation between predicted ratings and actual ratings is: 0.2749
#
# On training set:
# Residual sum of squares: 0.63
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3306
# Spearman Correlation between predicted ratings and actual ratings is: 0.3235
# ****************************************************************************************
# uncommon
# mean rating:  3.8728980956
# Correlation:  0.165535435416
# num of features:  50
# Spearman Correlation:  0.173926514254
# num of features:  44
# R^2 score:  0.0220800614093
# num of features:  33
# MSE:  0.432254458171
# num of features:  33
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.01
# Correlation between predicted ratings and actual ratings is: 0.1461
# Spearman Correlation between predicted ratings and actual ratings is: 0.1413
#
# On training set:
# Residual sum of squares: 0.41
# Variance score is: 0.06
# Correlation between predicted ratings and actual ratings is: 0.2494
# Spearman Correlation between predicted ratings and actual ratings is: 0.2386
# ****************************************************************************************
# unintelligent
# mean rating:  3.41826166923
# Correlation:  0.201599048788
# num of features:  50
# Spearman Correlation:  0.201761842064
# num of features:  50
# R^2 score:  0.0210026732924
# num of features:  50
# MSE:  0.538184860859
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.52
# Variance score is: -0.02
# Correlation between predicted ratings and actual ratings is: 0.1466
# Spearman Correlation between predicted ratings and actual ratings is: 0.1264
#
# On training set:
# Residual sum of squares: 0.57
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3331
# Spearman Correlation between predicted ratings and actual ratings is: 0.3086
# ****************************************************************************************
# untrustworthy
# mean rating:  3.65110533077
# Correlation:  0.322385630367
# num of features:  50
# Spearman Correlation:  0.307487515834
# num of features:  50
# R^2 score:  0.100076608306
# num of features:  50
# MSE:  0.889145968295
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.77
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.3062
# Spearman Correlation between predicted ratings and actual ratings is: 0.2645
#
# On training set:
# Residual sum of squares: 0.92
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.3913
# Spearman Correlation between predicted ratings and actual ratings is: 0.3773
# ****************************************************************************************
# 2206
# (353, 50) (1413, 50) (441, 50)
# The number of PCs needed to retain 50.000 variance is 50.
# (50, 50)
# (1413, 50)
# (441, 50)
# atypical
# mean rating:  4.08446414454
# Correlation:  0.175036254103
# num of features:  50
# Spearman Correlation:  0.208448343308
# num of features:  50
# R^2 score:  0.0175601946742
# num of features:  50
# MSE:  0.422243392391
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.47
# Variance score is: -0.00
# Correlation between predicted ratings and actual ratings is: 0.1293
# Spearman Correlation between predicted ratings and actual ratings is: 0.1471
#
# On training set:
# Residual sum of squares: 0.43
# Variance score is: 0.08
# Correlation between predicted ratings and actual ratings is: 0.2808
# Spearman Correlation between predicted ratings and actual ratings is: 0.2740
# ****************************************************************************************
# boring
# mean rating:  4.28997636656
# Correlation:  0.376307818581
# num of features:  50
# Spearman Correlation:  0.375804301711
# num of features:  50
# R^2 score:  0.135525304387
# num of features:  50
# MSE:  0.586973422581
# num of features:  50
# **************************Result of train and test**************************************
# number of features: 50
# On test set:
# Residual sum of squares: 0.63
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.2422
# Spearman Correlation between predicted ratings and actual ratings is: 0.2486
#
# On training set:
# Residual sum of squares: 0.61
# Variance score is: 0.10
# Correlation between predicted ratings and actual ratings is: 0.3174
# Spearman Correlation between predicted ratings and actual ratings is: 0.3122
# ****************************************************************************************
# calm

# %%
result = np.zeros((40,3))
for j in range(1,50): 
    fName = "../Result/FaceSNN/regression_result_"+str(j)+".csv"
    df = pd.read_csv(fName,index_col = 0)
    result += df.as_matrix()
result = result/49
result_df = pd.DataFrame(result,              
                         index=df.index,
                         columns=df.columns)
result_df.to_csv('../Result/FaceSNN/combined_result.csv')
print result_df
