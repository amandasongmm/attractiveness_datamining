# %%
import caffe
from caffe.draw import draw_net, draw_net_to_file
from caffe.proto import caffe_pb2
from google.protobuf import text_format
net = caffe_pb2.NetParameter()

proto_file = '/raid/linjieli/caffe/models/sraonet/siamese_lecun_train_val.prototxt'
text_format.Merge(open(proto_file).read(), net)
netimg = draw_net(net,'right-left')
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-86b4627f3602> in <module>()
#       7 proto_file = '/raid/linjieli/caffe/models/sraonet/siamese_lecun_train_val.prototxt'
#       8 text_format.Merge(open(proto_file).read(), net)
# ----> 9 netimg = draw_net(net,'right-left')
#
# /usr/local/caffe/python/caffe/draw.py in draw_net(caffe_net, rankdir, ext)
#     193         Postscript representation of the graph.
#     194     """
# --> 195     return get_pydot_graph(caffe_net, rankdir).create(format=ext)
#     196
#     197
#
# /usr/local/caffe/python/caffe/draw.py in get_pydot_graph(caffe_net, rankdir, label_edges)
#     140     pydot_edges = []
#     141     for layer in caffe_net.layer:
# --> 142         node_label = get_layer_label(layer, rankdir)
# ...

# %%
lmdb_env = lmdb.open('/raid/linjieli/faceSimilarity/features_fc8_p/')
lmdb_txn = lmdb_env.begin()
lmdb_cursor = lmdb_txn.cursor()
datum = caffe.proto.caffe_pb2.Datum()

for key, value in lmdb_cursor:
    datum.ParseFromString(value)
    label = datum.label
    data = caffe.io.datum_to_array(datum)
    for d in data:
        print d
# Out:
# [[ 0.24567518]]
# [[-0.05573863]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.25322822]]
# [[-0.04611512]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.24979722]]
# [[-0.06169854]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.25095412]]
# [[-0.06275544]]
# [[ 0.25074619]]
# [[-0.06276745]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.23440474]]
# [[-0.06060856]]
# [[ 0.25352189]]
# [[-0.05330005]]
# [[ 0.25087917]]
# [[-0.06087144]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.2507486]]
# [[-0.06287031]]
# [[ 0.24712285]]
# [[-0.03636336]]
# [[ 0.25156328]]
# [[-0.05827831]]
# [[ 0.25098366]]
# [[-0.06273894]]
# [[ 0.25291544]]
# [[-0.06240667]]
# ...
