# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pandas as pd

from sklearn.decomposition import PCA as sklearnPCA
landMarks = pd.read_csv('../../processing/landmarking/mit/mitLandmarks.csv',index_col = 0)
imageList = list(set(landMarks.index.tolist()))
imageList.sort()
imList = [im[3:] for im in imageList]
print len(imList)
Dataset = 'mit'
MODEL = 'geometric'
homePath = '/home/lli-ms/'
allGeometric = np.loadtxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_totalFeatures.csv', delimiter=',')
print allGeometric.shape
# Out:
# 2207
# (2207, 4592)

# %%
# Make sure that caffe is on the python path:
caffe_root = homePath+'caffe/'
pretrained_model_root = homePath+'caffe/'

# run this line one time only!
import sys
caffePython = pretrained_model_root + 'python'
if caffePython not in sys.path:
    sys.path.insert(0, caffePython)

import caffe
# Load mean
mu = np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy')
mu = mu.mean(1).mean(1)  # average over pixels to obtain the mean (BGR) pixel values
print 'mean-subtracted values:', zip('BGR', mu)

# Load the trained net
MODEL = 'vgg16' #'caffeNet','vgg16','vggFace' or 'faceSNN'
    
if MODEL == 'vgg16':
    MODEL_FILE = caffe_root +'models/VGG16/VGG_ILSVRC_16_layers_deploy.prototxt'
    PRETRAINED_FILE = caffe_root + 'models/VGG16/VGG_ILSVRC_16_layers.caffemodel'
caffe.set_device(1)
caffe.set_mode_gpu()
if not os.path.isfile(PRETRAINED_FILE):
    print("No caffemodel!!!")
elif not os.path.isfile(MODEL_FILE):
    print("No MODEL !!!")
else:
    print "Defining the net!"
    net = caffe.Net(MODEL_FILE,
                PRETRAINED_FILE,
                caffe.TEST)
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
if MODEL != 'faceSNN':
    # subtract the dataset-mean value in each channel
    transformer.set_mean('data', mu)
for layer_name, param in net.params.iteritems():
    print layer_name + '\t' + str(param[0].data.shape), str(param[1].data.shape)
transformer.set_transpose('data', (2,0,1))
# the reference model operates on images in [0,255] range instead of [0,1]
transformer.set_raw_scale('data', 255) 
# the reference model has channels in BGR order instead of RGB
transformer.set_channel_swap('data', (2,1,0))
if MODEL == 'vgg16' or MODEL == 'vggFace':
    imgeReshape = [224,224]
    featureLayer = 'conv5_2' 
if 'fc' in featureLayer:
    featureNum = net.params[featureLayer][1].data.shape[0]
else:
    featureNum = net.blobs[featureLayer].data.flatten().shape[0]/net.blobs[featureLayer].data.shape[0]
print featureNum
features = np.zeros([len(imList),featureNum])
totalNum = 0

# print len(imList)
for img in imList:
    imgName = os.path.basename(img)
    if imgName.endswith(('.jpg','.png')):
        input_image = caffe.io.load_image(img)
        net.blobs['data'].reshape(1,3,imgeReshape[0],imgeReshape[1])
        net.blobs['data'].data[...] = transformer.preprocess('data', input_image)
        out = net.forward()
        feat = net.blobs[featureLayer].data
        if Dataset =='twin':
            img_type = int(imgName[7:-4])/perImNum
            img_index = int(imgName[7:-4])%perImNum
            #print 'img_type:',img_type
            if img_type in img_type_num.keys():
                img_type_num[img_type] = img_type_num[img_type] + 1
                img_type_list[img_type][img_index] = img
            else:
                img_type_num[img_type] = 0
                img_type_list[img_type] = [None]*perImNum
                img_type_index[img_type] = type_index
                type_index +=1
            #print 'img_type_index:',img_type_index[img_type]
            features[img_type_index[img_type],img_type_num[img_type]] = feat.flatten()
        else:
            # need to be further revised!
            features[totalNum] = feat.flatten()
            #print features[totalNum]
        totalNum +=1
    else:
        print img
#print len(img_type_num)
print totalNum
vggFeature = features
# Out:
# mean-subtracted values: [('B', 104.0069879317889), ('G', 116.66876761696767), ('R', 122.6789143406786)]
# Defining the net!
# conv1_1	(64, 3, 3, 3) (64,)
# conv1_2	(64, 64, 3, 3) (64,)
# conv2_1	(128, 64, 3, 3) (128,)
# conv2_2	(128, 128, 3, 3) (128,)
# conv3_1	(256, 128, 3, 3) (256,)
# conv3_2	(256, 256, 3, 3) (256,)
# conv3_3	(256, 256, 3, 3) (256,)
# conv4_1	(512, 256, 3, 3) (512,)
# conv4_2	(512, 512, 3, 3) (512,)
# conv4_3	(512, 512, 3, 3) (512,)
# conv5_1	(512, 512, 3, 3) (512,)
# conv5_2	(512, 512, 3, 3) (512,)
# conv5_3	(512, 512, 3, 3) (512,)
# fc6	(4096, 25088) (4096,)
# fc7	(4096, 4096) (4096,)
# fc8	(1000, 4096) (1000,)
# 100352
# 2207

# %%
print vggFeature.shape
# Out:
# (2207, 100352)

# %%
for j in range(1,2): 
    import random
    featureMat = allGeometric
    randomInd = range(featureMat.shape[0])
    random.shuffle(randomInd)
    print max(randomInd)
    featureMat = featureMat[randomInd,:]
    nSamples = featureMat.shape[0]
    testRatio = 0.2
    valiRatio = 0.2
    testFeatures = featureMat[:int(nSamples*testRatio),:]
    trainFeatures = featureMat[int(nSamples*testRatio):,:]
    valiFeatures = featureMat[-int(trainFeatures.shape[0]*valiRatio):,:]
    trainFeatures = trainFeatures[:-int(trainFeatures.shape[0]*valiRatio),:]
    print valiFeatures.shape, trainFeatures.shape, testFeatures.shape
    explained_variance = 1000
    sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
    trainfeature_transf = sklearn_pca.fit_transform(trainFeatures)
    print 'The number of PCs needed to retain %.3f variance is %d.' \
          % (explained_variance, trainfeature_transf.shape[1])
    print sklearn_pca.components_.shape
    print trainfeature_transf.shape
    testfeature_tansf = sklearn_pca.transform(testFeatures)
    print testfeature_tansf.shape
    valifeature_transf = sklearn_pca.transform(valiFeatures)

    radomImlist = np.asarray(imList)[randomInd]

    vggfeatureMat = vggFeature[randomInd,:]
    nSamples = vggfeatureMat.shape[0]
    testFeatures_vgg = vggfeatureMat[:int(nSamples*testRatio),:]
    trainFeatures_vgg = vggfeatureMat[int(nSamples*testRatio):,:]
    valiFeatures_vgg = vggfeatureMat[-int(trainFeatures_vgg.shape[0]*valiRatio):,:]
    trainFeatures_vgg = trainFeatures_vgg[:-int(trainFeatures_vgg.shape[0]*valiRatio),:]
    print valiFeatures_vgg.shape, trainFeatures_vgg.shape, testFeatures_vgg.shape

    explained_variance = 0.99
    sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
    trainfeature_transf_vgg = sklearn_pca.fit_transform(trainFeatures_vgg)
    print 'The number of PCs needed to retain %.3f variance is %d.' \
          % (explained_variance, trainfeature_transf_vgg.shape[1])
    print sklearn_pca.components_.shape
    print trainfeature_transf_vgg.shape
    testfeature_tansf_vgg = sklearn_pca.transform(testFeatures_vgg)
    print testfeature_tansf_vgg.shape
    valifeature_transf_vgg = sklearn_pca.transform(valiFeatures_vgg)
    print valifeature_transf_vgg.shape

    modelList = []
    optFeaNumList = []
    modelList_vgg = []
    optFeaNumList_vgg = []
    import sys
    import pandas as pd
    socialMeasures = '../Result/mit/socialMeasures.csv'
    socialMeasures = pd.read_csv(socialMeasures,index_col = 0)
    socialAttr = socialMeasures.columns.tolist()
    delElement = ['subage.1', 'submale.1', 'subrace.1','subage', 'submale',\
                  'subrace','catch', 'catchAns','catch.1','catchAns.1']
    social2Attr = [x for x in socialAttr if x not in delElement]

    PkgPath = homePath+'attractiveness_datamining/linjieCode/code'
#     fName = "../Result/Config_vs_VGG16/regression_result_"+str(j)+".csv"
#     text_file = open(fName, "w")
#     d = 'Social Attributes, geometric_test, vgg16_test, geometric_train, vgg16_train, geometric_feature_num, vgg16_FeatureNum'+'\n'
#     text_file.write(d)

    if PkgPath not in sys.path:
        sys.path.insert(0, PkgPath)
    #print sys.path
    from xVal_train_test import Train_Test

    import sklearn
    import numpy as np
    fullRating = np.zeros((2207,40))
    for attr in social2Attr:
        print attr
        #attr= social2Attr[9]，
        mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
                   if imList[i][31:] in socialMeasures.index]
        mean_rating = map(float, mean_rating)
        mean_rating = np.array(mean_rating)
        radomRating = mean_rating[randomInd]
        testRating = radomRating[:int(nSamples*testRatio)]
        trainRating = radomRating[int(nSamples*testRatio):]
        valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
        trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]

        baseLine = mean_rating.mean()
        print 'mean rating: ', baseLine

#         predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
#         myModel,optFeaNum,testC,trainC = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf, \
#                                        testfeature_tansf,valifeature_transf,xVal = True,numTrain = 1,\
#                                        pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
#                                        plotPredActual = False,returnModel = True,returnValTrain = True)
        predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
        myModel_vgg,optFeaNum_vgg,testC_vgg, trainC_vgg = Train_Test(trainSubRating,testRating,valiRating,\
                                        trainfeature_transf_vgg, \
                                       testfeature_tansf_vgg,valifeature_transf_vgg,xVal = True,numTrain = 1,\
                                       pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                       plotPredActual = False,returnModel = True,returnValTrain = True)
        modelList.append(myModel)
        optFeaNumList.append(optFeaNum)
        modelList_vgg.append(myModel_vgg)
        optFeaNumList_vgg.append(optFeaNum_vgg)
        totalRating = np.concatenate([trainSubRating,valiRating,testRating])
        print totalRating.shape
        totalFeature = np.concatenate([trainfeature_transf_vgg[:,:optFeaNum_vgg],valifeature_transf_vgg[:,:optFeaNum_vgg],\
                                       testfeature_tansf_vgg[:,:optFeaNum_vgg]])
        print totalFeature.shape
        fullRating[:,social2Attr.index(attr)] = myModel_vgg.predict(totalFeature)
#         d = attr+', '+ str(testC)+', '+str(testC_vgg)+', '+str(trainC)+', '+str(trainC_vgg)+', '+str(optFeaNum)+', '+str(optFeaNum_vgg)+'\n'
#         text_file.write(d)
#     text_file.close()
# Out:
# 2206
# (353, 4592) (1413, 4592) (441, 4592)
# The number of PCs needed to retain 1000.000 variance is 1000.
# (1000, 4592)
# (1413, 1000)
# (441, 1000)
# (353, 100352) (1413, 100352) (441, 100352)
# The number of PCs needed to retain 0.990 variance is 1244.
# (1244, 100352)
# (1413, 1244)
# (441, 1244)
# (353, 1244)
# atypical
# mean rating:  4.08446414454
# Correlation:  0.442099310232
# num of features:  363
# Spearman Correlation:  0.457348341359
# num of features:  363
# R^2 score:  0.183780074729
# num of features:  293
# MSE:  0.405291586765
# num of features:  293
# **************************Result of train and test**************************************
# number of features: 363
# On test set:
# Residual sum of squares: 0.41
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.3340
# Spearman Correlation between predicted ratings and actual ratings is: 0.3272
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.46
# Correlation between predicted ratings and actual ratings is: 0.6772
# Spearman Correlation between predicted ratings and actual ratings is: 0.6597
# ****************************************************************************************
# (2207,)
# (2207, 363)
# boring
# mean rating:  4.28997636656
# Correlation:  0.613448064439
# num of features:  247
# Spearman Correlation:  0.605879062552
# num of features:  121
# R^2 score:  0.374375465892
# num of features:  247
# MSE:  0.438120346165
# num of features:  247
# **************************Result of train and test**************************************
# number of features: 247
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.29
# Correlation between predicted ratings and actual ratings is: 0.5452
# Spearman Correlation between predicted ratings and actual ratings is: 0.5431
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7301
# Spearman Correlation between predicted ratings and actual ratings is: 0.7245
# ****************************************************************************************
# (2207,)
# (2207, 247)
# calm
# mean rating:  5.80624816221
# Correlation:  0.513247271602
# num of features:  358
# Spearman Correlation:  0.467364588988
# num of features:  116
# R^2 score:  0.258362010621
# num of features:  127
# MSE:  0.404694258268
# num of features:  127
# **************************Result of train and test**************************************
# number of features: 358
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.5055
# Spearman Correlation between predicted ratings and actual ratings is: 0.4251
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7115
# Spearman Correlation between predicted ratings and actual ratings is: 0.6337
# ****************************************************************************************
# (2207,)
# (2207, 358)
# cold
# mean rating:  3.71738235795
# Correlation:  0.80639678161
# num of features:  318
# Spearman Correlation:  0.791614475736
# num of features:  379
# R^2 score:  0.6492827408
# num of features:  318
# MSE:  0.553791396616
# num of features:  318
# **************************Result of train and test**************************************
# number of features: 318
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7661
# Spearman Correlation between predicted ratings and actual ratings is: 0.7295
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.75
# Correlation between predicted ratings and actual ratings is: 0.8692
# Spearman Correlation between predicted ratings and actual ratings is: 0.8242
# ****************************************************************************************
# (2207,)
# (2207, 318)
# common
# mean rating:  5.32550588808
# Correlation:  0.375294915851
# num of features:  96
# Spearman Correlation:  0.397710243201
# num of features:  96
# R^2 score:  0.137693571289
# num of features:  96
# MSE:  0.350809001164
# num of features:  96
# **************************Result of train and test**************************************
# number of features: 96
# On test set:
# Residual sum of squares: 0.34
# Variance score is: 0.21
# Correlation between predicted ratings and actual ratings is: 0.4658
# Spearman Correlation between predicted ratings and actual ratings is: 0.4403
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.4976
# Spearman Correlation between predicted ratings and actual ratings is: 0.4672
# ****************************************************************************************
# (2207,)
# (2207, 96)
# confident
# mean rating:  5.92335749751
# Correlation:  0.57794255082
# num of features:  81
# Spearman Correlation:  0.537307883429
# num of features:  51
# R^2 score:  0.333536613796
# num of features:  81
# MSE:  0.459966380066
# num of features:  81
# **************************Result of train and test**************************************
# number of features: 81
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6095
# Spearman Correlation between predicted ratings and actual ratings is: 0.5684
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.45
# Correlation between predicted ratings and actual ratings is: 0.6711
# Spearman Correlation between predicted ratings and actual ratings is: 0.6325
# ****************************************************************************************
# (2207,)
# (2207, 81)
# egotistic
# mean rating:  4.07662558269
# Correlation:  0.642902492621
# num of features:  449
# Spearman Correlation:  0.651910464315
# num of features:  449
# R^2 score:  0.403254966784
# num of features:  449
# MSE:  0.501220272179
# num of features:  449
# **************************Result of train and test**************************************
# number of features: 449
# On test set:
# Residual sum of squares: 0.53
# Variance score is: 0.39
# Correlation between predicted ratings and actual ratings is: 0.6326
# Spearman Correlation between predicted ratings and actual ratings is: 0.6293
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.65
# Correlation between predicted ratings and actual ratings is: 0.8059
# Spearman Correlation between predicted ratings and actual ratings is: 0.8012
# ****************************************************************************************
# (2207,)
# (2207, 449)
# emotUnstable
# mean rating:  3.63361718849
# Correlation:  0.648653857427
# num of features:  293
# Spearman Correlation:  0.565629603325
# num of features:  363
# R^2 score:  0.419708514686
# num of features:  293
# MSE:  0.502098870345
# num of features:  293
# **************************Result of train and test**************************************
# number of features: 293
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6134
# Spearman Correlation between predicted ratings and actual ratings is: 0.5352
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7712
# Spearman Correlation between predicted ratings and actual ratings is: 0.6957
# ****************************************************************************************
# (2207,)
# (2207, 293)
# forgettable
# mean rating:  4.54602870412
# Correlation:  0.436911211183
# num of features:  121
# Spearman Correlation:  0.43886917108
# num of features:  51
# R^2 score:  0.185784619128
# num of features:  51
# MSE:  0.447596572103
# num of features:  51
# **************************Result of train and test**************************************
# number of features: 121
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.23
# Correlation between predicted ratings and actual ratings is: 0.4870
# Spearman Correlation between predicted ratings and actual ratings is: 0.4601
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6092
# Spearman Correlation between predicted ratings and actual ratings is: 0.5969
# ****************************************************************************************
# (2207,)
# (2207, 121)
# intelligent
# mean rating:  5.83579811962
# Correlation:  0.611753736426
# num of features:  343
# Spearman Correlation:  0.554165012506
# num of features:  303
# R^2 score:  0.368141717105
# num of features:  343
# MSE:  0.334033029284
# num of features:  343
# **************************Result of train and test**************************************
# number of features: 343
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5747
# Spearman Correlation between predicted ratings and actual ratings is: 0.5209
#
# On training set:
# Residual sum of squares: 0.22
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7818
# Spearman Correlation between predicted ratings and actual ratings is: 0.7212
# ****************************************************************************************
# (2207,)
# (2207, 343)
# introverted
# mean rating:  3.9278672696
# Correlation:  0.643391447271
# num of features:  66
# Spearman Correlation:  0.643526457872
# num of features:  51
# R^2 score:  0.409225355401
# num of features:  66
# MSE:  0.570529144943
# num of features:  66
# **************************Result of train and test**************************************
# number of features: 66
# On test set:
# Residual sum of squares: 0.49
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6208
# Spearman Correlation between predicted ratings and actual ratings is: 0.6130
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7064
# Spearman Correlation between predicted ratings and actual ratings is: 0.6986
# ****************************************************************************************
# (2207,)
# (2207, 66)
# kind
# mean rating:  5.67934660807
# Correlation:  0.796088512479
# num of features:  429
# Spearman Correlation:  0.759307982106
# num of features:  409
# R^2 score:  0.633338499667
# num of features:  429
# MSE:  0.42418671166
# num of features:  429
# **************************Result of train and test**************************************
# number of features: 429
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.58
# Correlation between predicted ratings and actual ratings is: 0.7635
# Spearman Correlation between predicted ratings and actual ratings is: 0.7272
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.79
# Correlation between predicted ratings and actual ratings is: 0.8884
# Spearman Correlation between predicted ratings and actual ratings is: 0.8489
# ****************************************************************************************
# (2207,)
# (2207, 429)
# responsible
# mean rating:  5.86209432941
# Correlation:  0.681934603096
# num of features:  127
# Spearman Correlation:  0.607235002544
# num of features:  424
# R^2 score:  0.464166705534
# num of features:  127
# MSE:  0.437844485759
# num of features:  127
# **************************Result of train and test**************************************
# number of features: 127
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.51
# Correlation between predicted ratings and actual ratings is: 0.7195
# Spearman Correlation between predicted ratings and actual ratings is: 0.6357
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7532
# Spearman Correlation between predicted ratings and actual ratings is: 0.6582
# ****************************************************************************************
# (2207,)
# (2207, 127)
# trustworthy
# mean rating:  5.60918211192
# Correlation:  0.724351248755
# num of features:  323
# Spearman Correlation:  0.698315064159
# num of features:  313
# R^2 score:  0.521996993421
# num of features:  323
# MSE:  0.416149207336
# num of features:  323
# **************************Result of train and test**************************************
# number of features: 323
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7096
# Spearman Correlation between predicted ratings and actual ratings is: 0.6683
#
# On training set:
# Residual sum of squares: 0.27
# Variance score is: 0.69
# Correlation between predicted ratings and actual ratings is: 0.8349
# Spearman Correlation between predicted ratings and actual ratings is: 0.7668
# ****************************************************************************************
# (2207,)
# (2207, 323)
# unattractive
# mean rating:  4.26128344314
# Correlation:  0.700470723412
# num of features:  101
# Spearman Correlation:  0.695853989936
# num of features:  96
# R^2 score:  0.490564279191
# num of features:  101
# MSE:  0.724989736718
# num of features:  101
# **************************Result of train and test**************************************
# number of features: 101
# On test set:
# Residual sum of squares: 0.71
# Variance score is: 0.43
# Correlation between predicted ratings and actual ratings is: 0.6577
# Spearman Correlation between predicted ratings and actual ratings is: 0.6434
#
# On training set:
# Residual sum of squares: 0.55
# Variance score is: 0.58
# Correlation between predicted ratings and actual ratings is: 0.7615
# Spearman Correlation between predicted ratings and actual ratings is: 0.7566
# ****************************************************************************************
# (2207,)
# (2207, 101)
# unemotional
# mean rating:  3.81009778659
# Correlation:  0.764679324174
# num of features:  263
# Spearman Correlation:  0.750149884193
# num of features:  258
# R^2 score:  0.584325726469
# num of features:  263
# MSE:  0.400453068005
# num of features:  263
# **************************Result of train and test**************************************
# number of features: 263
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7129
# Spearman Correlation between predicted ratings and actual ratings is: 0.7072
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.69
# Correlation between predicted ratings and actual ratings is: 0.8333
# Spearman Correlation between predicted ratings and actual ratings is: 0.8086
# ****************************************************************************************
# (2207,)
# (2207, 263)
# unfamiliar
# mean rating:  4.39983614454
# Correlation:  0.465382758739
# num of features:  56
# Spearman Correlation:  0.473793918363
# num of features:  86
# R^2 score:  0.215537612988
# num of features:  76
# MSE:  0.420341130826
# num of features:  76
# **************************Result of train and test**************************************
# number of features: 56
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4139
# Spearman Correlation between predicted ratings and actual ratings is: 0.3868
#
# On training set:
# Residual sum of squares: 0.35
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.4908
# Spearman Correlation between predicted ratings and actual ratings is: 0.4711
# ****************************************************************************************
# (2207,)
# (2207, 56)
# unfriendly
# mean rating:  3.61636378885
# Correlation:  0.800289876805
# num of features:  409
# Spearman Correlation:  0.752610144981
# num of features:  414
# R^2 score:  0.640126786447
# num of features:  409
# MSE:  0.564146305262
# num of features:  409
# **************************Result of train and test**************************************
# number of features: 409
# On test set:
# Residual sum of squares: 0.64
# Variance score is: 0.54
# Correlation between predicted ratings and actual ratings is: 0.7416
# Spearman Correlation between predicted ratings and actual ratings is: 0.6940
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.78
# Correlation between predicted ratings and actual ratings is: 0.8834
# Spearman Correlation between predicted ratings and actual ratings is: 0.8278
# ****************************************************************************************
# (2207,)
# (2207, 409)
# unhappy
# mean rating:  3.60946439556
# Correlation:  0.805310400667
# num of features:  379
# Spearman Correlation:  0.753898858611
# num of features:  409
# R^2 score:  0.648458435532
# num of features:  379
# MSE:  0.615364974049
# num of features:  379
# **************************Result of train and test**************************************
# number of features: 379
# On test set:
# Residual sum of squares: 0.57
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7871
# Spearman Correlation between predicted ratings and actual ratings is: 0.7463
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.79
# Correlation between predicted ratings and actual ratings is: 0.8885
# Spearman Correlation between predicted ratings and actual ratings is: 0.8308
# ****************************************************************************************
# (2207,)
# (2207, 379)
# weird
# mean rating:  3.63519592705
# Correlation:  0.553350376429
# num of features:  101
# Spearman Correlation:  0.55349169381
# num of features:  253
# R^2 score:  0.303264223818
# num of features:  101
# MSE:  0.6788610615
# num of features:  101
# **************************Result of train and test**************************************
# number of features: 101
# On test set:
# Residual sum of squares: 0.68
# Variance score is: 0.30
# Correlation between predicted ratings and actual ratings is: 0.5460
# Spearman Correlation between predicted ratings and actual ratings is: 0.5179
#
# On training set:
# Residual sum of squares: 0.53
# Variance score is: 0.42
# Correlation between predicted ratings and actual ratings is: 0.6501
# Spearman Correlation between predicted ratings and actual ratings is: 0.6248
# ****************************************************************************************
# (2207,)
# (2207, 101)
# aggressive
# mean rating:  3.68722056094
# Correlation:  0.756217730231
# num of features:  323
# Spearman Correlation:  0.699828879778
# num of features:  137
# R^2 score:  0.570057866123
# num of features:  323
# MSE:  0.568450541422
# num of features:  323
# **************************Result of train and test**************************************
# number of features: 323
# On test set:
# Residual sum of squares: 0.67
# Variance score is: 0.47
# Correlation between predicted ratings and actual ratings is: 0.6899
# Spearman Correlation between predicted ratings and actual ratings is: 0.6421
#
# On training set:
# Residual sum of squares: 0.41
# Variance score is: 0.67
# Correlation between predicted ratings and actual ratings is: 0.8228
# Spearman Correlation between predicted ratings and actual ratings is: 0.7539
# ****************************************************************************************
# (2207,)
# (2207, 323)
# attractive
# mean rating:  4.93915489035
# Correlation:  0.766777271464
# num of features:  308
# Spearman Correlation:  0.757095729658
# num of features:  116
# R^2 score:  0.587399655801
# num of features:  308
# MSE:  0.648954085433
# num of features:  308
# **************************Result of train and test**************************************
# number of features: 308
# On test set:
# Residual sum of squares: 0.61
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7465
# Spearman Correlation between predicted ratings and actual ratings is: 0.7428
#
# On training set:
# Residual sum of squares: 0.40
# Variance score is: 0.72
# Correlation between predicted ratings and actual ratings is: 0.8504
# Spearman Correlation between predicted ratings and actual ratings is: 0.8478
# ****************************************************************************************
# (2207,)
# (2207, 308)
# caring
# mean rating:  5.54517054055
# Correlation:  0.800018940535
# num of features:  318
# Spearman Correlation:  0.765923279847
# num of features:  358
# R^2 score:  0.639469192659
# num of features:  318
# MSE:  0.412577593672
# num of features:  318
# **************************Result of train and test**************************************
# number of features: 318
# On test set:
# Residual sum of squares: 0.50
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7340
# Spearman Correlation between predicted ratings and actual ratings is: 0.7064
#
# On training set:
# Residual sum of squares: 0.28
# Variance score is: 0.76
# Correlation between predicted ratings and actual ratings is: 0.8719
# Spearman Correlation between predicted ratings and actual ratings is: 0.8312
# ****************************************************************************************
# (2207,)
# (2207, 318)
# emotStable
# mean rating:  5.72743004531
# Correlation:  0.704919697855
# num of features:  379
# Spearman Correlation:  0.631772502
# num of features:  127
# R^2 score:  0.496596079385
# num of features:  379
# MSE:  0.388698983745
# num of features:  379
# **************************Result of train and test**************************************
# number of features: 379
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6274
# Spearman Correlation between predicted ratings and actual ratings is: 0.5622
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.65
# Correlation between predicted ratings and actual ratings is: 0.8083
# Spearman Correlation between predicted ratings and actual ratings is: 0.7257
# ****************************************************************************************
# (2207,)
# (2207, 379)
# emotional
# mean rating:  4.8545259343
# Correlation:  0.609860235099
# num of features:  121
# Spearman Correlation:  0.626457561394
# num of features:  46
# R^2 score:  0.366935612952
# num of features:  121
# MSE:  0.335695264152
# num of features:  121
# **************************Result of train and test**************************************
# number of features: 121
# On test set:
# Residual sum of squares: 0.30
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5759
# Spearman Correlation between predicted ratings and actual ratings is: 0.5767
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.6966
# Spearman Correlation between predicted ratings and actual ratings is: 0.7076
# ****************************************************************************************
# (2207,)
# (2207, 121)
# familiar
# mean rating:  4.82427548618
# Correlation:  0.410201552932
# num of features:  86
# Spearman Correlation:  0.394337953556
# num of features:  86
# R^2 score:  0.156870524405
# num of features:  86
# MSE:  0.405781878807
# num of features:  86
# **************************Result of train and test**************************************
# number of features: 86
# On test set:
# Residual sum of squares: 0.41
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.4015
# Spearman Correlation between predicted ratings and actual ratings is: 0.3986
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.31
# Correlation between predicted ratings and actual ratings is: 0.5612
# Spearman Correlation between predicted ratings and actual ratings is: 0.5166
# ****************************************************************************************
# (2207,)
# (2207, 86)
# friendly
# mean rating:  5.82372672542
# Correlation:  0.834639525355
# num of features:  449
# Spearman Correlation:  0.816703493866
# num of features:  96
# R^2 score:  0.696526072196
# num of features:  449
# MSE:  0.466097871399
# num of features:  449
# **************************Result of train and test**************************************
# number of features: 449
# On test set:
# Residual sum of squares: 0.54
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7844
# Spearman Correlation between predicted ratings and actual ratings is: 0.7500
#
# On training set:
# Residual sum of squares: 0.28
# Variance score is: 0.82
# Correlation between predicted ratings and actual ratings is: 0.9053
# Spearman Correlation between predicted ratings and actual ratings is: 0.8597
# ****************************************************************************************
# (2207,)
# (2207, 449)
# happy
# mean rating:  5.76725519665
# Correlation:  0.861614967115
# num of features:  409
# Spearman Correlation:  0.839723194144
# num of features:  409
# R^2 score:  0.741262773503
# num of features:  409
# MSE:  0.519703306426
# num of features:  409
# **************************Result of train and test**************************************
# number of features: 409
# On test set:
# Residual sum of squares: 0.61
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8033
# Spearman Correlation between predicted ratings and actual ratings is: 0.7844
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.84
# Correlation between predicted ratings and actual ratings is: 0.9159
# Spearman Correlation between predicted ratings and actual ratings is: 0.8815
# ****************************************************************************************
# (2207,)
# (2207, 409)
# humble
# mean rating:  5.26263057771
# Correlation:  0.659314325379
# num of features:  404
# Spearman Correlation:  0.629380930701
# num of features:  444
# R^2 score:  0.432786261946
# num of features:  404
# MSE:  0.429656266211
# num of features:  404
# **************************Result of train and test**************************************
# number of features: 404
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.36
# Correlation between predicted ratings and actual ratings is: 0.6046
# Spearman Correlation between predicted ratings and actual ratings is: 0.5858
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.62
# Correlation between predicted ratings and actual ratings is: 0.7913
# Spearman Correlation between predicted ratings and actual ratings is: 0.7515
# ****************************************************************************************
# (2207,)
# (2207, 404)
# interesting
# mean rating:  5.19165798958
# Correlation:  0.624473378611
# num of features:  121
# Spearman Correlation:  0.621541052904
# num of features:  121
# R^2 score:  0.384640030902
# num of features:  137
# MSE:  0.400745594107
# num of features:  137
# **************************Result of train and test**************************************
# number of features: 121
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.5129
# Spearman Correlation between predicted ratings and actual ratings is: 0.4879
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.46
# Correlation between predicted ratings and actual ratings is: 0.6786
# Spearman Correlation between predicted ratings and actual ratings is: 0.6487
# ****************************************************************************************
# (2207,)
# (2207, 121)
# irresponsible
# mean rating:  3.49263116855
# Correlation:  0.691143358347
# num of features:  353
# Spearman Correlation:  0.616899652851
# num of features:  358
# R^2 score:  0.476543797462
# num of features:  353
# MSE:  0.414867114509
# num of features:  353
# **************************Result of train and test**************************************
# number of features: 353
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6368
# Spearman Correlation between predicted ratings and actual ratings is: 0.5625
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8048
# Spearman Correlation between predicted ratings and actual ratings is: 0.7200
# ****************************************************************************************
# (2207,)
# (2207, 353)
# mean
# mean rating:  3.5064195034
# Correlation:  0.76146526714
# num of features:  293
# Spearman Correlation:  0.704554325495
# num of features:  439
# R^2 score:  0.577277477564
# num of features:  293
# MSE:  0.561660678308
# num of features:  293
# **************************Result of train and test**************************************
# number of features: 293
# On test set:
# Residual sum of squares: 0.69
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6728
# Spearman Correlation between predicted ratings and actual ratings is: 0.6134
#
# On training set:
# Residual sum of squares: 0.40
# Variance score is: 0.70
# Correlation between predicted ratings and actual ratings is: 0.8381
# Spearman Correlation between predicted ratings and actual ratings is: 0.7585
# ****************************************************************************************
# (2207,)
# (2207, 293)
# memorable
# mean rating:  4.9651826126
# Correlation:  0.465709507549
# num of features:  137
# Spearman Correlation:  0.446670034444
# num of features:  247
# R^2 score:  0.213594743411
# num of features:  137
# MSE:  0.405222146129
# num of features:  137
# **************************Result of train and test**************************************
# number of features: 137
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.21
# Correlation between predicted ratings and actual ratings is: 0.4720
# Spearman Correlation between predicted ratings and actual ratings is: 0.4572
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6100
# Spearman Correlation between predicted ratings and actual ratings is: 0.5828
# ****************************************************************************************
# (2207,)
# (2207, 137)
# normal
# mean rating:  6.00765605256
# Correlation:  0.626833111197
# num of features:  308
# Spearman Correlation:  0.595547627326
# num of features:  308
# R^2 score:  0.386002661045
# num of features:  308
# MSE:  0.403681413992
# num of features:  308
# **************************Result of train and test**************************************
# number of features: 308
# On test set:
# Residual sum of squares: 0.50
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.5194
# Spearman Correlation between predicted ratings and actual ratings is: 0.4656
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7708
# Spearman Correlation between predicted ratings and actual ratings is: 0.6995
# ****************************************************************************************
# (2207,)
# (2207, 308)
# sociable
# mean rating:  5.82178301767
# Correlation:  0.800508404474
# num of features:  253
# Spearman Correlation:  0.783794626039
# num of features:  46
# R^2 score:  0.640263397183
# num of features:  253
# MSE:  0.471122797896
# num of features:  253
# **************************Result of train and test**************************************
# number of features: 253
# On test set:
# Residual sum of squares: 0.53
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7154
# Spearman Correlation between predicted ratings and actual ratings is: 0.6721
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.73
# Correlation between predicted ratings and actual ratings is: 0.8545
# Spearman Correlation between predicted ratings and actual ratings is: 0.8088
# ****************************************************************************************
# (2207,)
# (2207, 253)
# typical
# mean rating:  5.28990378885
# Correlation:  0.472385018924
# num of features:  61
# Spearman Correlation:  0.455402836625
# num of features:  61
# R^2 score:  0.222497605958
# num of features:  61
# MSE:  0.342266536847
# num of features:  61
# **************************Result of train and test**************************************
# number of features: 61
# On test set:
# Residual sum of squares: 0.35
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4372
# Spearman Correlation between predicted ratings and actual ratings is: 0.4096
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.5016
# Spearman Correlation between predicted ratings and actual ratings is: 0.4670
# ****************************************************************************************
# (2207,)
# (2207, 61)
# uncertain
# mean rating:  3.71752754508
# Correlation:  0.62572140073
# num of features:  51
# Spearman Correlation:  0.622772779617
# num of features:  41
# R^2 score:  0.383208535603
# num of features:  197
# MSE:  0.474569559073
# num of features:  197
# **************************Result of train and test**************************************
# number of features: 51
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.36
# Correlation between predicted ratings and actual ratings is: 0.5992
# Spearman Correlation between predicted ratings and actual ratings is: 0.5914
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.43
# Correlation between predicted ratings and actual ratings is: 0.6576
# Spearman Correlation between predicted ratings and actual ratings is: 0.6327
# ****************************************************************************************
# (2207,)
# (2207, 51)
# uncommon
# mean rating:  3.8728980956
# Correlation:  0.40628113047
# num of features:  61
# Spearman Correlation:  0.410794112575
# num of features:  288
# R^2 score:  0.163644193492
# num of features:  61
# MSE:  0.366906114591
# num of features:  61
# **************************Result of train and test**************************************
# number of features: 61
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.3751
# Spearman Correlation between predicted ratings and actual ratings is: 0.3603
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.4904
# Spearman Correlation between predicted ratings and actual ratings is: 0.4688
# ****************************************************************************************
# (2207,)
# (2207, 61)
# unintelligent
# mean rating:  3.41826166923
# Correlation:  0.618670040234
# num of features:  187
# Spearman Correlation:  0.538927676897
# num of features:  187
# R^2 score:  0.379936406409
# num of features:  187
# MSE:  0.378954591657
# num of features:  187
# **************************Result of train and test**************************************
# number of features: 187
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5665
# Spearman Correlation between predicted ratings and actual ratings is: 0.5054
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.6907
# Spearman Correlation between predicted ratings and actual ratings is: 0.6137
# ****************************************************************************************
# (2207,)
# (2207, 187)
# untrustworthy
# mean rating:  3.65110533077
# Correlation:  0.732432435169
# num of features:  409
# Spearman Correlation:  0.680455370084
# num of features:  414
# R^2 score:  0.536066981394
# num of features:  409
# MSE:  0.496957680558
# num of features:  409
# **************************Result of train and test**************************************
# number of features: 409
# On test set:
# Residual sum of squares: 0.59
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6301
# Spearman Correlation between predicted ratings and actual ratings is: 0.5614
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.71
# Correlation between predicted ratings and actual ratings is: 0.8415
# Spearman Correlation between predicted ratings and actual ratings is: 0.7715
# ****************************************************************************************
# (2207,)
# (2207, 409)

# %%
import scipy
rho, pval = scipy.stats.spearmanr(fullRating)
print fullRating.shape, len(social2Attr)
fullRating_df = pd.DataFrame(fullRating)
print fullRating_df.shape
fullRating_df.columns = social2Attr
fullRating_df.index = radomImlist
fullRating_df = fullRating_df.sort_index()
fullRating_df.to_csv('../Result/fullRating_predicted.csv')

print fullRating_df
# Out:
# (2207, 40) 40
# (2207, 40)
#                                                               atypical  \
# ../../MIT2kFaceDataset/2kfaces/Aaron_Dollar_13_oval.jpg       3.353041
# ../../MIT2kFaceDataset/2kfaces/Aaron_Mink_9_oval.jpg          3.813427
# ../../MIT2kFaceDataset/2kfaces/Aaron_Turner_13_oval.jpg       4.126641
# ../../MIT2kFaceDataset/2kfaces/Ada_Galbreath_19_oval.jpg      4.391781
# ../../MIT2kFaceDataset/2kfaces/Ada_Riddick_15_oval.jpg        4.631135
# ../../MIT2kFaceDataset/2kfaces/Adam_Cauthen_11_oval.jpg       4.639407
# ../../MIT2kFaceDataset/2kfaces/Adam_Cowart_5_oval.jpg         3.472642
# ../../MIT2kFaceDataset/2kfaces/Adam_Cuthbertson_3_oval.jpg    4.023546
# ../../MIT2kFaceDataset/2kfaces/Adam_Koester_12_oval.jpg       4.173249
# ../../MIT2kFaceDataset/2kfaces/Adam_Koester_6_oval.jpg        4.289589
# ../../MIT2kFaceDataset/2kfaces/Adrienne_Blaney_15_oval.jpg    3.922009
# ../../MIT2kFaceDataset/2kfaces/Adrienne_Blaney_1_oval.jpg     3.978319
# ../../MIT2kFaceDataset/2kfaces/Adrienne_Coen_13_oval.jpg      4.827904
# ../../MIT2kFaceDataset/2kfaces/Agnes_Castellanos_11_oval.jpg  3.495055
# ../../MIT2kFaceDataset/2kfaces/Alan_Abbey_19_oval.jpg         3.525758
# ../../MIT2kFaceDataset/2kfaces/Alan_Gamerson_7_oval.jpg       3.487033
# ../../MIT2kFaceDataset/2kfaces/Alan_Infante_11_oval.jpg       3.931971
# ../../MIT2kFaceDataset/2kfaces/Alan_Rainwater_15_oval.jpg     4.520496
# ../../MIT2kFaceDataset/2kfaces/Albert_Belk_12_oval.jpg        3.590217
# ../../MIT2kFaceDataset/2kfaces/Albert_Carbaugh_3_oval.jpg     3.537288
# ../../MIT2kFaceDataset/2kfaces/Albert_Cardoza_5_oval.jpg      4.417247
# ../../MIT2kFaceDataset/2kfaces/Albert_Carlyle_5_oval.jpg      3.623352
# ../../MIT2kFaceDataset/2kfaces/Albert_Dobson_9_oval.jpg       3.838592
# ../../MIT2kFaceDataset/2kfaces/Albert_Neu_11_oval.jpg         4.644031
# ../../MIT2kFaceDataset/2kfaces/Albert_Neu_7_oval.jpg          4.951790
# ../../MIT2kFaceDataset/2kfaces/Albert_Rohr_5_oval.jpg         3.711462
# ../../MIT2kFaceDataset/2kfaces/Ana_Bahr_11_oval.jpg           4.807112 ...
# ../../MIT2kFaceDataset/2kfaces/Ana_Gulley_15_oval.jpg         3.064750 ...
# ../../MIT2kFaceDataset/2kfaces/Ana_Starnes_1_oval.jpg         3.349114 ...
# ../../MIT2kFaceDataset/2kfaces/Andrew_Baugh_17_oval.jpg       3.898718 ...
# ../../MIT2kFaceDataset/2kfaces/Andrew_Cuevas_3_oval.jpg       2.598708 ...
# ../../MIT2kFaceDataset/2kfaces/Andrew_Jaggers_11_oval.jpg     3.387500 ...
# ../../MIT2kFaceDataset/2kfaces/Andrew_Perreira_5_oval.jpg     3.106031 ...
# ../../MIT2kFaceDataset/2kfaces/Andrew_Presley_11_oval.jpg     3.063796 ...
# ../../MIT2kFaceDataset/2kfaces/Angela_Bono_3_oval.jpg         4.021554 ...
# ../../MIT2kFaceDataset/2kfaces/Angela_Upshaw_15_oval.jpg      3.665102 ...
# ../../MIT2kFaceDataset/2kfaces/Ann_Marino_9_oval.jpg          3.178601 ...
# ../../MIT2kFaceDataset/2kfaces/Ann_Mullen_15_oval.jpg         3.738490 ...
# ../../MIT2kFaceDataset/2kfaces/Ann_Siu_13_oval.jpg            3.281197 ...
# ../../MIT2kFaceDataset/2kfaces/Annette_Vest_17_oval.jpg       4.105006 ...
#                                                                    ...
#
# [2207 rows x 40 columns]

# %%
#print rho
explained_variance = 0.95
sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
transform_rating = sklearn_pca.fit_transform(fullRating)
print 'The number of PCs needed to retain %.3f variance is %d.' \
      % (explained_variance, transform_rating.shape[1])
rho_df = pd.DataFrame(rho)
rho_df.columns = social2Attr
rho_df.to_csv('correlation_predicted.csv')
# Out:
# The number of PCs needed to retain 0.950 variance is 8.

# %%
print social2Attr
ordered = ['attractive','happy','friendly','sociable','kind','caring','calm',\
           'trustworthy','responsible','confident','humble','emotStable',\
           'normal','intelligent','interesting','emotional','memorable','typical',\
           'familiar','common','unattractive','unhappy','unfriendly','introverted',\
           'mean','cold','aggressive','untrustworthy','irresponsible','uncertain',\
           'egotistic','emotUnstable','weird','unintelligent','boring',\
           'unemotional','forgettable','atypical','unfamiliar','uncommon']
ordered_index = [social2Attr.index(temp) for temp in ordered]
print ordered_index
print ordered
# Out:
# ['atypical', 'boring', 'calm', 'cold', 'common', 'confident', 'egotistic', 'emotUnstable', 'forgettable', 'intelligent', 'introverted', 'kind', 'responsible', 'trustworthy', 'unattractive', 'unemotional', 'unfamiliar', 'unfriendly', 'unhappy', 'weird', 'aggressive', 'attractive', 'caring', 'emotStable', 'emotional', 'familiar', 'friendly', 'happy', 'humble', 'interesting', 'irresponsible', 'mean', 'memorable', 'normal', 'sociable', 'typical', 'uncertain', 'uncommon', 'unintelligent', 'untrustworthy']
# [21, 27, 26, 34, 11, 22, 2, 13, 12, 5, 28, 23, 33, 9, 29, 24, 32, 35, 25, 4, 14, 18, 17, 10, 31, 3, 20, 39, 30, 36, 6, 7, 19, 38, 1, 15, 8, 0, 16, 37]
# ['attractive', 'happy', 'friendly', 'sociable', 'kind', 'caring', 'calm', 'trustworthy', 'responsible', 'confident', 'humble', 'emotStable', 'normal', 'intelligent', 'interesting', 'emotional', 'memorable', 'typical', 'familiar', 'common', 'unattractive', 'unhappy', 'unfriendly', 'introverted', 'mean', 'cold', 'aggressive', 'untrustworthy', 'irresponsible', 'uncertain', 'egotistic', 'emotUnstable', 'weird', 'unintelligent', 'boring', 'unemotional', 'forgettable', 'atypical', 'unfamiliar', 'uncommon']

# %%
result = np.zeros((40,6))
for j in range(1,50): 
    fName = "../Result/Config_vs_VGG16/regression_result_"+str(j)+".csv"
    df = pd.read_csv(fName,index_col = 0)
    result += df.as_matrix()
result = result/49
result_df = pd.DataFrame(result,              
                         index=df.index,
                         columns=df.columns)

# %%
result_df.to_csv('../Result/Config_vs_VGG16/combined_result.csv')
print result_df
# Out:
#                     geometric_test   vgg16_test   geometric_train  \
# Social Attributes
# atypical                  0.402237     0.425398          0.489236
# boring                    0.535243     0.597514          0.600339
# calm                      0.470863     0.495751          0.579291
# cold                      0.806880     0.784627          0.840375
# common                    0.371715     0.401104          0.485130
# confident                 0.552498     0.605544          0.635330
# egotistic                 0.620672     0.620933          0.677723
# emotUnstable              0.616999     0.642095          0.675754
# forgettable               0.401189     0.480230          0.496722
# intelligent               0.532326     0.615056          0.603440
# introverted               0.644715     0.652433          0.689155
# kind                      0.791768     0.785611          0.830976
# responsible               0.651286     0.700054          0.717695
# trustworthy               0.719369     0.731650          0.763551
# unattractive              0.618276     0.698494          0.676386
# unemotional               0.759798     0.746688          0.791983
# unfamiliar                0.396491     0.438311          0.441833
# unfriendly                0.797545     0.780197          0.833444
# unhappy                   0.813517     0.798503          0.851421
# weird                     0.492777     0.558175          0.563616
# aggressive                0.716386     0.718406          0.772323
# attractive                0.657614     0.751353          0.736919
# caring                    0.783243     0.785322          0.827977
# emotStable                0.638680     0.665423          0.712222
# emotional                 0.599780     0.604461          0.638568
# familiar                  0.420838     0.438254          0.491057
# friendly                  0.825922     0.817014          0.859372
# happy                     0.855791     0.839102          0.884445
# humble                    0.637441     0.628475          0.700529
# interesting               0.532106     0.580260          0.609410
# irresponsible             0.635621     0.672135          0.698633
# mean                      0.749040     0.734550          0.795736
# memorable                 0.380388     0.483912          0.487245
# normal                    0.580280     0.613317          0.667597
# sociable                  0.776129     0.777470          0.826167
# typical                   0.410364     0.430608          0.499703
# uncertain                 0.622488     0.625804          0.674569
# uncommon                  0.377829     0.400555          0.457071
# unintelligent             0.526645     0.582987          0.605032
# untrustworthy             0.693333     0.700923          0.748433
#
#                     vgg16_train   geometric_feature_num   vgg16_FeatureNum
# Social Attributes
# atypical               0.509419               86.040816         101.142857
# boring                 0.684780               85.142857         161.489796
# calm                   0.641846              123.510204         226.673469
# cold                   0.854958              118.163265         278.551020
# common                 0.491612              101.346939          99.632653
# confident              0.692921              111.102041         175.571429
# egotistic              0.742102               95.673469         266.244898
# emotUnstable           0.726363               97.489796         189.918367
# forgettable            0.606727               91.020408         169.000000
# intelligent            0.733225              101.367347         261.959184
# introverted            0.723336               76.857143         161.979592
# kind                   0.864208              127.265306         321.020408
# responsible            0.777156              132.693878         216.612245
# trustworthy            0.805520              105.734694         235.734694
# unattractive           0.775048              100.653061         193.897959
# unemotional            0.800268               87.918367         164.020408
# unfamiliar             0.511700               45.020408          89.795918
# unfriendly             0.854875              124.877551         298.938776
# unhappy                0.865633              135.877551         288.693878
# weird                  0.634838               80.244898         119.510204
# aggressive             0.796422              140.285714         235.367347
# attractive             0.852584              145.040816         350.714286
# caring                 0.852474              146.897959         278.510204
# emotStable             0.762028              128.040816         232.469388
# emotional              0.661457               44.877551          92.387755
# familiar               0.527801               66.734694         106.979592
# friendly               0.882335              137.408163         324.142857
# happy                  0.892868              140.040816         283.122449
# humble                 0.723963              119.836735         206.530612
# interesting            0.681491               86.367347         174.081633
# irresponsible          0.754618              111.448980         195.285714
# mean                   0.819980              130.693878         267.571429
# memorable              0.573275               83.020408         104.755102
# normal                 0.695074              128.653061         156.877551
# sociable               0.841476              148.551020         243.408163
# typical                0.539553               78.448980         127.326531
# uncertain              0.692423               87.693878         137.653061
# uncommon               0.496871               72.346939          92.959184
# unintelligent          0.675137               99.346939         159.183673
# untrustworthy          0.784932              124.367347         235.081633
#
# [40 rows x 6 columns]

# %%
print valifeature_transf_vgg.shape
def writeFile(imList, rating,fName):
    text_file = open(fName, "w")
    for i in range(imList.shape[0]):
        d = homePath+'attractiveness_datamining/'+imList[i][6:]+' '+str(rating[i])+'\n'
        text_file.write(d)
    text_file.close()
modelList = []
optFeaNumList = []
radomImlist = np.asarray(imList)[randomInd]
testIm = radomImlist[:int(nSamples*testRatio)]
trainIm = radomImlist[int(nSamples*testRatio):]
print testIm.shape, trainIm.shape
for attr in ['attractive']:
    print attr
    #attr= social2Attr[9]
    mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
               if imList[i][31:] in socialMeasures.index]
    print len(mean_rating)
    mean_rating = map(float, mean_rating)
    mean_rating = np.array(mean_rating)
    radomRating = mean_rating[randomInd]
    testRating = radomRating[:int(nSamples*testRatio)]
    trainRating = radomRating[int(nSamples*testRatio):]
    valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
    print valiRating.shape
    trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]
    #writeFile(trainIm,trainRating,'../list/'+attr+'_train.txt')
    #writeFile(testIm,testRating,'../list/'+attr+'_test.txt')
#     writeFile(trainIm,trainRating,'../data_list/'+attr+'_train.txt')
#     writeFile(testIm,testRating,'../data_list/'+attr+'_test.txt')
    baseLine = mean_rating.mean()
    print 'mean rating: ', baseLine

    predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
    myModel,optFeaNum = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf_vgg, \
                                   testfeature_tansf_vgg,valifeature_transf_vgg,xVal = True,numTrain = 1,\
                                   pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                   plotPredActual = False,returnModel = True)
    modelList.append(myModel)
    optFeaNumList.append(optFeaNum)
