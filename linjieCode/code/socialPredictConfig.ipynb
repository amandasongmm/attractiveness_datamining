# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pandas as pd

from sklearn.decomposition import PCA as sklearnPCA
landMarks = pd.read_csv('../../processing/landmarking/mit/mitLandmarks.csv',index_col = 0)
imageList = list(set(landMarks.index.tolist()))
imageList.sort()
imList = [im[3:] for im in imageList]
print len(imList)
Dataset = 'mit'
MODEL = 'geometric'
homePath = '/home/lli-ms/'
allGeometric = np.loadtxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_totalFeatures.csv', delimiter=',')
print allGeometric.shape
# Out:
# 2207
# (2207, 4592)

# %%
# Make sure that caffe is on the python path:
caffe_root = homePath+'caffe/'
pretrained_model_root = homePath+'caffe/'

# run this line one time only!
import sys
caffePython = pretrained_model_root + 'python'
if caffePython not in sys.path:
    sys.path.insert(0, caffePython)

import caffe
# Load mean
mu = np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy')
mu = mu.mean(1).mean(1)  # average over pixels to obtain the mean (BGR) pixel values
print 'mean-subtracted values:', zip('BGR', mu)

# Load the trained net
MODEL = 'vgg16' #'caffeNet','vgg16','vggFace' or 'faceSNN'
    
if MODEL == 'vgg16':
    MODEL_FILE = caffe_root +'models/VGG16/VGG_ILSVRC_16_layers_deploy.prototxt'
    PRETRAINED_FILE = caffe_root + 'models/VGG16/VGG_ILSVRC_16_layers.caffemodel'
caffe.set_device(1)
caffe.set_mode_gpu()
if not os.path.isfile(PRETRAINED_FILE):
    print("No caffemodel!!!")
elif not os.path.isfile(MODEL_FILE):
    print("No MODEL !!!")
else:
    print "Defining the net!"
    net = caffe.Net(MODEL_FILE,
                PRETRAINED_FILE,
                caffe.TEST)
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
if MODEL != 'faceSNN':
    # subtract the dataset-mean value in each channel
    transformer.set_mean('data', mu)
for layer_name, param in net.params.iteritems():
    print layer_name + '\t' + str(param[0].data.shape), str(param[1].data.shape)
transformer.set_transpose('data', (2,0,1))
# the reference model operates on images in [0,255] range instead of [0,1]
transformer.set_raw_scale('data', 255) 
# the reference model has channels in BGR order instead of RGB
transformer.set_channel_swap('data', (2,1,0))
if MODEL == 'vgg16' or MODEL == 'vggFace':
    imgeReshape = [224,224]
    featureLayer = 'conv5_2' 
if 'fc' in featureLayer:
    featureNum = net.params[featureLayer][1].data.shape[0]
else:
    featureNum = net.blobs[featureLayer].data.flatten().shape[0]/net.blobs[featureLayer].data.shape[0]
print featureNum
features = np.zeros([len(imList),featureNum])
totalNum = 0

# print len(imList)
for img in imList:
    imgName = os.path.basename(img)
    if imgName.endswith(('.jpg','.png')):
        input_image = caffe.io.load_image(img)
        net.blobs['data'].reshape(1,3,imgeReshape[0],imgeReshape[1])
        net.blobs['data'].data[...] = transformer.preprocess('data', input_image)
        out = net.forward()
        feat = net.blobs[featureLayer].data
        if Dataset =='twin':
            img_type = int(imgName[7:-4])/perImNum
            img_index = int(imgName[7:-4])%perImNum
            #print 'img_type:',img_type
            if img_type in img_type_num.keys():
                img_type_num[img_type] = img_type_num[img_type] + 1
                img_type_list[img_type][img_index] = img
            else:
                img_type_num[img_type] = 0
                img_type_list[img_type] = [None]*perImNum
                img_type_index[img_type] = type_index
                type_index +=1
            #print 'img_type_index:',img_type_index[img_type]
            features[img_type_index[img_type],img_type_num[img_type]] = feat.flatten()
        else:
            # need to be further revised!
            features[totalNum] = feat.flatten()
            #print features[totalNum]
        totalNum +=1
    else:
        print img
#print len(img_type_num)
print totalNum
vggFeature = features
# Out:
# mean-subtracted values: [('B', 104.0069879317889), ('G', 116.66876761696767), ('R', 122.6789143406786)]
# Defining the net!
# conv1_1	(64, 3, 3, 3) (64,)
# conv1_2	(64, 64, 3, 3) (64,)
# conv2_1	(128, 64, 3, 3) (128,)
# conv2_2	(128, 128, 3, 3) (128,)
# conv3_1	(256, 128, 3, 3) (256,)
# conv3_2	(256, 256, 3, 3) (256,)
# conv3_3	(256, 256, 3, 3) (256,)
# conv4_1	(512, 256, 3, 3) (512,)
# conv4_2	(512, 512, 3, 3) (512,)
# conv4_3	(512, 512, 3, 3) (512,)
# conv5_1	(512, 512, 3, 3) (512,)
# conv5_2	(512, 512, 3, 3) (512,)
# conv5_3	(512, 512, 3, 3) (512,)
# fc6	(4096, 25088) (4096,)
# fc7	(4096, 4096) (4096,)
# fc8	(1000, 4096) (1000,)
# 100352
# 2207

# %%
print vggFeature.shape
# Out:
# (2207, 100352)

# %%
import random
featureMat = allGeometric
randomInd = range(featureMat.shape[0])
random.shuffle(randomInd)
print max(randomInd)
featureMat = featureMat[randomInd,:]
nSamples = featureMat.shape[0]
testRatio = 0.2
valiRatio = 0.2
testFeatures = featureMat[:int(nSamples*testRatio),:]
trainFeatures = featureMat[int(nSamples*testRatio):,:]
valiFeatures = featureMat[-int(trainFeatures.shape[0]*valiRatio):,:]
trainFeatures = trainFeatures[:-int(trainFeatures.shape[0]*valiRatio),:]
print valiFeatures.shape, trainFeatures.shape, testFeatures.shape
explained_variance = 1000
sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
trainfeature_transf = sklearn_pca.fit_transform(trainFeatures)
print 'The number of PCs needed to retain %.3f variance is %d.' \
      % (explained_variance, trainfeature_transf.shape[1])
print sklearn_pca.components_.shape
print trainfeature_transf.shape
testfeature_tansf = sklearn_pca.transform(testFeatures)
print testfeature_tansf.shape
valifeature_transf = sklearn_pca.transform(valiFeatures)

radomImlist = np.asarray(imList)[randomInd]
# Out:
# 2206
# (353, 4592) (1413, 4592) (441, 4592)
# The number of PCs needed to retain 1000.000 variance is 1000.
# (1000, 4592)
# (1413, 1000)
# (441, 1000)

# %%
vggfeatureMat = vggFeature[randomInd,:]
nSamples = vggfeatureMat.shape[0]
testFeatures_vgg = vggfeatureMat[:int(nSamples*testRatio),:]
trainFeatures_vgg = vggfeatureMat[int(nSamples*testRatio):,:]
valiFeatures_vgg = vggfeatureMat[-int(trainFeatures_vgg.shape[0]*valiRatio):,:]
trainFeatures_vgg = trainFeatures_vgg[:-int(trainFeatures_vgg.shape[0]*valiRatio),:]
print valiFeatures_vgg.shape, trainFeatures_vgg.shape, testFeatures_vgg.shape

explained_variance = 0.99
sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
trainfeature_transf_vgg = sklearn_pca.fit_transform(trainFeatures_vgg)
print 'The number of PCs needed to retain %.3f variance is %d.' \
      % (explained_variance, trainfeature_transf_vgg.shape[1])
print sklearn_pca.components_.shape
print trainfeature_transf_vgg.shape
testfeature_tansf_vgg = sklearn_pca.transform(testFeatures_vgg)
print testfeature_tansf_vgg.shape
valifeature_transf_vgg = sklearn_pca.transform(valiFeatures_vgg)
print valifeature_transf_vgg.shape
# Out:
# (353, 100352) (1413, 100352) (441, 100352)
# The number of PCs needed to retain 0.990 variance is 1244.
# (1244, 100352)
# (1413, 1244)
# (441, 1244)
# (353, 1244)

# %%
modelList = []
optFeaNumList = []
modelList_vgg = []
optFeaNumList_vgg = []
import sys
#print sys.path
# local
# PkgPath = '/Users/Olivialinlin/Documents/Github/attractiveness_datamining/linjieCode/code'
# server
import pandas as pd
socialMeasures = '../Result/mit/socialMeasures.csv'
socialMeasures = pd.read_csv(socialMeasures,index_col = 0)
socialAttr = socialMeasures.columns.tolist()
delElement = ['subage.1', 'submale.1', 'subrace.1','subage', 'submale',\
              'subrace','catch', 'catchAns','catch.1','catchAns.1']
social2Attr = [x for x in socialAttr if x not in delElement]

PkgPath = homePath+'attractiveness_datamining/linjieCode/code'
fName = "./regression_result.csv"
text_file = open(fName, "w")
d = 'Social Attributes, geometric_test, vgg16_test, geometric_train, vgg16_train, geometric_feature_num, vgg16_FeatureNum'+'\n'
text_file.write(d)

if PkgPath not in sys.path:
    sys.path.insert(0, PkgPath)
#print sys.path
from xVal_train_test import Train_Test

import sklearn
import numpy as np
for attr in social2Attr:
    print attr
    #attr= social2Attr[9]，
    mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
               if imList[i][31:] in socialMeasures.index]
    mean_rating = map(float, mean_rating)
    mean_rating = np.array(mean_rating)
    radomRating = mean_rating[randomInd]
    testRating = radomRating[:int(nSamples*testRatio)]
    trainRating = radomRating[int(nSamples*testRatio):]
    valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
    trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]

    baseLine = mean_rating.mean()
    print 'mean rating: ', baseLine

    predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
    myModel,optFeaNum,testC,trainC = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf, \
                                   testfeature_tansf,valifeature_transf,xVal = True,numTrain = 1,\
                                   pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                   plotPredActual = False,returnModel = True,returnValTrain = True)
    predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
    myModel_vgg,optFeaNum_vgg,testC_vgg, trainC_vgg = Train_Test(trainSubRating,testRating,valiRating,\
                                    trainfeature_transf_vgg, \
                                   testfeature_tansf_vgg,valifeature_transf_vgg,xVal = True,numTrain = 1,\
                                   pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                   plotPredActual = False,returnModel = True,returnValTrain = True)
    modelList.append(myModel)
    optFeaNumList.append(optFeaNum)
    modelList_vgg.append(myModel_vgg)
    optFeaNumList_vgg.append(optFeaNum_vgg)
    d = attr+', '+ str(testC)+', '+str(testC_vgg)+', '+str(trainC)+', '+str(trainC_vgg)+', '+str(optFeaNum)+', '+str(optFeaNum_vgg)+'\n'
    text_file.write(d)
text_file.close()
# Out:
# atypical
# mean rating:  4.08446414454
# Correlation:  0.423095587913
# num of features:  90
# Spearman Correlation:  0.447400917047
# num of features:  87
# R^2 score:  0.175383828412
# num of features:  90
# MSE:  0.377625878073
# num of features:  90
# **************************Result of train and test**************************************
# number of features: 90
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.3880
# Spearman Correlation between predicted ratings and actual ratings is: 0.3764
#
# On training set:
# Residual sum of squares: 0.35
# Variance score is: 0.26
# Correlation between predicted ratings and actual ratings is: 0.5093
# Spearman Correlation between predicted ratings and actual ratings is: 0.4791
# ****************************************************************************************
# Correlation:  0.416264933374
# num of features:  111
# Spearman Correlation:  0.417127197784
# num of features:  487
# R^2 score:  0.171703741393
# num of features:  111
# MSE:  0.379311142248
# num of features:  111
# **************************Result of train and test**************************************
# number of features: 111
# On test set:
# Residual sum of squares: 0.35
# Variance score is: 0.20
# Correlation between predicted ratings and actual ratings is: 0.4481
# Spearman Correlation between predicted ratings and actual ratings is: 0.4359
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.28
# Correlation between predicted ratings and actual ratings is: 0.5292
# Spearman Correlation between predicted ratings and actual ratings is: 0.5048
# ****************************************************************************************
# boring
# mean rating:  4.28997636656
# Correlation:  0.518053738613
# num of features:  37
# Spearman Correlation:  0.512410615254
# num of features:  37
# R^2 score:  0.266643890541
# num of features:  37
# MSE:  0.513725082339
# num of features:  37
# **************************Result of train and test**************************************
# number of features: 37
# On test set:
# Residual sum of squares: 0.52
# Variance score is: 0.28
# Correlation between predicted ratings and actual ratings is: 0.5249
# Spearman Correlation between predicted ratings and actual ratings is: 0.5434
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.34
# Correlation between predicted ratings and actual ratings is: 0.5818
# Spearman Correlation between predicted ratings and actual ratings is: 0.5750
# ****************************************************************************************
# Correlation:  0.57256655346
# num of features:  114
# Spearman Correlation:  0.575791902677
# num of features:  108
# R^2 score:  0.32311422851
# num of features:  114
# MSE:  0.474166907738
# num of features:  114
# **************************Result of train and test**************************************
# number of features: 114
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6320
# Spearman Correlation between predicted ratings and actual ratings is: 0.6389
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.45
# Correlation between predicted ratings and actual ratings is: 0.6721
# Spearman Correlation between predicted ratings and actual ratings is: 0.6612
# ****************************************************************************************
# calm
# mean rating:  5.80624816221
# Correlation:  0.536650346205
# num of features:  46
# Spearman Correlation:  0.384911641152
# num of features:  134
# R^2 score:  0.281588569919
# num of features:  46
# MSE:  0.401051337584
# num of features:  46
# **************************Result of train and test**************************************
# number of features: 46
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4311
# Spearman Correlation between predicted ratings and actual ratings is: 0.3948
#
# On training set:
# Residual sum of squares: 0.39
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.4871
# Spearman Correlation between predicted ratings and actual ratings is: 0.4161
# ****************************************************************************************
# Correlation:  0.557438213555
# num of features:  237
# Spearman Correlation:  0.443573081843
# num of features:  714
# R^2 score:  0.308263459261
# num of features:  237
# MSE:  0.38616014905
# num of features:  237
# **************************Result of train and test**************************************
# number of features: 237
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.22
# Correlation between predicted ratings and actual ratings is: 0.4749
# Spearman Correlation between predicted ratings and actual ratings is: 0.3981
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.42
# Correlation between predicted ratings and actual ratings is: 0.6496
# Spearman Correlation between predicted ratings and actual ratings is: 0.5649
# ****************************************************************************************
# cold
# mean rating:  3.71738235795
# Correlation:  0.84329008461
# num of features:  72
# Spearman Correlation:  0.82357675097
# num of features:  75
# R^2 score:  0.708071692274
# num of features:  72
# MSE:  0.501606990163
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 72
# On test set:
# Residual sum of squares: 0.57
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8029
# Spearman Correlation between predicted ratings and actual ratings is: 0.7546
#
# On training set:
# Residual sum of squares: 0.48
# Variance score is: 0.67
# Correlation between predicted ratings and actual ratings is: 0.8215
# Spearman Correlation between predicted ratings and actual ratings is: 0.7935
# ****************************************************************************************
# Correlation:  0.801023950063
# num of features:  352
# Spearman Correlation:  0.769267243974
# num of features:  205
# R^2 score:  0.633621586041
# num of features:  352
# MSE:  0.629531184961
# num of features:  352
# **************************Result of train and test**************************************
# number of features: 352
# On test set:
# Residual sum of squares: 0.57
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8042
# Spearman Correlation between predicted ratings and actual ratings is: 0.7519
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.75
# Correlation between predicted ratings and actual ratings is: 0.8669
# Spearman Correlation between predicted ratings and actual ratings is: 0.8313
# ****************************************************************************************
# common
# mean rating:  5.32550588808
# Correlation:  0.415254261233
# num of features:  90
# Spearman Correlation:  0.421076569164
# num of features:  90
# R^2 score:  0.170730119533
# num of features:  90
# MSE:  0.37449626443
# num of features:  90
# **************************Result of train and test**************************************
# number of features: 90
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.13
# Correlation between predicted ratings and actual ratings is: 0.3707
# Spearman Correlation between predicted ratings and actual ratings is: 0.3573
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.4876
# Spearman Correlation between predicted ratings and actual ratings is: 0.4747
# ****************************************************************************************
# Correlation:  0.38963824432
# num of features:  34
# Spearman Correlation:  0.372750990048
# num of features:  208
# R^2 score:  0.150621278257
# num of features:  34
# MSE:  0.383577368323
# num of features:  34
# **************************Result of train and test**************************************
# number of features: 34
# On test set:
# Residual sum of squares: 0.34
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4460
# Spearman Correlation between predicted ratings and actual ratings is: 0.4239
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4407
# Spearman Correlation between predicted ratings and actual ratings is: 0.4209
# ****************************************************************************************
# confident
# mean rating:  5.92335749751
# Correlation:  0.519629984831
# num of features:  72
# Spearman Correlation:  0.496748280797
# num of features:  72
# R^2 score:  0.262820665917
# num of features:  72
# MSE:  0.441444446873
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 72
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.34
# Correlation between predicted ratings and actual ratings is: 0.5828
# Spearman Correlation between predicted ratings and actual ratings is: 0.5390
#
# On training set:
# Residual sum of squares: 0.42
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6212
# Spearman Correlation between predicted ratings and actual ratings is: 0.5805
# ****************************************************************************************
# Correlation:  0.59484747559
# num of features:  234
# Spearman Correlation:  0.557831639658
# num of features:  234
# R^2 score:  0.351515359812
# num of features:  234
# MSE:  0.388331481985
# num of features:  234
# **************************Result of train and test**************************************
# number of features: 234
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.41
# Correlation between predicted ratings and actual ratings is: 0.6410
# Spearman Correlation between predicted ratings and actual ratings is: 0.5940
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.52
# Correlation between predicted ratings and actual ratings is: 0.7247
# Spearman Correlation between predicted ratings and actual ratings is: 0.6851
# ****************************************************************************************
# egotistic
# mean rating:  4.07662558269
# Correlation:  0.697034597169
# num of features:  108
# Spearman Correlation:  0.691776041863
# num of features:  134
# R^2 score:  0.477782414083
# num of features:  108
# MSE:  0.558338041501
# num of features:  108
# **************************Result of train and test**************************************
# number of features: 108
# On test set:
# Residual sum of squares: 0.58
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6089
# Spearman Correlation between predicted ratings and actual ratings is: 0.6014
#
# On training set:
# Residual sum of squares: 0.46
# Variance score is: 0.45
# Correlation between predicted ratings and actual ratings is: 0.6757
# Spearman Correlation between predicted ratings and actual ratings is: 0.6685
# ****************************************************************************************
# Correlation:  0.671056663889
# num of features:  149
# Spearman Correlation:  0.674803644602
# num of features:  155
# R^2 score:  0.438741288308
# num of features:  532
# MSE:  0.600079542153
# num of features:  532
# **************************Result of train and test**************************************
# number of features: 149
# On test set:
# Residual sum of squares: 0.59
# Variance score is: 0.36
# Correlation between predicted ratings and actual ratings is: 0.6118
# Spearman Correlation between predicted ratings and actual ratings is: 0.6145
#
# On training set:
# Residual sum of squares: 0.45
# Variance score is: 0.47
# Correlation between predicted ratings and actual ratings is: 0.6862
# Spearman Correlation between predicted ratings and actual ratings is: 0.6899
# ****************************************************************************************
# emotUnstable
# mean rating:  3.63361718849
# Correlation:  0.64504940148
# num of features:  61
# Spearman Correlation:  0.580558739166
# num of features:  20
# R^2 score:  0.412568141998
# num of features:  72
# MSE:  0.52000125831
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 61
# On test set:
# Residual sum of squares: 0.50
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6118
# Spearman Correlation between predicted ratings and actual ratings is: 0.5513
#
# On training set:
# Residual sum of squares: 0.48
# Variance score is: 0.41
# Correlation between predicted ratings and actual ratings is: 0.6424
# Spearman Correlation between predicted ratings and actual ratings is: 0.5721
# ****************************************************************************************
# Correlation:  0.680256370207
# num of features:  237
# Spearman Correlation:  0.575510168575
# num of features:  208
# R^2 score:  0.45645844168
# num of features:  237
# MSE:  0.481149073582
# num of features:  237
# **************************Result of train and test**************************************
# number of features: 237
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6642
# Spearman Correlation between predicted ratings and actual ratings is: 0.5712
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.54
# Correlation between predicted ratings and actual ratings is: 0.7387
# Spearman Correlation between predicted ratings and actual ratings is: 0.6625
# ****************************************************************************************
# forgettable
# mean rating:  4.54602870412
# Correlation:  0.410527283626
# num of features:  37
# Spearman Correlation:  0.407881824507
# num of features:  37
# R^2 score:  0.165481175127
# num of features:  37
# MSE:  0.45241396391
# num of features:  37
# **************************Result of train and test**************************************
# number of features: 37
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4324
# Spearman Correlation between predicted ratings and actual ratings is: 0.4487
#
# On training set:
# Residual sum of squares: 0.39
# Variance score is: 0.21
# Correlation between predicted ratings and actual ratings is: 0.4557
# Spearman Correlation between predicted ratings and actual ratings is: 0.4433
# ****************************************************************************************
# Correlation:  0.450632463128
# num of features:  105
# Spearman Correlation:  0.451722663949
# num of features:  105
# R^2 score:  0.19506920235
# num of features:  105
# MSE:  0.43637353884
# num of features:  105
# **************************Result of train and test**************************************
# number of features: 105
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.27
# Correlation between predicted ratings and actual ratings is: 0.5254
# Spearman Correlation between predicted ratings and actual ratings is: 0.5193
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.34
# Correlation between predicted ratings and actual ratings is: 0.5872
# Spearman Correlation between predicted ratings and actual ratings is: 0.5757
# ****************************************************************************************
# intelligent
# mean rating:  5.83579811962
# Correlation:  0.571706088399
# num of features:  90
# Spearman Correlation:  0.465788904794
# num of features:  93
# R^2 score:  0.324940855664
# num of features:  90
# MSE:  0.374979357718
# num of features:  90
# **************************Result of train and test**************************************
# number of features: 90
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.5078
# Spearman Correlation between predicted ratings and actual ratings is: 0.4451
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.36
# Correlation between predicted ratings and actual ratings is: 0.6009
# Spearman Correlation between predicted ratings and actual ratings is: 0.5116
# ****************************************************************************************
# Correlation:  0.62718857108
# num of features:  290
# Spearman Correlation:  0.522220076349
# num of features:  87
# R^2 score:  0.392937131779
# num of features:  290
# MSE:  0.337209037652
# num of features:  290
# **************************Result of train and test**************************************
# number of features: 290
# On test set:
# Residual sum of squares: 0.31
# Variance score is: 0.35
# Correlation between predicted ratings and actual ratings is: 0.6016
# Spearman Correlation between predicted ratings and actual ratings is: 0.5376
#
# On training set:
# Residual sum of squares: 0.24
# Variance score is: 0.57
# Correlation between predicted ratings and actual ratings is: 0.7569
# Spearman Correlation between predicted ratings and actual ratings is: 0.6982
# ****************************************************************************************
# introverted
# mean rating:  3.9278672696
# Correlation:  0.659381829566
# num of features:  34
# Spearman Correlation:  0.659319788721
# num of features:  34
# R^2 score:  0.431093331431
# num of features:  34
# MSE:  0.460186724054
# num of features:  34
# **************************Result of train and test**************************************
# number of features: 34
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.45
# Correlation between predicted ratings and actual ratings is: 0.6700
# Spearman Correlation between predicted ratings and actual ratings is: 0.6675
#
# On training set:
# Residual sum of squares: 0.50
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6629
# Spearman Correlation between predicted ratings and actual ratings is: 0.6575
# ****************************************************************************************
# Correlation:  0.66024583999
# num of features:  231
# Spearman Correlation:  0.643556212911
# num of features:  217
# R^2 score:  0.432852712662
# num of features:  231
# MSE:  0.45876356639
# num of features:  231
# **************************Result of train and test**************************************
# number of features: 231
# On test set:
# Residual sum of squares: 0.51
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6368
# Spearman Correlation between predicted ratings and actual ratings is: 0.6344
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.57
# Correlation between predicted ratings and actual ratings is: 0.7562
# Spearman Correlation between predicted ratings and actual ratings is: 0.7476
# ****************************************************************************************
# kind
# mean rating:  5.67934660807
# Correlation:  0.834911798065
# num of features:  78
# Spearman Correlation:  0.811586052294
# num of features:  61
# R^2 score:  0.692142692768
# num of features:  78
# MSE:  0.406318899011
# num of features:  78
# **************************Result of train and test**************************************
# number of features: 78
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.62
# Correlation between predicted ratings and actual ratings is: 0.7882
# Spearman Correlation between predicted ratings and actual ratings is: 0.7360
#
# On training set:
# Residual sum of squares: 0.39
# Variance score is: 0.65
# Correlation between predicted ratings and actual ratings is: 0.8086
# Spearman Correlation between predicted ratings and actual ratings is: 0.7704
# ****************************************************************************************
# Correlation:  0.808087869632
# num of features:  390
# Spearman Correlation:  0.76604615056
# num of features:  152
# R^2 score:  0.646297771904
# num of features:  655
# MSE:  0.466826339742
# num of features:  655
# **************************Result of train and test**************************************
# number of features: 390
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.63
# Correlation between predicted ratings and actual ratings is: 0.7952
# Spearman Correlation between predicted ratings and actual ratings is: 0.7364
#
# On training set:
# Residual sum of squares: 0.27
# Variance score is: 0.76
# Correlation between predicted ratings and actual ratings is: 0.8735
# Spearman Correlation between predicted ratings and actual ratings is: 0.8329
# ****************************************************************************************
# responsible
# mean rating:  5.86209432941
# Correlation:  0.70392095838
# num of features:  84
# Spearman Correlation:  0.604917755032
# num of features:  52
# R^2 score:  0.488169597813
# num of features:  84
# MSE:  0.442745161273
# num of features:  84
# **************************Result of train and test**************************************
# number of features: 84
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6175
# Spearman Correlation between predicted ratings and actual ratings is: 0.5518
#
# On training set:
# Residual sum of squares: 0.40
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.6930
# Spearman Correlation between predicted ratings and actual ratings is: 0.5874
# ****************************************************************************************
# Correlation:  0.726593194085
# num of features:  234
# Spearman Correlation:  0.610410000028
# num of features:  108
# R^2 score:  0.520258187072
# num of features:  234
# MSE:  0.414987787804
# num of features:  234
# **************************Result of train and test**************************************
# number of features: 234
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.49
# Correlation between predicted ratings and actual ratings is: 0.6987
# Spearman Correlation between predicted ratings and actual ratings is: 0.6125
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7814
# Spearman Correlation between predicted ratings and actual ratings is: 0.6971
# ****************************************************************************************
# trustworthy
# mean rating:  5.60918211192
# Correlation:  0.777406917941
# num of features:  84
# Spearman Correlation:  0.723211959573
# num of features:  67
# R^2 score:  0.597958003327
# num of features:  84
# MSE:  0.375910376829
# num of features:  84
# **************************Result of train and test**************************************
# number of features: 84
# On test set:
# Residual sum of squares: 0.41
# Variance score is: 0.51
# Correlation between predicted ratings and actual ratings is: 0.7156
# Spearman Correlation between predicted ratings and actual ratings is: 0.6714
#
# On training set:
# Residual sum of squares: 0.39
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7475
# Spearman Correlation between predicted ratings and actual ratings is: 0.6853
# ****************************************************************************************
# Correlation:  0.752354947985
# num of features:  349
# Spearman Correlation:  0.696459689262
# num of features:  117
# R^2 score:  0.562221101919
# num of features:  349
# MSE:  0.409324478307
# num of features:  349
# **************************Result of train and test**************************************
# number of features: 349
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.55
# Correlation between predicted ratings and actual ratings is: 0.7405
# Spearman Correlation between predicted ratings and actual ratings is: 0.6867
#
# On training set:
# Residual sum of squares: 0.28
# Variance score is: 0.68
# Correlation between predicted ratings and actual ratings is: 0.8278
# Spearman Correlation between predicted ratings and actual ratings is: 0.7708
# ****************************************************************************************
# unattractive
# mean rating:  4.26128344314
# Correlation:  0.611230346637
# num of features:  40
# Spearman Correlation:  0.611936180706
# num of features:  40
# R^2 score:  0.367092481239
# num of features:  40
# MSE:  0.891013563444
# num of features:  40
# **************************Result of train and test**************************************
# number of features: 40
# On test set:
# Residual sum of squares: 0.79
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6207
# Spearman Correlation between predicted ratings and actual ratings is: 0.6111
#
# On training set:
# Residual sum of squares: 0.77
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6346
# Spearman Correlation between predicted ratings and actual ratings is: 0.6314
# ****************************************************************************************
# Correlation:  0.720756857594
# num of features:  84
# Spearman Correlation:  0.727786321811
# num of features:  84
# R^2 score:  0.497867026585
# num of features:  84
# MSE:  0.706907844674
# num of features:  84
# **************************Result of train and test**************************************
# number of features: 84
# On test set:
# Residual sum of squares: 0.60
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7368
# Spearman Correlation between predicted ratings and actual ratings is: 0.7239
#
# On training set:
# Residual sum of squares: 0.61
# Variance score is: 0.52
# Correlation between predicted ratings and actual ratings is: 0.7254
# Spearman Correlation between predicted ratings and actual ratings is: 0.7173
# ****************************************************************************************
# unemotional
# mean rating:  3.81009778659
# Correlation:  0.791780863914
# num of features:  131
# Spearman Correlation:  0.774234947761
# num of features:  70
# R^2 score:  0.625521649121
# num of features:  131
# MSE:  0.364512505314
# num of features:  131
# **************************Result of train and test**************************************
# number of features: 131
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.55
# Correlation between predicted ratings and actual ratings is: 0.7416
# Spearman Correlation between predicted ratings and actual ratings is: 0.7216
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8031
# Spearman Correlation between predicted ratings and actual ratings is: 0.7888
# ****************************************************************************************
# Correlation:  0.772018217647
# num of features:  214
# Spearman Correlation:  0.75381734235
# num of features:  214
# R^2 score:  0.593073780701
# num of features:  214
# MSE:  0.39609685133
# num of features:  214
# **************************Result of train and test**************************************
# number of features: 214
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.54
# Correlation between predicted ratings and actual ratings is: 0.7343
# Spearman Correlation between predicted ratings and actual ratings is: 0.7278
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.66
# Correlation between predicted ratings and actual ratings is: 0.8151
# Spearman Correlation between predicted ratings and actual ratings is: 0.7927
# ****************************************************************************************
# unfamiliar
# mean rating:  4.39983614454
# Correlation:  0.411555733433
# num of features:  22
# Spearman Correlation:  0.391248766661
# num of features:  22
# R^2 score:  0.160089225691
# num of features:  22
# MSE:  0.39022293656
# num of features:  22
# **************************Result of train and test**************************************
# number of features: 22
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.09
# Correlation between predicted ratings and actual ratings is: 0.3223
# Spearman Correlation between predicted ratings and actual ratings is: 0.3284
#
# On training set:
# Residual sum of squares: 0.39
# Variance score is: 0.20
# Correlation between predicted ratings and actual ratings is: 0.4528
# Spearman Correlation between predicted ratings and actual ratings is: 0.4382
# ****************************************************************************************
# Correlation:  0.438418855251
# num of features:  87
# Spearman Correlation:  0.41589769972
# num of features:  117
# R^2 score:  0.184025782665
# num of features:  87
# MSE:  0.379102001052
# num of features:  87
# **************************Result of train and test**************************************
# number of features: 87
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4131
# Spearman Correlation between predicted ratings and actual ratings is: 0.4158
#
# On training set:
# Residual sum of squares: 0.35
# Variance score is: 0.28
# Correlation between predicted ratings and actual ratings is: 0.5311
# Spearman Correlation between predicted ratings and actual ratings is: 0.5138
# ****************************************************************************************
# unfriendly
# mean rating:  3.61636378885
# Correlation:  0.821065606765
# num of features:  78
# Spearman Correlation:  0.793829966172
# num of features:  22
# R^2 score:  0.670385276084
# num of features:  78
# MSE:  0.560091335299
# num of features:  78
# **************************Result of train and test**************************************
# number of features: 78
# On test set:
# Residual sum of squares: 0.57
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.7999
# Spearman Correlation between predicted ratings and actual ratings is: 0.7396
#
# On training set:
# Residual sum of squares: 0.49
# Variance score is: 0.66
# Correlation between predicted ratings and actual ratings is: 0.8152
# Spearman Correlation between predicted ratings and actual ratings is: 0.7734
# ****************************************************************************************
# Correlation:  0.799522858591
# num of features:  387
# Spearman Correlation:  0.754704881768
# num of features:  205
# R^2 score:  0.630229996079
# num of features:  387
# MSE:  0.628324404896
# num of features:  387
# **************************Result of train and test**************************************
# number of features: 387
# On test set:
# Residual sum of squares: 0.55
# Variance score is: 0.65
# Correlation between predicted ratings and actual ratings is: 0.8082
# Spearman Correlation between predicted ratings and actual ratings is: 0.7548
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.74
# Correlation between predicted ratings and actual ratings is: 0.8642
# Spearman Correlation between predicted ratings and actual ratings is: 0.8062
# ****************************************************************************************
# unhappy
# mean rating:  3.60946439556
# Correlation:  0.838794277312
# num of features:  72
# Spearman Correlation:  0.802913006743
# num of features:  55
# R^2 score:  0.699609511476
# num of features:  72
# MSE:  0.543844798044
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 72
# On test set:
# Residual sum of squares: 0.56
# Variance score is: 0.66
# Correlation between predicted ratings and actual ratings is: 0.8104
# Spearman Correlation between predicted ratings and actual ratings is: 0.7531
#
# On training set:
# Residual sum of squares: 0.52
# Variance score is: 0.68
# Correlation between predicted ratings and actual ratings is: 0.8277
# Spearman Correlation between predicted ratings and actual ratings is: 0.7885
# ****************************************************************************************
# Correlation:  0.816261161194
# num of features:  390
# Spearman Correlation:  0.768562180016
# num of features:  128
# R^2 score:  0.659016219652
# num of features:  390
# MSE:  0.617337306753
# num of features:  390
# **************************Result of train and test**************************************
# number of features: 390
# On test set:
# Residual sum of squares: 0.56
# Variance score is: 0.66
# Correlation between predicted ratings and actual ratings is: 0.8135
# Spearman Correlation between predicted ratings and actual ratings is: 0.7566
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.77
# Correlation between predicted ratings and actual ratings is: 0.8797
# Spearman Correlation between predicted ratings and actual ratings is: 0.8247
# ****************************************************************************************
# weird
# mean rating:  3.63519592705
# Correlation:  0.516444021531
# num of features:  52
# Spearman Correlation:  0.50720817191
# num of features:  52
# R^2 score:  0.265849917748
# num of features:  52
# MSE:  0.685526883405
# num of features:  52
# **************************Result of train and test**************************************
# number of features: 52
# On test set:
# Residual sum of squares: 0.70
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.5023
# Spearman Correlation between predicted ratings and actual ratings is: 0.4864
#
# On training set:
# Residual sum of squares: 0.66
# Variance score is: 0.29
# Correlation between predicted ratings and actual ratings is: 0.5405
# Spearman Correlation between predicted ratings and actual ratings is: 0.5231
# ****************************************************************************************
# Correlation:  0.542469338381
# num of features:  87
# Spearman Correlation:  0.532786158678
# num of features:  155
# R^2 score:  0.292673831547
# num of features:  87
# MSE:  0.660479533452
# num of features:  87
# **************************Result of train and test**************************************
# number of features: 87
# On test set:
# Residual sum of squares: 0.63
# Variance score is: 0.33
# Correlation between predicted ratings and actual ratings is: 0.5823
# Spearman Correlation between predicted ratings and actual ratings is: 0.5646
#
# On training set:
# Residual sum of squares: 0.57
# Variance score is: 0.39
# Correlation between predicted ratings and actual ratings is: 0.6289
# Spearman Correlation between predicted ratings and actual ratings is: 0.6074
# ****************************************************************************************
# aggressive
# mean rating:  3.68722056094
# Correlation:  0.74537459175
# num of features:  146
# Spearman Correlation:  0.714306738408
# num of features:  55
# R^2 score:  0.555155985072
# num of features:  146
# MSE:  0.56451817006
# num of features:  146
# **************************Result of train and test**************************************
# number of features: 146
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7293
# Spearman Correlation between predicted ratings and actual ratings is: 0.6601
#
# On training set:
# Residual sum of squares: 0.51
# Variance score is: 0.60
# Correlation between predicted ratings and actual ratings is: 0.7735
# Spearman Correlation between predicted ratings and actual ratings is: 0.7006
# ****************************************************************************************
# Correlation:  0.723319008849
# num of features:  173
# Spearman Correlation:  0.666806249076
# num of features:  61
# R^2 score:  0.522722163611
# num of features:  173
# MSE:  0.605677499903
# num of features:  173
# **************************Result of train and test**************************************
# number of features: 173
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7327
# Spearman Correlation between predicted ratings and actual ratings is: 0.6660
#
# On training set:
# Residual sum of squares: 0.51
# Variance score is: 0.60
# Correlation between predicted ratings and actual ratings is: 0.7745
# Spearman Correlation between predicted ratings and actual ratings is: 0.7030
# ****************************************************************************************
# attractive
# mean rating:  4.93915489035
# Correlation:  0.641441424757
# num of features:  72
# Spearman Correlation:  0.636936945664
# num of features:  72
# R^2 score:  0.409132155259
# num of features:  72
# MSE:  0.840245657792
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 72
# On test set:
# Residual sum of squares: 0.80
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6625
# Spearman Correlation between predicted ratings and actual ratings is: 0.6574
#
# On training set:
# Residual sum of squares: 0.73
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7113
# Spearman Correlation between predicted ratings and actual ratings is: 0.7111
# ****************************************************************************************
# Correlation:  0.771847109626
# num of features:  499
# Spearman Correlation:  0.777070514133
# num of features:  452
# R^2 score:  0.591398137558
# num of features:  499
# MSE:  0.581053688634
# num of features:  499
# **************************Result of train and test**************************************
# number of features: 499
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7517
# Spearman Correlation between predicted ratings and actual ratings is: 0.7679
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.79
# Correlation between predicted ratings and actual ratings is: 0.8882
# Spearman Correlation between predicted ratings and actual ratings is: 0.8823
# ****************************************************************************************
# caring
# mean rating:  5.54517054055
# Correlation:  0.822049843976
# num of features:  72
# Spearman Correlation:  0.804767475308
# num of features:  52
# R^2 score:  0.6754027968
# num of features:  72
# MSE:  0.376387193718
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 72
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7802
# Spearman Correlation between predicted ratings and actual ratings is: 0.7490
#
# On training set:
# Residual sum of squares: 0.42
# Variance score is: 0.63
# Correlation between predicted ratings and actual ratings is: 0.7931
# Spearman Correlation between predicted ratings and actual ratings is: 0.7449
# ****************************************************************************************
# Correlation:  0.808510980984
# num of features:  452
# Spearman Correlation:  0.784131467298
# num of features:  317
# R^2 score:  0.650926884284
# num of features:  452
# MSE:  0.404768276286
# num of features:  452
# **************************Result of train and test**************************************
# number of features: 452
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7836
# Spearman Correlation between predicted ratings and actual ratings is: 0.7428
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.78
# Correlation between predicted ratings and actual ratings is: 0.8837
# Spearman Correlation between predicted ratings and actual ratings is: 0.8412
# ****************************************************************************************
# emotStable
# mean rating:  5.72743004531
# Correlation:  0.657752752455
# num of features:  78
# Spearman Correlation:  0.589453262203
# num of features:  84
# R^2 score:  0.432466531968
# num of features:  78
# MSE:  0.403739079963
# num of features:  78
# **************************Result of train and test**************************************
# number of features: 78
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.39
# Correlation between predicted ratings and actual ratings is: 0.6261
# Spearman Correlation between predicted ratings and actual ratings is: 0.5652
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.6920
# Spearman Correlation between predicted ratings and actual ratings is: 0.6074
# ****************************************************************************************
# Correlation:  0.658282049439
# num of features:  599
# Spearman Correlation:  0.547523872792
# num of features:  40
# R^2 score:  0.429184279586
# num of features:  264
# MSE:  0.406074049849
# num of features:  264
# **************************Result of train and test**************************************
# number of features: 599
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6634
# Spearman Correlation between predicted ratings and actual ratings is: 0.5714
#
# On training set:
# Residual sum of squares: 0.19
# Variance score is: 0.74
# Correlation between predicted ratings and actual ratings is: 0.8594
# Spearman Correlation between predicted ratings and actual ratings is: 0.7996
# ****************************************************************************************
# emotional
# mean rating:  4.8545259343
# Correlation:  0.639068717701
# num of features:  22
# Spearman Correlation:  0.643846773369
# num of features:  22
# R^2 score:  0.400817825506
# num of features:  22
# MSE:  0.316692507681
# num of features:  22
# **************************Result of train and test**************************************
# number of features: 22
# On test set:
# Residual sum of squares: 0.32
# Variance score is: 0.34
# Correlation between predicted ratings and actual ratings is: 0.5852
# Spearman Correlation between predicted ratings and actual ratings is: 0.6011
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6129
# Spearman Correlation between predicted ratings and actual ratings is: 0.6311
# ****************************************************************************************
# Correlation:  0.642659856743
# num of features:  152
# Spearman Correlation:  0.668453084774
# num of features:  152
# R^2 score:  0.411477830479
# num of features:  152
# MSE:  0.31105825511
# num of features:  152
# **************************Result of train and test**************************************
# number of features: 152
# On test set:
# Residual sum of squares: 0.34
# Variance score is: 0.29
# Correlation between predicted ratings and actual ratings is: 0.5443
# Spearman Correlation between predicted ratings and actual ratings is: 0.5641
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.49
# Correlation between predicted ratings and actual ratings is: 0.6998
# Spearman Correlation between predicted ratings and actual ratings is: 0.7075
# ****************************************************************************************
# familiar
# mean rating:  4.82427548618
# Correlation:  0.454466996122
# num of features:  78
# Spearman Correlation:  0.425051191377
# num of features:  78
# R^2 score:  0.201066252373
# num of features:  78
# MSE:  0.359395571087
# num of features:  78
# **************************Result of train and test**************************************
# number of features: 78
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.10
# Correlation between predicted ratings and actual ratings is: 0.3627
# Spearman Correlation between predicted ratings and actual ratings is: 0.3538
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.28
# Correlation between predicted ratings and actual ratings is: 0.5314
# Spearman Correlation between predicted ratings and actual ratings is: 0.4857
# ****************************************************************************************
# Correlation:  0.479262702135
# num of features:  81
# Spearman Correlation:  0.452714240214
# num of features:  81
# R^2 score:  0.229578757976
# num of features:  81
# MSE:  0.346569390863
# num of features:  81
# **************************Result of train and test**************************************
# number of features: 81
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.3992
# Spearman Correlation between predicted ratings and actual ratings is: 0.4001
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.28
# Correlation between predicted ratings and actual ratings is: 0.5338
# Spearman Correlation between predicted ratings and actual ratings is: 0.4902
# ****************************************************************************************
# friendly
# mean rating:  5.82372672542
# Correlation:  0.848129909553
# num of features:  72
# Spearman Correlation:  0.840160517791
# num of features:  20
# R^2 score:  0.718781965001
# num of features:  72
# MSE:  0.450392747346
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 72
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.67
# Correlation between predicted ratings and actual ratings is: 0.8187
# Spearman Correlation between predicted ratings and actual ratings is: 0.7665
#
# On training set:
# Residual sum of squares: 0.46
# Variance score is: 0.70
# Correlation between predicted ratings and actual ratings is: 0.8360
# Spearman Correlation between predicted ratings and actual ratings is: 0.8039
# ****************************************************************************************
# Correlation:  0.83705375869
# num of features:  387
# Spearman Correlation:  0.814122280292
# num of features:  317
# R^2 score:  0.694066362698
# num of features:  387
# MSE:  0.489976723613
# num of features:  387
# **************************Result of train and test**************************************
# number of features: 387
# On test set:
# Residual sum of squares: 0.46
# Variance score is: 0.67
# Correlation between predicted ratings and actual ratings is: 0.8198
# Spearman Correlation between predicted ratings and actual ratings is: 0.7696
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.80
# Correlation between predicted ratings and actual ratings is: 0.8942
# Spearman Correlation between predicted ratings and actual ratings is: 0.8468
# ****************************************************************************************
# happy
# mean rating:  5.76725519665
# Correlation:  0.868375391167
# num of features:  75
# Spearman Correlation:  0.873755300308
# num of features:  22
# R^2 score:  0.753453477417
# num of features:  75
# MSE:  0.506010289357
# num of features:  75
# **************************Result of train and test**************************************
# number of features: 75
# On test set:
# Residual sum of squares: 0.52
# Variance score is: 0.73
# Correlation between predicted ratings and actual ratings is: 0.8538
# Spearman Correlation between predicted ratings and actual ratings is: 0.8132
#
# On training set:
# Residual sum of squares: 0.47
# Variance score is: 0.75
# Correlation between predicted ratings and actual ratings is: 0.8667
# Spearman Correlation between predicted ratings and actual ratings is: 0.8461
# ****************************************************************************************
# Correlation:  0.856802743703
# num of features:  387
# Spearman Correlation:  0.843117264217
# num of features:  387
# R^2 score:  0.724356116613
# num of features:  387
# MSE:  0.565729500993
# num of features:  387
# **************************Result of train and test**************************************
# number of features: 387
# On test set:
# Residual sum of squares: 0.57
# Variance score is: 0.70
# Correlation between predicted ratings and actual ratings is: 0.8370
# Spearman Correlation between predicted ratings and actual ratings is: 0.8104
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.83
# Correlation between predicted ratings and actual ratings is: 0.9110
# Spearman Correlation between predicted ratings and actual ratings is: 0.8736
# ****************************************************************************************
# humble
# mean rating:  5.26263057771
# Correlation:  0.69136444697
# num of features:  181
# Spearman Correlation:  0.632810965724
# num of features:  87
# R^2 score:  0.47723217426
# num of features:  87
# MSE:  0.412102648494
# num of features:  87
# **************************Result of train and test**************************************
# number of features: 181
# On test set:
# ...
# num of features:  237
# MSE:  0.415747350376
# num of features:  237
# **************************Result of train and test**************************************
# number of features: 237
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.46
# Correlation between predicted ratings and actual ratings is: 0.6788
# Spearman Correlation between predicted ratings and actual ratings is: 0.6043
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.60
# Correlation between predicted ratings and actual ratings is: 0.7748
# Spearman Correlation between predicted ratings and actual ratings is: 0.6984
# ****************************************************************************************
# mean
# mean rating:  3.5064195034
# Correlation:  0.774470390603
# num of features:  84
# Spearman Correlation:  0.734721859002
# num of features:  20
# R^2 score:  0.598950582265
# num of features:  84
# MSE:  0.518428193485
# num of features:  84
# **************************Result of train and test**************************************
# number of features: 84
# On test set:
# Residual sum of squares: 0.59
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7462
# Spearman Correlation between predicted ratings and actual ratings is: 0.6596
#
# On training set:
# Residual sum of squares: 0.52
# Variance score is: 0.60
# Correlation between predicted ratings and actual ratings is: 0.7766
# Spearman Correlation between predicted ratings and actual ratings is: 0.7106
# ****************************************************************************************
# Correlation:  0.765126710778
# num of features:  387
# Spearman Correlation:  0.685035684781
# num of features:  117
# R^2 score:  0.584884383179
# num of features:  387
# MSE:  0.536611274818
# num of features:  387
# **************************Result of train and test**************************************
# number of features: 387
# On test set:
# Residual sum of squares: 0.58
# Variance score is: 0.57
# Correlation between predicted ratings and actual ratings is: 0.7530
# Spearman Correlation between predicted ratings and actual ratings is: 0.6594
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.71
# Correlation between predicted ratings and actual ratings is: 0.8460
# Spearman Correlation between predicted ratings and actual ratings is: 0.7756
# ****************************************************************************************
# memorable
# mean rating:  4.9651826126
# Correlation:  0.420838670723
# num of features:  61
# Spearman Correlation:  0.427469525513
# num of features:  61
# R^2 score:  0.175654315985
# num of features:  61
# MSE:  0.390357957589
# num of features:  61
# **************************Result of train and test**************************************
# number of features: 61
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.4006
# Spearman Correlation between predicted ratings and actual ratings is: 0.4059
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.22
# Correlation between predicted ratings and actual ratings is: 0.4750
# Spearman Correlation between predicted ratings and actual ratings is: 0.4544
# ****************************************************************************************
# Correlation:  0.524326736983
# num of features:  49
# Spearman Correlation:  0.524303784067
# num of features:  49
# R^2 score:  0.269138861397
# num of features:  49
# MSE:  0.346089591877
# num of features:  49
# **************************Result of train and test**************************************
# number of features: 49
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.22
# Correlation between predicted ratings and actual ratings is: 0.4734
# Spearman Correlation between predicted ratings and actual ratings is: 0.4636
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.28
# Correlation between predicted ratings and actual ratings is: 0.5307
# Spearman Correlation between predicted ratings and actual ratings is: 0.5151
# ****************************************************************************************
# normal
# mean rating:  6.00765605256
# Correlation:  0.623853417487
# num of features:  78
# Spearman Correlation:  0.594048420451
# num of features:  40
# R^2 score:  0.388948911484
# num of features:  78
# MSE:  0.375996918781
# num of features:  78
# **************************Result of train and test**************************************
# number of features: 78
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.34
# Correlation between predicted ratings and actual ratings is: 0.5896
# Spearman Correlation between predicted ratings and actual ratings is: 0.5572
#
# On training set:
# Residual sum of squares: 0.39
# Variance score is: 0.41
# Correlation between predicted ratings and actual ratings is: 0.6419
# Spearman Correlation between predicted ratings and actual ratings is: 0.5743
# ****************************************************************************************
# Correlation:  0.636984527207
# num of features:  87
# Spearman Correlation:  0.576355954282
# num of features:  84
# R^2 score:  0.403725888313
# num of features:  87
# MSE:  0.36690422938
# num of features:  87
# **************************Result of train and test**************************************
# number of features: 87
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6129
# Spearman Correlation between predicted ratings and actual ratings is: 0.5629
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6642
# Spearman Correlation between predicted ratings and actual ratings is: 0.6038
# ****************************************************************************************
# sociable
# mean rating:  5.82178301767
# Correlation:  0.777627982098
# num of features:  72
# Spearman Correlation:  0.778984711062
# num of features:  20
# R^2 score:  0.60405607239
# num of features:  72
# MSE:  0.485875944894
# num of features:  72
# **************************Result of train and test**************************************
# number of features: 72
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.63
# Correlation between predicted ratings and actual ratings is: 0.7930
# Spearman Correlation between predicted ratings and actual ratings is: 0.7598
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8027
# Spearman Correlation between predicted ratings and actual ratings is: 0.7651
# ****************************************************************************************
# Correlation:  0.777333912141
# num of features:  390
# Spearman Correlation:  0.750492423204
# num of features:  90
# R^2 score:  0.602555562105
# num of features:  387
# MSE:  0.487717270904
# num of features:  387
# **************************Result of train and test**************************************
# number of features: 390
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.63
# Correlation between predicted ratings and actual ratings is: 0.7920
# Spearman Correlation between predicted ratings and actual ratings is: 0.7512
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.76
# Correlation between predicted ratings and actual ratings is: 0.8741
# Spearman Correlation between predicted ratings and actual ratings is: 0.8236
# ****************************************************************************************
# typical
# mean rating:  5.28990378885
# Correlation:  0.413629191444
# num of features:  43
# Spearman Correlation:  0.391333829006
# num of features:  78
# R^2 score:  0.168058909131
# num of features:  43
# MSE:  0.374750320764
# num of features:  43
# **************************Result of train and test**************************************
# number of features: 43
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4430
# Spearman Correlation between predicted ratings and actual ratings is: 0.4373
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.21
# Correlation between predicted ratings and actual ratings is: 0.4573
# Spearman Correlation between predicted ratings and actual ratings is: 0.4246
# ****************************************************************************************
# Correlation:  0.478099089983
# num of features:  105
# Spearman Correlation:  0.447406722713
# num of features:  202
# R^2 score:  0.226111918377
# num of features:  105
# MSE:  0.348600171343
# num of features:  105
# **************************Result of train and test**************************************
# number of features: 105
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4379
# Spearman Correlation between predicted ratings and actual ratings is: 0.4269
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.28
# Correlation between predicted ratings and actual ratings is: 0.5271
# Spearman Correlation between predicted ratings and actual ratings is: 0.4919
# ****************************************************************************************
# uncertain
# mean rating:  3.71752754508
# Correlation:  0.623018071018
# num of features:  61
# Spearman Correlation:  0.634825522099
# num of features:  37
# R^2 score:  0.387183755639
# num of features:  61
# MSE:  0.393998537686
# num of features:  61
# **************************Result of train and test**************************************
# number of features: 61
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.35
# Correlation between predicted ratings and actual ratings is: 0.5947
# Spearman Correlation between predicted ratings and actual ratings is: 0.5846
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.45
# Correlation between predicted ratings and actual ratings is: 0.6730
# Spearman Correlation between predicted ratings and actual ratings is: 0.6478
# ****************************************************************************************
# Correlation:  0.619681498817
# num of features:  123
# Spearman Correlation:  0.601243378272
# num of features:  123
# R^2 score:  0.382778482634
# num of features:  123
# MSE:  0.396830824098
# num of features:  123
# **************************Result of train and test**************************************
# number of features: 123
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6096
# Spearman Correlation between predicted ratings and actual ratings is: 0.6095
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.49
# Correlation between predicted ratings and actual ratings is: 0.7041
# Spearman Correlation between predicted ratings and actual ratings is: 0.6766
# ****************************************************************************************
# uncommon
# mean rating:  3.8728980956
# Correlation:  0.377735857673
# num of features:  43
# Spearman Correlation:  0.372913523497
# num of features:  43
# R^2 score:  0.139022974096
# num of features:  43
# MSE:  0.374733348625
# num of features:  43
# **************************Result of train and test**************************************
# number of features: 43
# On test set:
# Residual sum of squares: 0.35
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4222
# Spearman Correlation between predicted ratings and actual ratings is: 0.4102
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4294
# Spearman Correlation between predicted ratings and actual ratings is: 0.4043
# ****************************************************************************************
# Correlation:  0.410249680541
# num of features:  37
# Spearman Correlation:  0.399942525516
# num of features:  37
# R^2 score:  0.166431207811
# num of features:  37
# MSE:  0.362804134615
# num of features:  37
# **************************Result of train and test**************************************
# number of features: 37
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.15
# Correlation between predicted ratings and actual ratings is: 0.3973
# Spearman Correlation between predicted ratings and actual ratings is: 0.3981
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.20
# Correlation between predicted ratings and actual ratings is: 0.4488
# Spearman Correlation between predicted ratings and actual ratings is: 0.4234
# ****************************************************************************************
# unintelligent
# mean rating:  3.41826166923
# Correlation:  0.588447389746
# num of features:  40
# Spearman Correlation:  0.524035755096
# num of features:  20
# R^2 score:  0.342856115571
# num of features:  40
# MSE:  0.390325245701
# num of features:  40
# **************************Result of train and test**************************************
# number of features: 40
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.4905
# Spearman Correlation between predicted ratings and actual ratings is: 0.4386
#
# On training set:
# Residual sum of squares: 0.43
# Variance score is: 0.30
# Correlation between predicted ratings and actual ratings is: 0.5486
# Spearman Correlation between predicted ratings and actual ratings is: 0.4749
# ****************************************************************************************
# Correlation:  0.603608248744
# num of features:  161
# Spearman Correlation:  0.505125419093
# num of features:  155
# R^2 score:  0.363118164769
# num of features:  161
# MSE:  0.378290150315
# num of features:  161
# **************************Result of train and test**************************************
# number of features: 161
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5682
# Spearman Correlation between predicted ratings and actual ratings is: 0.5119
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.6937
# Spearman Correlation between predicted ratings and actual ratings is: 0.6166
# ****************************************************************************************
# untrustworthy
# mean rating:  3.65110533077
# Correlation:  0.729863516147
# num of features:  75
# Spearman Correlation:  0.68467311723
# num of features:  20
# R^2 score:  0.529111692531
# num of features:  75
# MSE:  0.479448751147
# num of features:  75
# **************************Result of train and test**************************************
# number of features: 75
# On test set:
# Residual sum of squares: 0.56
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6636
# Spearman Correlation between predicted ratings and actual ratings is: 0.6012
#
# On training set:
# Residual sum of squares: 0.48
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7309
# Spearman Correlation between predicted ratings and actual ratings is: 0.6723
# ****************************************************************************************
# Correlation:  0.738451986946
# num of features:  393
# Spearman Correlation:  0.646506319856
# num of features:  402
# R^2 score:  0.544158768635
# num of features:  393
# MSE:  0.464128128971
# num of features:  393
# **************************Result of train and test**************************************
# number of features: 393
# On test set:
# Residual sum of squares: 0.50
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7092
# Spearman Correlation between predicted ratings and actual ratings is: 0.6191
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.68
# Correlation between predicted ratings and actual ratings is: 0.8275
# Spearman Correlation between predicted ratings and actual ratings is: 0.7580
# ****************************************************************************************

# %%
print valifeature_transf_vgg.shape
def writeFile(imList, rating,fName):
    text_file = open(fName, "w")
    for i in range(imList.shape[0]):
        d = homePath+'attractiveness_datamining/'+imList[i][6:]+' '+str(rating[i])+'\n'
        text_file.write(d)
    text_file.close()
modelList = []
optFeaNumList = []
radomImlist = np.asarray(imList)[randomInd]
testIm = radomImlist[:int(nSamples*testRatio)]
trainIm = radomImlist[int(nSamples*testRatio):]
print testIm.shape, trainIm.shape
for attr in ['attractive']:
    print attr
    #attr= social2Attr[9]
    mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
               if imList[i][31:] in socialMeasures.index]
    print len(mean_rating)
    mean_rating = map(float, mean_rating)
    mean_rating = np.array(mean_rating)
    radomRating = mean_rating[randomInd]
    testRating = radomRating[:int(nSamples*testRatio)]
    trainRating = radomRating[int(nSamples*testRatio):]
    valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
    print valiRating.shape
    trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]
    #writeFile(trainIm,trainRating,'../list/'+attr+'_train.txt')
    #writeFile(testIm,testRating,'../list/'+attr+'_test.txt')
#     writeFile(trainIm,trainRating,'../data_list/'+attr+'_train.txt')
#     writeFile(testIm,testRating,'../data_list/'+attr+'_test.txt')
    baseLine = mean_rating.mean()
    print 'mean rating: ', baseLine

    predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
    myModel,optFeaNum = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf_vgg, \
                                   testfeature_tansf_vgg,valifeature_transf_vgg,xVal = True,numTrain = 1,\
                                   pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                   plotPredActual = False,returnModel = True)
    modelList.append(myModel)
    optFeaNumList.append(optFeaNum)
# Out:
# (110, 892)
# (1103,) (1104,)
# attractive
# 2207
# (110,)
# mean rating:  4.93915489035
# Correlation:  0.768658635815
# num of features:  75
# Spearman Correlation:  0.756248954008
# num of features:  75
# R^2 score:  0.587703036589
# num of features:  87
# MSE:  0.65147353875
# num of features:  87
# **************************Result of train and test**************************************
# number of features: 75
# On test set:
# Residual sum of squares: 0.67
# Variance score is: 0.52
# Correlation between predicted ratings and actual ratings is: 0.7225
# Spearman Correlation between predicted ratings and actual ratings is: 0.7194
#
# On training set:
# Residual sum of squares: 0.58
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7825
# Spearman Correlation between predicted ratings and actual ratings is: 0.7823
# ****************************************************************************************
