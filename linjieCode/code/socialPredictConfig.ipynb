# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pandas as pd

from sklearn.decomposition import PCA as sklearnPCA
landMarks = pd.read_csv('../../processing/landmarking/mit/mitLandmarks.csv',index_col = 0)
imageList = list(set(landMarks.index.tolist()))
imageList.sort()
imList = [im[3:] for im in imageList]
print len(imList)
Dataset = 'mit'
MODEL = 'geometric'
homePath = '/home/lli-ms/'
allGeometric = np.loadtxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_totalFeatures.csv', delimiter=',')
print allGeometric.shape
# Out:
# 2207
# (2207, 4592)

# %%
# Make sure that caffe is on the python path:
caffe_root = homePath+'caffe/'
pretrained_model_root = homePath+'caffe/'

# run this line one time only!
import sys
caffePython = pretrained_model_root + 'python'
if caffePython not in sys.path:
    sys.path.insert(0, caffePython)

import caffe
# Load mean
mu = np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy')
mu = mu.mean(1).mean(1)  # average over pixels to obtain the mean (BGR) pixel values
print 'mean-subtracted values:', zip('BGR', mu)

# Load the trained net
MODEL = 'vgg16' #'caffeNet','vgg16','vggFace' or 'faceSNN'
    
if MODEL == 'vgg16':
    MODEL_FILE = caffe_root +'models/VGG16/VGG_ILSVRC_16_layers_deploy.prototxt'
    PRETRAINED_FILE = caffe_root + 'models/VGG16/VGG_ILSVRC_16_layers.caffemodel'
caffe.set_device(1)
caffe.set_mode_gpu()
if not os.path.isfile(PRETRAINED_FILE):
    print("No caffemodel!!!")
elif not os.path.isfile(MODEL_FILE):
    print("No MODEL !!!")
else:
    print "Defining the net!"
    net = caffe.Net(MODEL_FILE,
                PRETRAINED_FILE,
                caffe.TEST)
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
if MODEL != 'faceSNN':
    # subtract the dataset-mean value in each channel
    transformer.set_mean('data', mu)
for layer_name, param in net.params.iteritems():
    print layer_name + '\t' + str(param[0].data.shape), str(param[1].data.shape)
transformer.set_transpose('data', (2,0,1))
# the reference model operates on images in [0,255] range instead of [0,1]
transformer.set_raw_scale('data', 255) 
# the reference model has channels in BGR order instead of RGB
transformer.set_channel_swap('data', (2,1,0))
if MODEL == 'vgg16' or MODEL == 'vggFace':
    imgeReshape = [224,224]
    featureLayer = 'conv5_2' 
if 'fc' in featureLayer:
    featureNum = net.params[featureLayer][1].data.shape[0]
else:
    featureNum = net.blobs[featureLayer].data.flatten().shape[0]/net.blobs[featureLayer].data.shape[0]
print featureNum
features = np.zeros([len(imList),featureNum])
totalNum = 0

# print len(imList)
for img in imList:
    imgName = os.path.basename(img)
    if imgName.endswith(('.jpg','.png')):
        input_image = caffe.io.load_image(img)
        net.blobs['data'].reshape(1,3,imgeReshape[0],imgeReshape[1])
        net.blobs['data'].data[...] = transformer.preprocess('data', input_image)
        out = net.forward()
        feat = net.blobs[featureLayer].data
        if Dataset =='twin':
            img_type = int(imgName[7:-4])/perImNum
            img_index = int(imgName[7:-4])%perImNum
            #print 'img_type:',img_type
            if img_type in img_type_num.keys():
                img_type_num[img_type] = img_type_num[img_type] + 1
                img_type_list[img_type][img_index] = img
            else:
                img_type_num[img_type] = 0
                img_type_list[img_type] = [None]*perImNum
                img_type_index[img_type] = type_index
                type_index +=1
            #print 'img_type_index:',img_type_index[img_type]
            features[img_type_index[img_type],img_type_num[img_type]] = feat.flatten()
        else:
            # need to be further revised!
            features[totalNum] = feat.flatten()
            #print features[totalNum]
        totalNum +=1
    else:
        print img
#print len(img_type_num)
print totalNum
vggFeature = features
# Out:
# mean-subtracted values: [('B', 104.0069879317889), ('G', 116.66876761696767), ('R', 122.6789143406786)]
# Defining the net!
# conv1_1	(64, 3, 3, 3) (64,)
# conv1_2	(64, 64, 3, 3) (64,)
# conv2_1	(128, 64, 3, 3) (128,)
# conv2_2	(128, 128, 3, 3) (128,)
# conv3_1	(256, 128, 3, 3) (256,)
# conv3_2	(256, 256, 3, 3) (256,)
# conv3_3	(256, 256, 3, 3) (256,)
# conv4_1	(512, 256, 3, 3) (512,)
# conv4_2	(512, 512, 3, 3) (512,)
# conv4_3	(512, 512, 3, 3) (512,)
# conv5_1	(512, 512, 3, 3) (512,)
# conv5_2	(512, 512, 3, 3) (512,)
# conv5_3	(512, 512, 3, 3) (512,)
# fc6	(4096, 25088) (4096,)
# fc7	(4096, 4096) (4096,)
# fc8	(1000, 4096) (1000,)
# 100352
# 2207

# %%
print vggFeature.shape
# Out:
# (2207, 100352)

# %%
for j in range(1,2): 
    import random
    featureMat = allGeometric
    randomInd = range(featureMat.shape[0])
    random.shuffle(randomInd)
    print max(randomInd)
    featureMat = featureMat[randomInd,:]
    nSamples = featureMat.shape[0]
    testRatio = 0.2
    valiRatio = 0.2
    testFeatures = featureMat[:int(nSamples*testRatio),:]
    trainFeatures = featureMat[int(nSamples*testRatio):,:]
    valiFeatures = featureMat[-int(trainFeatures.shape[0]*valiRatio):,:]
    trainFeatures = trainFeatures[:-int(trainFeatures.shape[0]*valiRatio),:]
    print valiFeatures.shape, trainFeatures.shape, testFeatures.shape
    explained_variance = 1000
    sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
    trainfeature_transf = sklearn_pca.fit_transform(trainFeatures)
    print 'The number of PCs needed to retain %.3f variance is %d.' \
          % (explained_variance, trainfeature_transf.shape[1])
    print sklearn_pca.components_.shape
    print trainfeature_transf.shape
    testfeature_tansf = sklearn_pca.transform(testFeatures)
    print testfeature_tansf.shape
    valifeature_transf = sklearn_pca.transform(valiFeatures)

    radomImlist = np.asarray(imList)[randomInd]

    vggfeatureMat = vggFeature[randomInd,:]
    nSamples = vggfeatureMat.shape[0]
    testFeatures_vgg = vggfeatureMat[:int(nSamples*testRatio),:]
    trainFeatures_vgg = vggfeatureMat[int(nSamples*testRatio):,:]
    valiFeatures_vgg = vggfeatureMat[-int(trainFeatures_vgg.shape[0]*valiRatio):,:]
    trainFeatures_vgg = trainFeatures_vgg[:-int(trainFeatures_vgg.shape[0]*valiRatio),:]
    print valiFeatures_vgg.shape, trainFeatures_vgg.shape, testFeatures_vgg.shape

    explained_variance = 0.99
    sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
    trainfeature_transf_vgg = sklearn_pca.fit_transform(trainFeatures_vgg)
    print 'The number of PCs needed to retain %.3f variance is %d.' \
          % (explained_variance, trainfeature_transf_vgg.shape[1])
    print sklearn_pca.components_.shape
    print trainfeature_transf_vgg.shape
    testfeature_tansf_vgg = sklearn_pca.transform(testFeatures_vgg)
    print testfeature_tansf_vgg.shape
    valifeature_transf_vgg = sklearn_pca.transform(valiFeatures_vgg)
    print valifeature_transf_vgg.shape

    modelList = []
    optFeaNumList = []
    modelList_vgg = []
    optFeaNumList_vgg = []
    import sys
    import pandas as pd
    socialMeasures = '../Result/mit/socialMeasures.csv'
    socialMeasures = pd.read_csv(socialMeasures,index_col = 0)
    socialAttr = socialMeasures.columns.tolist()
    delElement = ['subage.1', 'submale.1', 'subrace.1','subage', 'submale',\
                  'subrace','catch', 'catchAns','catch.1','catchAns.1']
    social2Attr = [x for x in socialAttr if x not in delElement]

    PkgPath = homePath+'attractiveness_datamining/linjieCode/code'
#     fName = "../Result/Config_vs_VGG16/regression_result_"+str(j)+".csv"
#     text_file = open(fName, "w")
#     d = 'Social Attributes, geometric_test, vgg16_test, geometric_train, vgg16_train, geometric_feature_num, vgg16_FeatureNum'+'\n'
#     text_file.write(d)

    if PkgPath not in sys.path:
        sys.path.insert(0, PkgPath)
    #print sys.path
    from xVal_train_test import Train_Test

    import sklearn
    import numpy as np
    fullRating = np.zeros((2207,40))
    for attr in social2Attr:
        print attr
        #attr= social2Attr[9]，
        mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
                   if imList[i][31:] in socialMeasures.index]
        mean_rating = map(float, mean_rating)
        mean_rating = np.array(mean_rating)
        radomRating = mean_rating[randomInd]
        testRating = radomRating[:int(nSamples*testRatio)]
        trainRating = radomRating[int(nSamples*testRatio):]
        valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
        trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]

        baseLine = mean_rating.mean()
        print 'mean rating: ', baseLine

#         predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
#         myModel,optFeaNum,testC,trainC = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf, \
#                                        testfeature_tansf,valifeature_transf,xVal = True,numTrain = 1,\
#                                        pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
#                                        plotPredActual = False,returnModel = True,returnValTrain = True)
        predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
        myModel_vgg,optFeaNum_vgg,testC_vgg, trainC_vgg = Train_Test(trainSubRating,testRating,valiRating,\
                                        trainfeature_transf_vgg, \
                                       testfeature_tansf_vgg,valifeature_transf_vgg,xVal = True,numTrain = 1,\
                                       pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                       plotPredActual = False,returnModel = True,returnValTrain = True)
        modelList.append(myModel)
        optFeaNumList.append(optFeaNum)
        modelList_vgg.append(myModel_vgg)
        optFeaNumList_vgg.append(optFeaNum_vgg)
        totalRating = np.concatenate([trainSubRating,valiRating,testRating])
        print totalRating.shape
        totalFeature = np.concatenate([trainfeature_transf_vgg[:,:optFeaNum_vgg],valifeature_transf_vgg[:,:optFeaNum_vgg],\
                                       testfeature_tansf_vgg[:,:optFeaNum_vgg]])
        print totalFeature.shape
        fullRating[:,social2Attr.index(attr)] = myModel_vgg.predict(totalFeature)
#         d = attr+', '+ str(testC)+', '+str(testC_vgg)+', '+str(trainC)+', '+str(trainC_vgg)+', '+str(optFeaNum)+', '+str(optFeaNum_vgg)+'\n'
#         text_file.write(d)
#     text_file.close()
# Out:
# 2206
# (353, 4592) (1413, 4592) (441, 4592)
# The number of PCs needed to retain 1000.000 variance is 1000.
# (1000, 4592)
# (1413, 1000)
# (441, 1000)
# (353, 100352) (1413, 100352) (441, 100352)
# The number of PCs needed to retain 0.990 variance is 1244.
# (1244, 100352)
# (1413, 1244)
# (441, 1244)
# (353, 1244)
# atypical
# mean rating:  4.08446414454
# Correlation:  0.442099310232
# num of features:  363
# Spearman Correlation:  0.457348341359
# num of features:  363
# R^2 score:  0.183780074729
# num of features:  293
# MSE:  0.405291586765
# num of features:  293
# **************************Result of train and test**************************************
# number of features: 363
# On test set:
# Residual sum of squares: 0.41
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.3340
# Spearman Correlation between predicted ratings and actual ratings is: 0.3272
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.46
# Correlation between predicted ratings and actual ratings is: 0.6772
# Spearman Correlation between predicted ratings and actual ratings is: 0.6597
# ****************************************************************************************
# (2207,)
# (2207, 363)
# boring
# mean rating:  4.28997636656
# Correlation:  0.613448064439
# num of features:  247
# Spearman Correlation:  0.605879062552
# num of features:  121
# R^2 score:  0.374375465892
# num of features:  247
# MSE:  0.438120346165
# num of features:  247
# **************************Result of train and test**************************************
# number of features: 247
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.29
# Correlation between predicted ratings and actual ratings is: 0.5452
# Spearman Correlation between predicted ratings and actual ratings is: 0.5431
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7301
# Spearman Correlation between predicted ratings and actual ratings is: 0.7245
# ****************************************************************************************
# (2207,)
# (2207, 247)
# calm
# mean rating:  5.80624816221
# Correlation:  0.513247271602
# num of features:  358
# Spearman Correlation:  0.467364588988
# num of features:  116
# R^2 score:  0.258362010621
# num of features:  127
# MSE:  0.404694258268
# num of features:  127
# **************************Result of train and test**************************************
# number of features: 358
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.5055
# Spearman Correlation between predicted ratings and actual ratings is: 0.4251
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7115
# Spearman Correlation between predicted ratings and actual ratings is: 0.6337
# ****************************************************************************************
# (2207,)
# (2207, 358)
# cold
# mean rating:  3.71738235795
# Correlation:  0.80639678161
# num of features:  318
# Spearman Correlation:  0.791614475736
# num of features:  379
# R^2 score:  0.6492827408
# num of features:  318
# MSE:  0.553791396616
# num of features:  318
# **************************Result of train and test**************************************
# number of features: 318
# On test set:
# Residual sum of squares: 0.62
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7661
# Spearman Correlation between predicted ratings and actual ratings is: 0.7295
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.75
# Correlation between predicted ratings and actual ratings is: 0.8692
# Spearman Correlation between predicted ratings and actual ratings is: 0.8242
# ****************************************************************************************
# (2207,)
# (2207, 318)
# common
# mean rating:  5.32550588808
# Correlation:  0.375294915851
# num of features:  96
# Spearman Correlation:  0.397710243201
# num of features:  96
# R^2 score:  0.137693571289
# num of features:  96
# MSE:  0.350809001164
# num of features:  96
# **************************Result of train and test**************************************
# number of features: 96
# On test set:
# Residual sum of squares: 0.34
# Variance score is: 0.21
# Correlation between predicted ratings and actual ratings is: 0.4658
# Spearman Correlation between predicted ratings and actual ratings is: 0.4403
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.4976
# Spearman Correlation between predicted ratings and actual ratings is: 0.4672
# ****************************************************************************************
# (2207,)
# (2207, 96)
# confident
# mean rating:  5.92335749751
# Correlation:  0.57794255082
# num of features:  81
# Spearman Correlation:  0.537307883429
# num of features:  51
# R^2 score:  0.333536613796
# num of features:  81
# MSE:  0.459966380066
# num of features:  81
# **************************Result of train and test**************************************
# number of features: 81
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6095
# Spearman Correlation between predicted ratings and actual ratings is: 0.5684
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.45
# Correlation between predicted ratings and actual ratings is: 0.6711
# Spearman Correlation between predicted ratings and actual ratings is: 0.6325
# ****************************************************************************************
# (2207,)
# (2207, 81)
# egotistic
# mean rating:  4.07662558269
# Correlation:  0.642902492621
# num of features:  449
# Spearman Correlation:  0.651910464315
# num of features:  449
# R^2 score:  0.403254966784
# num of features:  449
# MSE:  0.501220272179
# num of features:  449
# **************************Result of train and test**************************************
# number of features: 449
# On test set:
# Residual sum of squares: 0.53
# Variance score is: 0.39
# Correlation between predicted ratings and actual ratings is: 0.6326
# Spearman Correlation between predicted ratings and actual ratings is: 0.6293
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.65
# Correlation between predicted ratings and actual ratings is: 0.8059
# Spearman Correlation between predicted ratings and actual ratings is: 0.8012
# ****************************************************************************************
# (2207,)
# (2207, 449)
# emotUnstable
# mean rating:  3.63361718849
# Correlation:  0.648653857427
# num of features:  293
# Spearman Correlation:  0.565629603325
# num of features:  363
# R^2 score:  0.419708514686
# num of features:  293
# MSE:  0.502098870345
# num of features:  293
# **************************Result of train and test**************************************
# number of features: 293
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6134
# Spearman Correlation between predicted ratings and actual ratings is: 0.5352
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7712
# Spearman Correlation between predicted ratings and actual ratings is: 0.6957
# ****************************************************************************************
# (2207,)
# (2207, 293)
# forgettable
# mean rating:  4.54602870412
# Correlation:  0.436911211183
# num of features:  121
# Spearman Correlation:  0.43886917108
# num of features:  51
# R^2 score:  0.185784619128
# num of features:  51
# MSE:  0.447596572103
# num of features:  51
# **************************Result of train and test**************************************
# number of features: 121
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.23
# Correlation between predicted ratings and actual ratings is: 0.4870
# Spearman Correlation between predicted ratings and actual ratings is: 0.4601
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6092
# Spearman Correlation between predicted ratings and actual ratings is: 0.5969
# ****************************************************************************************
# (2207,)
# (2207, 121)
# intelligent
# mean rating:  5.83579811962
# Correlation:  0.611753736426
# num of features:  343
# Spearman Correlation:  0.554165012506
# num of features:  303
# R^2 score:  0.368141717105
# num of features:  343
# MSE:  0.334033029284
# num of features:  343
# **************************Result of train and test**************************************
# number of features: 343
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5747
# Spearman Correlation between predicted ratings and actual ratings is: 0.5209
#
# On training set:
# Residual sum of squares: 0.22
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7818
# Spearman Correlation between predicted ratings and actual ratings is: 0.7212
# ****************************************************************************************
# (2207,)
# (2207, 343)
# introverted
# mean rating:  3.9278672696
# Correlation:  0.643391447271
# num of features:  66
# Spearman Correlation:  0.643526457872
# num of features:  51
# R^2 score:  0.409225355401
# num of features:  66
# MSE:  0.570529144943
# num of features:  66
# **************************Result of train and test**************************************
# number of features: 66
# On test set:
# Residual sum of squares: 0.49
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6208
# Spearman Correlation between predicted ratings and actual ratings is: 0.6130
#
# On training set:
# Residual sum of squares: 0.44
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7064
# Spearman Correlation between predicted ratings and actual ratings is: 0.6986
# ****************************************************************************************
# (2207,)
# (2207, 66)
# kind
# mean rating:  5.67934660807
# Correlation:  0.796088512479
# num of features:  429
# Spearman Correlation:  0.759307982106
# num of features:  409
# R^2 score:  0.633338499667
# num of features:  429
# MSE:  0.42418671166
# num of features:  429
# **************************Result of train and test**************************************
# number of features: 429
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.58
# Correlation between predicted ratings and actual ratings is: 0.7635
# Spearman Correlation between predicted ratings and actual ratings is: 0.7272
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.79
# Correlation between predicted ratings and actual ratings is: 0.8884
# Spearman Correlation between predicted ratings and actual ratings is: 0.8489
# ****************************************************************************************
# (2207,)
# (2207, 429)
# responsible
# mean rating:  5.86209432941
# Correlation:  0.681934603096
# num of features:  127
# Spearman Correlation:  0.607235002544
# num of features:  424
# R^2 score:  0.464166705534
# num of features:  127
# MSE:  0.437844485759
# num of features:  127
# **************************Result of train and test**************************************
# number of features: 127
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.51
# Correlation between predicted ratings and actual ratings is: 0.7195
# Spearman Correlation between predicted ratings and actual ratings is: 0.6357
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7532
# Spearman Correlation between predicted ratings and actual ratings is: 0.6582
# ****************************************************************************************
# (2207,)
# (2207, 127)
# trustworthy
# mean rating:  5.60918211192
# Correlation:  0.724351248755
# num of features:  323
# Spearman Correlation:  0.698315064159
# num of features:  313
# R^2 score:  0.521996993421
# num of features:  323
# MSE:  0.416149207336
# num of features:  323
# **************************Result of train and test**************************************
# number of features: 323
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7096
# Spearman Correlation between predicted ratings and actual ratings is: 0.6683
#
# On training set:
# Residual sum of squares: 0.27
# Variance score is: 0.69
# Correlation between predicted ratings and actual ratings is: 0.8349
# Spearman Correlation between predicted ratings and actual ratings is: 0.7668
# ****************************************************************************************
# (2207,)
# (2207, 323)
# unattractive
# mean rating:  4.26128344314
# Correlation:  0.700470723412
# num of features:  101
# Spearman Correlation:  0.695853989936
# num of features:  96
# R^2 score:  0.490564279191
# num of features:  101
# MSE:  0.724989736718
# num of features:  101
# **************************Result of train and test**************************************
# number of features: 101
# On test set:
# Residual sum of squares: 0.71
# Variance score is: 0.43
# Correlation between predicted ratings and actual ratings is: 0.6577
# Spearman Correlation between predicted ratings and actual ratings is: 0.6434
#
# On training set:
# Residual sum of squares: 0.55
# Variance score is: 0.58
# Correlation between predicted ratings and actual ratings is: 0.7615
# Spearman Correlation between predicted ratings and actual ratings is: 0.7566
# ****************************************************************************************
# (2207,)
# (2207, 101)
# unemotional
# mean rating:  3.81009778659
# Correlation:  0.764679324174
# num of features:  263
# Spearman Correlation:  0.750149884193
# num of features:  258
# R^2 score:  0.584325726469
# num of features:  263
# MSE:  0.400453068005
# num of features:  263
# **************************Result of train and test**************************************
# number of features: 263
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7129
# Spearman Correlation between predicted ratings and actual ratings is: 0.7072
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.69
# Correlation between predicted ratings and actual ratings is: 0.8333
# Spearman Correlation between predicted ratings and actual ratings is: 0.8086
# ****************************************************************************************
# (2207,)
# (2207, 263)
# unfamiliar
# mean rating:  4.39983614454
# Correlation:  0.465382758739
# num of features:  56
# Spearman Correlation:  0.473793918363
# num of features:  86
# R^2 score:  0.215537612988
# num of features:  76
# MSE:  0.420341130826
# num of features:  76
# **************************Result of train and test**************************************
# number of features: 56
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4139
# Spearman Correlation between predicted ratings and actual ratings is: 0.3868
#
# On training set:
# Residual sum of squares: 0.35
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.4908
# Spearman Correlation between predicted ratings and actual ratings is: 0.4711
# ****************************************************************************************
# (2207,)
# (2207, 56)
# unfriendly
# mean rating:  3.61636378885
# Correlation:  0.800289876805
# num of features:  409
# Spearman Correlation:  0.752610144981
# num of features:  414
# R^2 score:  0.640126786447
# num of features:  409
# MSE:  0.564146305262
# num of features:  409
# **************************Result of train and test**************************************
# number of features: 409
# On test set:
# Residual sum of squares: 0.64
# Variance score is: 0.54
# Correlation between predicted ratings and actual ratings is: 0.7416
# Spearman Correlation between predicted ratings and actual ratings is: 0.6940
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.78
# Correlation between predicted ratings and actual ratings is: 0.8834
# Spearman Correlation between predicted ratings and actual ratings is: 0.8278
# ****************************************************************************************
# (2207,)
# (2207, 409)
# unhappy
# mean rating:  3.60946439556
# Correlation:  0.805310400667
# num of features:  379
# Spearman Correlation:  0.753898858611
# num of features:  409
# R^2 score:  0.648458435532
# num of features:  379
# MSE:  0.615364974049
# num of features:  379
# **************************Result of train and test**************************************
# number of features: 379
# On test set:
# Residual sum of squares: 0.57
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7871
# Spearman Correlation between predicted ratings and actual ratings is: 0.7463
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.79
# Correlation between predicted ratings and actual ratings is: 0.8885
# Spearman Correlation between predicted ratings and actual ratings is: 0.8308
# ****************************************************************************************
# (2207,)
# (2207, 379)
# weird
# mean rating:  3.63519592705
# Correlation:  0.553350376429
# num of features:  101
# Spearman Correlation:  0.55349169381
# num of features:  253
# R^2 score:  0.303264223818
# num of features:  101
# MSE:  0.6788610615
# num of features:  101
# **************************Result of train and test**************************************
# number of features: 101
# On test set:
# Residual sum of squares: 0.68
# Variance score is: 0.30
# Correlation between predicted ratings and actual ratings is: 0.5460
# Spearman Correlation between predicted ratings and actual ratings is: 0.5179
#
# On training set:
# Residual sum of squares: 0.53
# Variance score is: 0.42
# Correlation between predicted ratings and actual ratings is: 0.6501
# Spearman Correlation between predicted ratings and actual ratings is: 0.6248
# ****************************************************************************************
# (2207,)
# (2207, 101)
# aggressive
# mean rating:  3.68722056094
# Correlation:  0.756217730231
# num of features:  323
# Spearman Correlation:  0.699828879778
# num of features:  137
# R^2 score:  0.570057866123
# num of features:  323
# MSE:  0.568450541422
# num of features:  323
# **************************Result of train and test**************************************
# number of features: 323
# On test set:
# Residual sum of squares: 0.67
# Variance score is: 0.47
# Correlation between predicted ratings and actual ratings is: 0.6899
# Spearman Correlation between predicted ratings and actual ratings is: 0.6421
#
# On training set:
# Residual sum of squares: 0.41
# Variance score is: 0.67
# Correlation between predicted ratings and actual ratings is: 0.8228
# Spearman Correlation between predicted ratings and actual ratings is: 0.7539
# ****************************************************************************************
# (2207,)
# (2207, 323)
# attractive
# mean rating:  4.93915489035
# Correlation:  0.766777271464
# num of features:  308
# Spearman Correlation:  0.757095729658
# num of features:  116
# R^2 score:  0.587399655801
# num of features:  308
# MSE:  0.648954085433
# num of features:  308
# **************************Result of train and test**************************************
# number of features: 308
# On test set:
# Residual sum of squares: 0.61
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7465
# Spearman Correlation between predicted ratings and actual ratings is: 0.7428
#
# On training set:
# Residual sum of squares: 0.40
# Variance score is: 0.72
# Correlation between predicted ratings and actual ratings is: 0.8504
# Spearman Correlation between predicted ratings and actual ratings is: 0.8478
# ****************************************************************************************
# (2207,)
# (2207, 308)
# caring
# mean rating:  5.54517054055
# Correlation:  0.800018940535
# num of features:  318
# Spearman Correlation:  0.765923279847
# num of features:  358
# R^2 score:  0.639469192659
# num of features:  318
# MSE:  0.412577593672
# num of features:  318
# **************************Result of train and test**************************************
# number of features: 318
# On test set:
# Residual sum of squares: 0.50
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7340
# Spearman Correlation between predicted ratings and actual ratings is: 0.7064
#
# On training set:
# Residual sum of squares: 0.28
# Variance score is: 0.76
# Correlation between predicted ratings and actual ratings is: 0.8719
# Spearman Correlation between predicted ratings and actual ratings is: 0.8312
# ****************************************************************************************
# (2207,)
# (2207, 318)
# emotStable
# mean rating:  5.72743004531
# Correlation:  0.704919697855
# num of features:  379
# Spearman Correlation:  0.631772502
# num of features:  127
# R^2 score:  0.496596079385
# num of features:  379
# MSE:  0.388698983745
# num of features:  379
# **************************Result of train and test**************************************
# number of features: 379
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6274
# Spearman Correlation between predicted ratings and actual ratings is: 0.5622
#
# On training set:
# Residual sum of squares: 0.25
# Variance score is: 0.65
# Correlation between predicted ratings and actual ratings is: 0.8083
# Spearman Correlation between predicted ratings and actual ratings is: 0.7257
# ****************************************************************************************
# (2207,)
# (2207, 379)
# emotional
# mean rating:  4.8545259343
# Correlation:  0.609860235099
# num of features:  121
# Spearman Correlation:  0.626457561394
# num of features:  46
# R^2 score:  0.366935612952
# num of features:  121
# MSE:  0.335695264152
# num of features:  121
# **************************Result of train and test**************************************
# number of features: 121
# On test set:
# Residual sum of squares: 0.30
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5759
# Spearman Correlation between predicted ratings and actual ratings is: 0.5767
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.6966
# Spearman Correlation between predicted ratings and actual ratings is: 0.7076
# ****************************************************************************************
# (2207,)
# (2207, 121)
# familiar
# mean rating:  4.82427548618
# Correlation:  0.410201552932
# num of features:  86
# Spearman Correlation:  0.394337953556
# num of features:  86
# R^2 score:  0.156870524405
# num of features:  86
# MSE:  0.405781878807
# num of features:  86
# **************************Result of train and test**************************************
# number of features: 86
# On test set:
# Residual sum of squares: 0.41
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.4015
# Spearman Correlation between predicted ratings and actual ratings is: 0.3986
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.31
# Correlation between predicted ratings and actual ratings is: 0.5612
# Spearman Correlation between predicted ratings and actual ratings is: 0.5166
# ****************************************************************************************
# (2207,)
# (2207, 86)
# friendly
# mean rating:  5.82372672542
# Correlation:  0.834639525355
# num of features:  449
# Spearman Correlation:  0.816703493866
# num of features:  96
# R^2 score:  0.696526072196
# num of features:  449
# MSE:  0.466097871399
# num of features:  449
# **************************Result of train and test**************************************
# number of features: 449
# On test set:
# Residual sum of squares: 0.54
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7844
# Spearman Correlation between predicted ratings and actual ratings is: 0.7500
#
# On training set:
# Residual sum of squares: 0.28
# Variance score is: 0.82
# Correlation between predicted ratings and actual ratings is: 0.9053
# Spearman Correlation between predicted ratings and actual ratings is: 0.8597
# ****************************************************************************************
# (2207,)
# (2207, 449)
# happy
# mean rating:  5.76725519665
# Correlation:  0.861614967115
# num of features:  409
# Spearman Correlation:  0.839723194144
# num of features:  409
# R^2 score:  0.741262773503
# num of features:  409
# MSE:  0.519703306426
# num of features:  409
# **************************Result of train and test**************************************
# number of features: 409
# On test set:
# Residual sum of squares: 0.61
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8033
# Spearman Correlation between predicted ratings and actual ratings is: 0.7844
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.84
# Correlation between predicted ratings and actual ratings is: 0.9159
# Spearman Correlation between predicted ratings and actual ratings is: 0.8815
# ****************************************************************************************
# (2207,)
# (2207, 409)
# humble
# mean rating:  5.26263057771
# Correlation:  0.659314325379
# num of features:  404
# Spearman Correlation:  0.629380930701
# num of features:  444
# R^2 score:  0.432786261946
# num of features:  404
# MSE:  0.429656266211
# num of features:  404
# **************************Result of train and test**************************************
# number of features: 404
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.36
# Correlation between predicted ratings and actual ratings is: 0.6046
# Spearman Correlation between predicted ratings and actual ratings is: 0.5858
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.62
# Correlation between predicted ratings and actual ratings is: 0.7913
# Spearman Correlation between predicted ratings and actual ratings is: 0.7515
# ****************************************************************************************
# (2207,)
# (2207, 404)
# interesting
# mean rating:  5.19165798958
# Correlation:  0.624473378611
# num of features:  121
# Spearman Correlation:  0.621541052904
# num of features:  121
# R^2 score:  0.384640030902
# num of features:  137
# MSE:  0.400745594107
# num of features:  137
# **************************Result of train and test**************************************
# number of features: 121
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.5129
# Spearman Correlation between predicted ratings and actual ratings is: 0.4879
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.46
# Correlation between predicted ratings and actual ratings is: 0.6786
# Spearman Correlation between predicted ratings and actual ratings is: 0.6487
# ****************************************************************************************
# (2207,)
# (2207, 121)
# irresponsible
# mean rating:  3.49263116855
# Correlation:  0.691143358347
# num of features:  353
# Spearman Correlation:  0.616899652851
# num of features:  358
# R^2 score:  0.476543797462
# num of features:  353
# MSE:  0.414867114509
# num of features:  353
# **************************Result of train and test**************************************
# number of features: 353
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6368
# Spearman Correlation between predicted ratings and actual ratings is: 0.5625
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.8048
# Spearman Correlation between predicted ratings and actual ratings is: 0.7200
# ****************************************************************************************
# (2207,)
# (2207, 353)
# mean
# mean rating:  3.5064195034
# Correlation:  0.76146526714
# num of features:  293
# Spearman Correlation:  0.704554325495
# num of features:  439
# R^2 score:  0.577277477564
# num of features:  293
# MSE:  0.561660678308
# num of features:  293
# **************************Result of train and test**************************************
# number of features: 293
# On test set:
# Residual sum of squares: 0.69
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6728
# Spearman Correlation between predicted ratings and actual ratings is: 0.6134
#
# On training set:
# Residual sum of squares: 0.40
# Variance score is: 0.70
# Correlation between predicted ratings and actual ratings is: 0.8381
# Spearman Correlation between predicted ratings and actual ratings is: 0.7585
# ****************************************************************************************
# (2207,)
# (2207, 293)
# memorable
# mean rating:  4.9651826126
# Correlation:  0.465709507549
# num of features:  137
# Spearman Correlation:  0.446670034444
# num of features:  247
# R^2 score:  0.213594743411
# num of features:  137
# MSE:  0.405222146129
# num of features:  137
# **************************Result of train and test**************************************
# number of features: 137
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.21
# Correlation between predicted ratings and actual ratings is: 0.4720
# Spearman Correlation between predicted ratings and actual ratings is: 0.4572
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6100
# Spearman Correlation between predicted ratings and actual ratings is: 0.5828
# ****************************************************************************************
# (2207,)
# (2207, 137)
# normal
# mean rating:  6.00765605256
# Correlation:  0.626833111197
# num of features:  308
# Spearman Correlation:  0.595547627326
# num of features:  308
# R^2 score:  0.386002661045
# num of features:  308
# MSE:  0.403681413992
# num of features:  308
# **************************Result of train and test**************************************
# number of features: 308
# On test set:
# Residual sum of squares: 0.50
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.5194
# Spearman Correlation between predicted ratings and actual ratings is: 0.4656
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7708
# Spearman Correlation between predicted ratings and actual ratings is: 0.6995
# ****************************************************************************************
# (2207,)
# (2207, 308)
# sociable
# mean rating:  5.82178301767
# Correlation:  0.800508404474
# num of features:  253
# Spearman Correlation:  0.783794626039
# num of features:  46
# R^2 score:  0.640263397183
# num of features:  253
# MSE:  0.471122797896
# num of features:  253
# **************************Result of train and test**************************************
# number of features: 253
# On test set:
# Residual sum of squares: 0.53
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7154
# Spearman Correlation between predicted ratings and actual ratings is: 0.6721
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.73
# Correlation between predicted ratings and actual ratings is: 0.8545
# Spearman Correlation between predicted ratings and actual ratings is: 0.8088
# ****************************************************************************************
# (2207,)
# (2207, 253)
# typical
# mean rating:  5.28990378885
# Correlation:  0.472385018924
# num of features:  61
# Spearman Correlation:  0.455402836625
# num of features:  61
# R^2 score:  0.222497605958
# num of features:  61
# MSE:  0.342266536847
# num of features:  61
# **************************Result of train and test**************************************
# number of features: 61
# On test set:
# Residual sum of squares: 0.35
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4372
# Spearman Correlation between predicted ratings and actual ratings is: 0.4096
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.25
# Correlation between predicted ratings and actual ratings is: 0.5016
# Spearman Correlation between predicted ratings and actual ratings is: 0.4670
# ****************************************************************************************
# (2207,)
# (2207, 61)
# uncertain
# mean rating:  3.71752754508
# Correlation:  0.62572140073
# num of features:  51
# Spearman Correlation:  0.622772779617
# num of features:  41
# R^2 score:  0.383208535603
# num of features:  197
# MSE:  0.474569559073
# num of features:  197
# **************************Result of train and test**************************************
# number of features: 51
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.36
# Correlation between predicted ratings and actual ratings is: 0.5992
# Spearman Correlation between predicted ratings and actual ratings is: 0.5914
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.43
# Correlation between predicted ratings and actual ratings is: 0.6576
# Spearman Correlation between predicted ratings and actual ratings is: 0.6327
# ****************************************************************************************
# (2207,)
# (2207, 51)
# uncommon
# mean rating:  3.8728980956
# Correlation:  0.40628113047
# num of features:  61
# Spearman Correlation:  0.410794112575
# num of features:  288
# R^2 score:  0.163644193492
# num of features:  61
# MSE:  0.366906114591
# num of features:  61
# **************************Result of train and test**************************************
# number of features: 61
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.14
# Correlation between predicted ratings and actual ratings is: 0.3751
# Spearman Correlation between predicted ratings and actual ratings is: 0.3603
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.24
# Correlation between predicted ratings and actual ratings is: 0.4904
# Spearman Correlation between predicted ratings and actual ratings is: 0.4688
# ****************************************************************************************
# (2207,)
# (2207, 61)
# unintelligent
# mean rating:  3.41826166923
# Correlation:  0.618670040234
# num of features:  187
# Spearman Correlation:  0.538927676897
# num of features:  187
# R^2 score:  0.379936406409
# num of features:  187
# MSE:  0.378954591657
# num of features:  187
# **************************Result of train and test**************************************
# number of features: 187
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5665
# Spearman Correlation between predicted ratings and actual ratings is: 0.5054
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.6907
# Spearman Correlation between predicted ratings and actual ratings is: 0.6137
# ****************************************************************************************
# (2207,)
# (2207, 187)
# untrustworthy
# mean rating:  3.65110533077
# Correlation:  0.732432435169
# num of features:  409
# Spearman Correlation:  0.680455370084
# num of features:  414
# R^2 score:  0.536066981394
# num of features:  409
# MSE:  0.496957680558
# num of features:  409
# **************************Result of train and test**************************************
# number of features: 409
# On test set:
# Residual sum of squares: 0.59
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6301
# Spearman Correlation between predicted ratings and actual ratings is: 0.5614
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.71
# Correlation between predicted ratings and actual ratings is: 0.8415
# Spearman Correlation between predicted ratings and actual ratings is: 0.7715
# ****************************************************************************************
# (2207,)
# (2207, 409)

# %%
import scipy
rho, pval = scipy.stats.spearmanr(fullRating)
print fullRating.shape, len(social2Attr)
fullRating_df = pd.DataFrame(fullRating)
print fullRating_df.shape
fullRating_df.columns = social2Attr
fullRating_df.index = radomImlist
fullRating_df = fullRating_df.sort_
fullRating_df.to_csv('../Result/fullRating_predicted.csv')

print fullRating_df
# Out:
# (2207, 40) 40
# (2207, 40)
#                                                                           atypical  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg         4.727012
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                3.823379
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg       3.590300
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg        3.720556
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg            3.417973
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg              3.971019
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg          4.010940
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg           4.534292
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg        3.751843
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg            3.859688
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg             4.772437
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg        3.584310
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg         3.563625
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg       4.425233
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg          3.800224
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg             4.131195
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg         3.748725
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg          3.101037
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg  4.251164
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg             3.918679
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg    3.443819
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg         3.894489
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg          4.325465
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg          3.881246
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg         3.772201
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg           4.117828
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg            3.719053
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg           4.036089
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg         3.625344
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg          5.376468
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg           5.082139
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg           4.134340
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg         3.888467
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg      4.330803
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg       4.444275
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg           3.811764
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg            4.234143
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg      4.524391
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg        4.910054
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg       3.722301
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg      3.682549
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg           3.547312
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg       4.783528
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg           3.972209
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg        4.665030
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg          4.096307
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                   4.532997
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg      4.306097
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg            3.558240
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg           4.038593
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg            4.286367
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg          3.786719
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                3.586267
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg       3.545330
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg        2.939454
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg             3.902158
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg             4.005679
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                   3.866172
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg          4.101913
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg              4.416961
#                                                                                ...
#
#                                                                             boring  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg         4.299460
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                3.683961
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg       4.202762
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg        3.755541
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg            3.711043
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg              4.605630
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg          4.497772
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg           4.421265
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg        3.648896
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg            3.750217
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg             4.512468
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg        3.846481
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg         3.570335
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg       4.800961
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg          4.538295
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg             4.663756
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg         3.923670
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg          3.995967
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg  3.854484
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg             4.507186
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg    4.494668
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg         3.849224
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg          4.110924
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg          3.668227
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg         3.489372
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg           3.651040
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg            4.332991
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg           4.475671
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg         3.394197
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg          4.046963
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg           4.676684
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg           4.636493
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg         3.565691
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg      3.744224
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg       5.304700
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg           4.301864
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg            4.460765
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg      5.716501
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg        5.374620
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg       4.352566
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg      5.063770
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg           3.761937
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg       4.730365
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg           3.778414
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg        4.615503
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg          5.076754
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                   3.509715
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg      4.473443
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg            3.766312
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg           4.553319
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg            4.267421
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg          4.247009
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                3.457768
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg       3.012480
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg        2.765321
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg             4.418047
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg             4.650549
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                   3.834422
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg          4.394732
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg              3.873591
#                                                                                ...
#
#                                                                               calm  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg         6.226076
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                6.428073
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg       5.534535
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg        6.269936
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg            6.412863
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg              5.564798
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg          5.894550
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg           5.564003
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg        5.689314
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg            6.331241
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg             5.589042
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg        5.961681
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg         5.982445
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg       5.481454
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg          6.146055
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg             5.989255
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg         6.378516
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg          6.767997
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg  5.759950
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg             6.152947
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg    6.136437
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg         6.491322
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg          5.300755
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg          6.293750
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg         5.964278
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg           5.773332
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg            5.787666
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg           6.108910
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg         6.380278
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg          4.679893
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg           5.168711
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg           5.754127
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg         5.702233
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg      5.886485
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg       5.038389
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg           5.870000
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg            5.548143
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg      5.160682
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg        4.377591
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg       6.156319
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg      6.211070
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg           6.592309
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg       5.584558
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg           5.845160
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg        6.153040
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg          6.037954
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                   5.781437
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg      4.682068
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg            6.186103
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg           6.126198
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg            6.320860
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg          5.357212
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                6.219205
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg       5.827335
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg        6.285012
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg             5.761421
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg             6.002334
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                   6.438439
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg          6.043567
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg              5.435641
#                                                                                ...
#
#                                                                               cold  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg         3.294117
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                2.527329
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg       3.394919
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg        2.540956
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg            2.790004
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg              3.150238
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg          2.874850
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg           3.406252
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg        2.874572
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg            3.408065
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg             5.599892
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg        3.012632
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg         2.230808
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg       4.528614
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg          3.473039
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg             4.459148
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg         2.646278
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg          1.630793
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg  3.758752
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg             2.613599
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg    2.359860
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg         2.485356
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg          4.542608
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg          2.748974
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg         3.623395
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg           2.718631
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg            2.997999
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg           3.853836
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg         2.517064
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg          5.427274
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg           5.043709
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg           3.469792
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg         4.272814
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg      4.640980
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg       5.476525
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg           3.106059
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg            3.146404
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg      5.599872
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg        6.245531
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg       2.875640
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg      3.664790
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg           2.444762
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg       3.742380
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg           3.315288
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg        4.675988
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg          4.330664
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                   4.268596
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg      5.303635
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg            2.875515
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg           2.655810
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg            2.558329
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg          3.837466
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                1.992807
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg       2.833535
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg        2.117739
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg             4.276818
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg             4.465905
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                   2.753453
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg          3.224146
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg              4.212326
#                                                                                ...
#
#                                                                             common  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg         4.852750
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                5.379042
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg       5.254145
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg        5.231071
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg            5.512139
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg              5.762261
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg          5.659622
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg           5.444049
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg        5.135801
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg            5.175350
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg             4.956548
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg        5.453359
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg         5.141578
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg       5.469017
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg          5.435699
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg             5.531248
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg         5.623531
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg          5.803045
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg  5.123066
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg             5.352662
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg    5.635271
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg         5.444704
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg          5.353341
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg          5.157592
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg         4.848067
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg           5.309798
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg            5.605958
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg           5.199890
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg         5.424612
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg          4.273759
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg           4.589818
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg           5.506236
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg         4.889498
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg      5.147543
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg       5.322049
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg           5.501876
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg            5.480459
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg      5.268657
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg        5.049825
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg       5.503326
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg      5.779384
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg           5.552074
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg       5.255989
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg           5.311249
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg        5.527415
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg          5.349325
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                   5.110459
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg      5.186556
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg            5.538069
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg           5.536729
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg            5.643220
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg          5.600751
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                5.611353
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg       5.087848
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg        5.314523
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg             5.092078
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg             5.341006
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                   5.105100
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg          5.606386
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg              5.003126
#                                                                                ...
#
#                                                                           confident  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg          6.550593
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                 6.125482
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg        5.868838
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg         6.439276
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg             6.922246
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg               5.737587
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg           5.766047
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg            6.148714
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg         6.527942
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg             6.399499
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg              5.130852
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg         5.930531
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg          6.318161
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg        5.413533
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg           5.594331
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg              5.418213
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg          6.515459
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg           6.429015
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg   5.970283
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg              6.748091
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg     6.469651
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg          6.667922
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg           5.513383
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg           6.183318
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg          5.436286
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg            5.893911
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg             5.723883
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg            5.859756
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg          6.385560
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg           5.302164
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg            5.833163
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg            5.459426
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg          5.800979
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg       6.249521
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg        5.265334
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg            6.254627
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg             6.027251
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg       4.864199
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg         5.177546
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg        6.305341
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg       5.069395
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg            6.130037
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg        5.404541
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg            6.379690
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg         5.936515
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg           5.601887
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                    5.756332
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg       5.677234
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg             6.201823
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg            5.408358
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg             6.260232
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg           6.078858
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                 6.478044
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg        6.905007
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg         7.008854
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg              5.884426
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg              6.183860
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                    5.698938
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg           5.828424
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg               6.197180
#                                                                                 ...
#
#                                                                           egotistic  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg          3.085592
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                 3.042361
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg        4.087598
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg         3.156940
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg             3.650454
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg               2.762640
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg           2.680819
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg            4.099928
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg         3.995634
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg             3.853312
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg              5.269041
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg         3.290909
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg          2.976314
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg        4.419157
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg           3.135414
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg              4.128703
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg          3.217388
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg           2.535443
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg   3.780574
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg              3.947271
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg     3.949724
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg          3.441314
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg           5.365307
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg           3.649280
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg          3.918969
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg            4.042780
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg             3.378960
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg            3.464571
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg          3.227483
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg           5.529982
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg            4.732956
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg            3.450787
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg          4.304906
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg       4.899195
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg        4.487137
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg            4.019091
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg             4.208996
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg       4.761620
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg         5.385420
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg        3.929532
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg       3.067974
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg            2.423092
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg        3.833899
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg            3.735492
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg         3.857901
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg           4.540462
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                    4.903306
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg       5.272770
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg             3.584403
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg            3.185406
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg             3.434669
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg           4.950180
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                 3.391779
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg        3.598418
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg         3.413615
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg              5.030996
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg              4.379014
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                    4.441604
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg           3.619704
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg               4.798553
#                                                                                 ...
#
#                                                                           emotUnstable  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg             3.523136
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                    2.987776
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg           3.449330
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg            2.703545
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg                2.473263
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg                  3.291865
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg              3.536373
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg               3.917753
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg            3.315753
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg                3.410867
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg                 4.750050
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg            3.308670
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg             3.469550
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg           4.404065
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg              3.243282
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg                 4.091845
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg             3.157512
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg              2.518578
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg      3.726246
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg                 2.799947
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg        2.718724
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg             3.034947
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg              4.303328
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg              3.015270
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg             3.780332
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg               3.214356
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg                3.791822
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg               3.671133
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg             2.940179
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg              4.417410
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg               4.433319
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg               3.906734
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg             4.324553
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg          3.735807
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg           4.513548
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg               2.915459
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg                3.890265
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg          4.404542
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg            5.315183
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg           2.766002
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg          3.656214
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg               3.070799
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg           3.999959
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg               3.455686
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg            3.437305
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg              3.878876
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                       3.692962
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg          4.629725
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg                3.455416
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg               3.626549
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg                2.820699
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg              3.810899
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                    2.936832
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg           3.364841
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg            2.715159
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg                 3.577323
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg                 3.481316
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                       2.951146
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg              3.623532
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg                  3.949747
#                                                                                    ...
#
#                                                                           forgettable  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg            3.983386
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                   4.339725
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg          4.372926
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg           4.032314
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg               4.249250
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg                 4.683649
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg             4.698252
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg              4.787708
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg           4.089359
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg               3.724383
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg                4.790575
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg           4.373210
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg            3.976266
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg          5.028010
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg             4.909768
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg                4.776456
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg            4.415829
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg             4.504976
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg     4.098146
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg                4.454954
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg       4.720716
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg            4.093544
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg             4.726161
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg             3.957479
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg            4.320371
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg              4.634964
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg               4.743843
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg              4.552736
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg            4.116893
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg             4.462739
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg              4.349114
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg              4.855319
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg            3.739316
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg         3.913725
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg          5.046918
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg              4.483460
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg               4.702730
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg         5.412648
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg           5.430112
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg          4.558268
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg         5.104690
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg              4.294995
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg          5.059147
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg              4.161552
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg           4.060732
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg             5.139098
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                      3.951100
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg         4.709999
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg               4.254782
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg              5.014920
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg               4.268895
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg             4.728488
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                   4.049928
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg          3.640858
# ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg               4.460793
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                     2.739246
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg            3.349592
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg                4.200503
#                                                                                  ...
#
#                                                                            unhappy  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg         2.488569
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                2.271555
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg       3.288071
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg        2.182274
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg            2.332330
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg              2.933450
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg          3.168061
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg           3.707871
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg        2.882591
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg            3.626054
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg             5.715423
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg        3.222883
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg         2.731350
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg       4.695735
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg          3.202016
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg             4.226916
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg         2.519153
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg          1.628217
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg  3.398578
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg             2.391271
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg    1.834741
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg         2.524031
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg          4.278905
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg          2.598495
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg         3.639622
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg           2.457402
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg            3.006143
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg           3.939593
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg         2.310969
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg          5.321020
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg           5.538168
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg           3.642504
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg         4.082631
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg      4.236833
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg       5.174302
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg           2.947640
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg            3.292283
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg      5.913484
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg        6.415123
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg       2.988966
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg      3.746275
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg           2.327036
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg       3.969800
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg           3.019355
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg        4.485775
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg          4.046004
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                   4.221901
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg      5.344667
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg            2.571486
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg           2.841357
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg            2.597779
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg          3.465994
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                2.338447
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg       2.175551
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg        1.805074
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg             3.772611
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg             4.111015
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                   3.008763
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg          3.293610
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg              3.936928
#                                                                                ...
#
#                                                                              weird  \
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg         3.564693
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg                2.526149
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg       3.593767
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg        3.461901
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg            2.536504
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg              3.913961
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg          3.897588
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg           3.038556
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg        3.401270
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg            2.724158
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg             4.284226
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg        3.677656
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg         3.460038
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg       4.208658
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg          3.669675
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg             3.796926
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg         2.616318
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg          2.842414
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg  3.364842
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg             3.176451
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg    3.250859
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg         2.887373
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg          4.066178
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg          2.944711
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg         3.463441
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg           3.859332
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg            3.671361
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg           4.043342
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg         2.687570
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg          4.782343
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg           4.248164
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg           3.627912
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg         3.642744
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg      3.079762
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg       4.442677
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg           3.062573
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg            3.744040
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg      4.509841
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg        4.417514
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg       2.950432
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg      3.690278
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg           3.168352
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg       4.324471
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg           2.993582
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg        3.771913
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg          3.823025
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                   3.453400
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg      3.831752
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg            3.434986
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg           3.837447
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg            2.730162
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg          3.405273
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg                2.806817
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg       2.693329
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg        2.687501
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg             3.624011
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg             3.365172
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                   4.162447
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg          3.635694
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg              3.465632
#                                                                                ...
#
#
# ../../MIT2kFaceDataset/2kfaces/Google_1_Bryan Gleason_19_oval.jpg        ...
# ../../MIT2kFaceDataset/2kfaces/Brandon_Kellogg_15_oval.jpg               ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leonard Shumpert_3_oval.jpg      ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_William Gorham_15_oval.jpg       ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Todd Mcghee_1_oval.jpg           ...
# ../../MIT2kFaceDataset/2kfaces/Brandon_Brownfield_7_oval.jpg             ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Patrick Cosme_3_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Waller_8_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Howard Lindsey_10_oval.jpg       ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Eugene Mars_3_oval.jpg           ...
# ../../MIT2kFaceDataset/2kfaces/Josephine_Anderson_17_oval.jpg            ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_7_oval.jpg       ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Flora Newsome_15_oval.jpg        ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Douglas Tanguay_72_oval.jpg      ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Mark Shilling_1_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Coons_7_oval.jpg            ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Creed_19_oval.jpg        ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Luis Carvajal_7_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Danielle Christenson_13_oval.jpg ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Howe_4_oval.jpg            ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeannette Register_15_oval.jpg   ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Bisson_3_oval.jpg        ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Shawn Orlando_1_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_James Hannon_17_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeffery Tilton_3_oval.jpg        ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Andrew Diggs_9_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_John Batey_19_oval.jpg           ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Scott Ernst_19_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steven Mastin_17_oval.jpg        ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Agnes Ambrose_1_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Freund_13_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Sean Holcomb_1_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Florence Lott_19_oval.jpg        ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Phillip Grantham_17_oval.jpg     ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Susan Froehlich_13_oval.jpg      ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Robert Pyles_1_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Grace Kuhns_1_oval.jpg           ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Debbie Blackwell_15_oval.jpg     ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Christy Ferraro_9_oval.jpg       ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Timothy Rayborn_12_oval.jpg      ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vincent Halstead_13_oval.jpg     ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gerald Gary_13_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jose Bustamante_15_oval.jpg      ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jimmy Freund_9_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Steve Rutledge_17_oval.jpg       ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Viola Sorrell_5_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Allen_Strain_13_oval.jpg                  ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Leah Hershberger_13_oval.jpg     ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Vera Becker_5_oval.jpg           ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Joshua Regan_7_oval.jpg          ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Gina Gruber_1_oval.jpg           ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Adam Griswold_9_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Jonathan_DArden_13_oval.jpg               ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Wayne Mcdaniels_19_oval.jpg      ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Jeanette Weddle_1_oval.jpg       ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Harold Hom_3_oval.jpg            ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Ida Markel_5_oval.jpg            ...
# ../../MIT2kFaceDataset/2kfaces/Joshua_Sides_19_oval.jpg                  ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Belinda Steib_3_oval.jpg         ...
# ../../MIT2kFaceDataset/2kfaces/Google_1_Dale Reid_3_oval.jpg             ...
#
# [2207 rows x 40 columns]

# %%
#print rho
explained_variance = 0.95
sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
transform_rating = sklearn_pca.fit_transform(fullRating)
print 'The number of PCs needed to retain %.3f variance is %d.' \
      % (explained_variance, transform_rating.shape[1])
rho_df = pd.DataFrame(rho)
rho_df.columns = social2Attr
rho_df.to_csv('correlation_predicted.csv')
# Out:
# The number of PCs needed to retain 0.950 variance is 8.

# %%
result = np.zeros((40,6))
for j in range(1,50): 
    fName = "../Result/Config_vs_VGG16/regression_result_"+str(j)+".csv"
    df = pd.read_csv(fName,index_col = 0)
    result += df.as_matrix()
result = result/49
result_df = pd.DataFrame(result,              
                         index=df.index,
                         columns=df.columns)

# %%
result_df.to_csv('../Result/Config_vs_VGG16/combined_result.csv')
print result_df
# Out:
#                     geometric_test   vgg16_test   geometric_train  \
# Social Attributes
# atypical                  0.402237     0.425398          0.489236
# boring                    0.535243     0.597514          0.600339
# calm                      0.470863     0.495751          0.579291
# cold                      0.806880     0.784627          0.840375
# common                    0.371715     0.401104          0.485130
# confident                 0.552498     0.605544          0.635330
# egotistic                 0.620672     0.620933          0.677723
# emotUnstable              0.616999     0.642095          0.675754
# forgettable               0.401189     0.480230          0.496722
# intelligent               0.532326     0.615056          0.603440
# introverted               0.644715     0.652433          0.689155
# kind                      0.791768     0.785611          0.830976
# responsible               0.651286     0.700054          0.717695
# trustworthy               0.719369     0.731650          0.763551
# unattractive              0.618276     0.698494          0.676386
# unemotional               0.759798     0.746688          0.791983
# unfamiliar                0.396491     0.438311          0.441833
# unfriendly                0.797545     0.780197          0.833444
# unhappy                   0.813517     0.798503          0.851421
# weird                     0.492777     0.558175          0.563616
# aggressive                0.716386     0.718406          0.772323
# attractive                0.657614     0.751353          0.736919
# caring                    0.783243     0.785322          0.827977
# emotStable                0.638680     0.665423          0.712222
# emotional                 0.599780     0.604461          0.638568
# familiar                  0.420838     0.438254          0.491057
# friendly                  0.825922     0.817014          0.859372
# happy                     0.855791     0.839102          0.884445
# humble                    0.637441     0.628475          0.700529
# interesting               0.532106     0.580260          0.609410
# irresponsible             0.635621     0.672135          0.698633
# mean                      0.749040     0.734550          0.795736
# memorable                 0.380388     0.483912          0.487245
# normal                    0.580280     0.613317          0.667597
# sociable                  0.776129     0.777470          0.826167
# typical                   0.410364     0.430608          0.499703
# uncertain                 0.622488     0.625804          0.674569
# uncommon                  0.377829     0.400555          0.457071
# unintelligent             0.526645     0.582987          0.605032
# untrustworthy             0.693333     0.700923          0.748433
#
#                     vgg16_train   geometric_feature_num   vgg16_FeatureNum
# Social Attributes
# atypical               0.509419               86.040816         101.142857
# boring                 0.684780               85.142857         161.489796
# calm                   0.641846              123.510204         226.673469
# cold                   0.854958              118.163265         278.551020
# common                 0.491612              101.346939          99.632653
# confident              0.692921              111.102041         175.571429
# egotistic              0.742102               95.673469         266.244898
# emotUnstable           0.726363               97.489796         189.918367
# forgettable            0.606727               91.020408         169.000000
# intelligent            0.733225              101.367347         261.959184
# introverted            0.723336               76.857143         161.979592
# kind                   0.864208              127.265306         321.020408
# responsible            0.777156              132.693878         216.612245
# trustworthy            0.805520              105.734694         235.734694
# unattractive           0.775048              100.653061         193.897959
# unemotional            0.800268               87.918367         164.020408
# unfamiliar             0.511700               45.020408          89.795918
# unfriendly             0.854875              124.877551         298.938776
# unhappy                0.865633              135.877551         288.693878
# weird                  0.634838               80.244898         119.510204
# aggressive             0.796422              140.285714         235.367347
# attractive             0.852584              145.040816         350.714286
# caring                 0.852474              146.897959         278.510204
# emotStable             0.762028              128.040816         232.469388
# emotional              0.661457               44.877551          92.387755
# familiar               0.527801               66.734694         106.979592
# friendly               0.882335              137.408163         324.142857
# happy                  0.892868              140.040816         283.122449
# humble                 0.723963              119.836735         206.530612
# interesting            0.681491               86.367347         174.081633
# irresponsible          0.754618              111.448980         195.285714
# mean                   0.819980              130.693878         267.571429
# memorable              0.573275               83.020408         104.755102
# normal                 0.695074              128.653061         156.877551
# sociable               0.841476              148.551020         243.408163
# typical                0.539553               78.448980         127.326531
# uncertain              0.692423               87.693878         137.653061
# uncommon               0.496871               72.346939          92.959184
# unintelligent          0.675137               99.346939         159.183673
# untrustworthy          0.784932              124.367347         235.081633
#
# [40 rows x 6 columns]

# %%
print valifeature_transf_vgg.shape
def writeFile(imList, rating,fName):
    text_file = open(fName, "w")
    for i in range(imList.shape[0]):
        d = homePath+'attractiveness_datamining/'+imList[i][6:]+' '+str(rating[i])+'\n'
        text_file.write(d)
    text_file.close()
modelList = []
optFeaNumList = []
radomImlist = np.asarray(imList)[randomInd]
testIm = radomImlist[:int(nSamples*testRatio)]
trainIm = radomImlist[int(nSamples*testRatio):]
print testIm.shape, trainIm.shape
for attr in ['attractive']:
    print attr
    #attr= social2Attr[9]
    mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
               if imList[i][31:] in socialMeasures.index]
    print len(mean_rating)
    mean_rating = map(float, mean_rating)
    mean_rating = np.array(mean_rating)
    radomRating = mean_rating[randomInd]
    testRating = radomRating[:int(nSamples*testRatio)]
    trainRating = radomRating[int(nSamples*testRatio):]
    valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
    print valiRating.shape
    trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]
    #writeFile(trainIm,trainRating,'../list/'+attr+'_train.txt')
    #writeFile(testIm,testRating,'../list/'+attr+'_test.txt')
#     writeFile(trainIm,trainRating,'../data_list/'+attr+'_train.txt')
#     writeFile(testIm,testRating,'../data_list/'+attr+'_test.txt')
    baseLine = mean_rating.mean()
    print 'mean rating: ', baseLine

    predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
    myModel,optFeaNum = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf_vgg, \
                                   testfeature_tansf_vgg,valifeature_transf_vgg,xVal = True,numTrain = 1,\
                                   pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                   plotPredActual = False,returnModel = True)
    modelList.append(myModel)
    optFeaNumList.append(optFeaNum)
