# %%
'''
This is code for extracting NN features of face image data 
and then fit a linear model to predict social attributes of a face
Available dataset: TWIN, CHICAGO and MIT
Available NN feature: 'caffeNet','vgg16','vggFace' and 'faceSNN'

BY Linjie Li
Please run this code on guru2/neon server
'''
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import pandas as pd

from sklearn.decomposition import PCA as sklearnPCA

# Load image dataset#
Dataset = 'mit' # 'twin', 'chicago' or 'mit', 'zhihu' or 'funnyFace'
if Dataset == 'mit':
    imPath = '../../MIT2kFaceDataset/2kfaces/'
    ext = '.jpg'
imList = []
for dirpath, dirnames, filenames in os.walk(imPath):
    for filename in [f for f in filenames if f.endswith(ext)]:
        imList.append(os.path.join(dirpath, filename))
imList.sort()
print len(imList)
#print imPath
df = pd.read_csv('../../MIT2kFaceDataset/clean_data/geometric_wSmoothness.csv',index_col = 0)

print len(df.index)
imList = [imList[i] for i in range(len(imList)) if imList[i][31:] in df.index]
remainIndex = [i for i in range(len(imList)) if imList[i][31:] in df.index]
print len(remainIndex)
landMarks = pd.read_csv('../../processing/landmarking/mit/mitLandmarks.csv',index_col = 0)
imageList = list(set(landMarks.index.tolist()))
imageList.sort()
config_feature = df.as_matrix()
print config_feature.shape
# Out:
# 2222
# 2207
# 2207
# (2207, 37)

# %%
X_LMmatrix = np.zeros((len(imList),68))
Y_LMmatrix = np.zeros((len(imList),68))
for im in imageList:
    ind_im = imageList.index(im)
    X_LMmatrix[ind_im,:] = landMarks.ix[im].x.tolist()
    Y_LMmatrix[ind_im,:] = landMarks.ix[im].y.tolist()
def computeDist(X_LMmatrix,Y_LMmatrix, imInd):
    pointNum = X_LMmatrix.shape[1]
    distArr = np.zeros((1,pointNum*(pointNum-1)/2))
    distInd = 0
    for i in range(pointNum):
        for j in range(i+1,pointNum):
            x1 = np.asarray([X_LMmatrix[imInd,i],Y_LMmatrix[imInd,i]])
            x2 = np.asarray([X_LMmatrix[imInd,j],Y_LMmatrix[imInd,j]])
            distArr[0,distInd] = np.linalg.norm(x1-x2)
            distInd +=1
    return distArr
import sys
def computeCosine(X_LMmatrix,Y_LMmatrix, imInd):
    pointNum = X_LMmatrix.shape[1]
    cosineArr = np.zeros((1,pointNum*(pointNum-1)/2))
    cosineInd = 0
    for i in range(pointNum):
        for j in range(i+1,pointNum):
            denominator = float(X_LMmatrix[imInd,i]-X_LMmatrix[imInd,j])
            if denominator != 0:
                cosineArr[0,cosineInd] = np.cos(np.arctan(float(Y_LMmatrix[imInd,i]-Y_LMmatrix[imInd,j])/denominator))
            else:
                cosineArr[0,cosineInd] = 0
            cosineInd +=1
    return cosineArr


distMat = np.zeros((len(imList),X_LMmatrix.shape[1]*(X_LMmatrix.shape[1]-1)/2))
slopeMat = np.zeros((len(imList),X_LMmatrix.shape[1]*(X_LMmatrix.shape[1]-1)/2))
for imInd in range(len(imList)):
    distArr = computeDist(X_LMmatrix,Y_LMmatrix, imInd)
    slopeArr = computeCosine(X_LMmatrix,Y_LMmatrix, imInd)
    distMat[imInd,:] = distArr
    slopeMat[imInd,:] = slopeArr


distSlope = np.concatenate((slopeMat,distMat), axis=1)
allGeometric = np.concatenate((config_feature,distSlope),axis = 1)
#only_w_pixel = np.concatenate((meanHSV,smoothness,distSlope),axis = 1)

# %%
Dataset = 'mit'
MODEL = 'geometric'
homePath = '/home/lli-ms/'
np.savetxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_totalFeatures.csv', allGeometric, delimiter=',')

# %%
import random
featureMat = allGeometric
randomInd = range(featureMat.shape[0])
random.shuffle(randomInd)
print max(randomInd)
featureMat = featureMat[randomInd,:]
nSamples = featureMat.shape[0]
testRatio = 0.2
valiRatio = 0.1
testFeatures = featureMat[:int(nSamples*testRatio),:]
trainFeatures = featureMat[int(nSamples*testRatio):,:]
valiFeatures = featureMat[-int(trainFeatures.shape[0]*valiRatio):,:]
trainFeatures = trainFeatures[:-int(trainFeatures.shape[0]*valiRatio),:]
print valiFeatures.shape, trainFeatures.shape, testFeatures.shape
radomImlist = np.asarray(imList)[randomInd]

explained_variance = 1000
sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
trainfeature_transf = sklearn_pca.fit_transform(trainFeatures)
print 'The number of PCs needed to retain %.3f variance is %d.' \
      % (explained_variance, trainfeature_transf.shape[1])
print sklearn_pca.components_.shape
print trainfeature_transf.shape
testfeature_tansf = sklearn_pca.transform(testFeatures)
print testfeature_tansf.shape
valifeature_transf = sklearn_pca.transform(valiFeatures)
#component_std = np.std(sklearn_pca.components_,axis = 0,dtype=np.float32)
# import scipy
# u,s,v = scipy.sparse.linalg.svds(featureMat, k =sklearn_pca.components_.shape[0], which = 'LM')

np.savetxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_trainFeatures.csv', trainfeature_transf, delimiter=',')
np.savetxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_testFeatures.csv', testfeature_tansf, delimiter=',')
np.savetxt(homePath+'/features/'+MODEL+'_geometric_'+Dataset+\
           '_valiFeatures.csv', valifeature_transf, delimiter=',')
# Out:
# 2206
# (176, 4593) (1590, 4593) (441, 4593)
# The number of PCs needed to retain 1000.000 variance is 1000.
# (1000, 4593)
# (1590, 1000)
# (441, 1000)

# %%
import pandas as pd
socialMeasures = '../Result/mit/socialMeasures.csv'
socialMeasures = pd.read_csv(socialMeasures,index_col = 0)
socialAttr = socialMeasures.columns.tolist()
delElement = ['subage.1', 'submale.1', 'subrace.1','subage', 'submale',\
              'subrace','catch', 'catchAns','catch.1','catchAns.1']
social2Attr = [x for x in socialAttr if x not in delElement]
socialMeasuresClean = socialMeasures.loc[:,social2Attr].as_matrix()
#print socialMeasuresClean
np.savetxt('../Result/mit/socialMeasuresClean.csv', socialMeasuresClean, delimiter=',')

attr= social2Attr[9]
mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
               if imList[i][31:] in socialMeasures.index]
mean_rating = map(float, mean_rating)
mean_rating = np.array(mean_rating)

radomRating = mean_rating[randomInd]
testRating = radomRating[:int(nSamples*testRatio)]
trainRating = radomRating[int(nSamples*testRatio):]
valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]

print trainSubRating.shape,testRating.shape,valiRating.shape
print randomInd.index(1)

print radomImlist[ randomInd.index(randI)],radomRating[ randomInd.index(randI)]
print imList[randomInd[ randomInd.index(randI)]],mean_rating[randomInd[ randomInd.index(randI)]]
print socialMeasures.loc[imList[randomInd[ randomInd.index(randI)]][31:],attr]
# Out:
# (1590,) (441,) (176,)
# 1126
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Friel_1_oval.jpg 5.733333
# ../../MIT2kFaceDataset/2kfaces/Google_1_Delores Friel_1_oval.jpg 5.733333
# 5.733333

# %%
modelList = []
optFeaNumList = []
import sys
#print sys.path
# local
# PkgPath = '/Users/Olivialinlin/Documents/Github/attractiveness_datamining/linjieCode/code'
# server

PkgPath = homePath+'attractiveness_datamining/linjieCode/code'

if PkgPath not in sys.path:
    sys.path.insert(0, PkgPath)
#print sys.path
from xVal_train_test import Train_Test

import sklearn
import numpy as np
for attr in social2Attr:
    print attr
    #attr= social2Attr[9]
    mean_rating = [socialMeasures.loc[imList[i][31:],attr] for i in range(len(imList))\
               if imList[i][31:] in socialMeasures.index]
    mean_rating = map(float, mean_rating)
    mean_rating = np.array(mean_rating)
    radomRating = mean_rating[randomInd]
    testRating = radomRating[:int(nSamples*testRatio)]
    trainRating = radomRating[int(nSamples*testRatio):]
    valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
    trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]

    baseLine = mean_rating.mean()
    print 'mean rating: ', baseLine

    predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
    myModel,optFeaNum = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf, \
                                   testfeature_tansf,valifeature_transf,xVal = True,numTrain = 1,\
                                   pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                   plotPredActual = False,returnModel = True)
    modelList.append(myModel)
    optFeaNumList.append(optFeaNum)
# Out:
# atypical
# mean rating:  4.08446414454
# Correlation:  0.428337524808
# num of features:  28
# Spearman Correlation:  0.419444478825
# num of features:  28
# R^2 score:  0.180219387586
# num of features:  28
# MSE:  0.405125875821
# num of features:  28
# **************************Result of train and test**************************************
# number of features: 28
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4154
# Spearman Correlation between predicted ratings and actual ratings is: 0.4130
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4281
# Spearman Correlation between predicted ratings and actual ratings is: 0.4072
# ****************************************************************************************
# boring
# mean rating:  4.28997636656
# Correlation:  0.629427329594
# num of features:  173
# Spearman Correlation:  0.587568111242
# num of features:  173
# R^2 score:  0.393606932182
# num of features:  173
# MSE:  0.424378259392
# num of features:  173
# **************************Result of train and test**************************************
# number of features: 173
# On test set:
# Residual sum of squares: 0.52
# Variance score is: 0.26
# Correlation between predicted ratings and actual ratings is: 0.5227
# Spearman Correlation between predicted ratings and actual ratings is: 0.5236
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.49
# Correlation between predicted ratings and actual ratings is: 0.7001
# Spearman Correlation between predicted ratings and actual ratings is: 0.6960
# ****************************************************************************************
# calm
# mean rating:  5.80624816221
# Correlation:  0.57310585285
# num of features:  217
# Spearman Correlation:  0.456398086501
# num of features:  231
# R^2 score:  0.326235504862
# num of features:  217
# MSE:  0.383447231825
# num of features:  217
# **************************Result of train and test**************************************
# number of features: 217
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.19
# Correlation between predicted ratings and actual ratings is: 0.4713
# Spearman Correlation between predicted ratings and actual ratings is: 0.3421
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.43
# Correlation between predicted ratings and actual ratings is: 0.6538
# Spearman Correlation between predicted ratings and actual ratings is: 0.5698
# ****************************************************************************************
# cold
# mean rating:  3.71738235795
# Correlation:  0.813996082523
# num of features:  102
# Spearman Correlation:  0.755729544331
# num of features:  61
# R^2 score:  0.657264005524
# num of features:  102
# MSE:  0.582963785784
# num of features:  102
# **************************Result of train and test**************************************
# number of features: 102
# On test set:
# Residual sum of squares: 0.57
# Variance score is: 0.63
# Correlation between predicted ratings and actual ratings is: 0.7960
# Spearman Correlation between predicted ratings and actual ratings is: 0.7694
#
# On training set:
# Residual sum of squares: 0.45
# Variance score is: 0.71
# Correlation between predicted ratings and actual ratings is: 0.8414
# Spearman Correlation between predicted ratings and actual ratings is: 0.7995
# ****************************************************************************************
# common
# mean rating:  5.32550588808
# Correlation:  0.433683145936
# num of features:  28
# Spearman Correlation:  0.467225967426
# num of features:  28
# R^2 score:  0.181792586981
# num of features:  46
# MSE:  0.400076553744
# num of features:  46
# **************************Result of train and test**************************************
# number of features: 28
# On test set:
# Residual sum of squares: 0.33
# Variance score is: 0.11
# Correlation between predicted ratings and actual ratings is: 0.3452
# Spearman Correlation between predicted ratings and actual ratings is: 0.2979
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4075
# Spearman Correlation between predicted ratings and actual ratings is: 0.3829
# ****************************************************************************************
# confident
# mean rating:  5.92335749751
# Correlation:  0.585721569252
# num of features:  181
# Spearman Correlation:  0.499419786199
# num of features:  181
# R^2 score:  0.315872804855
# num of features:  181
# MSE:  0.433839163817
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 181
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6381
# Spearman Correlation between predicted ratings and actual ratings is: 0.6218
#
# On training set:
# Residual sum of squares: 0.32
# Variance score is: 0.54
# Correlation between predicted ratings and actual ratings is: 0.7345
# Spearman Correlation between predicted ratings and actual ratings is: 0.6944
# ****************************************************************************************
# egotistic
# mean rating:  4.07662558269
# Correlation:  0.647025111613
# num of features:  99
# Spearman Correlation:  0.660536624832
# num of features:  258
# R^2 score:  0.401313991332
# num of features:  99
# MSE:  0.621802893668
# num of features:  99
# **************************Result of train and test**************************************
# number of features: 99
# On test set:
# Residual sum of squares: 0.59
# Variance score is: 0.37
# Correlation between predicted ratings and actual ratings is: 0.6116
# Spearman Correlation between predicted ratings and actual ratings is: 0.5818
#
# On training set:
# Residual sum of squares: 0.47
# Variance score is: 0.46
# Correlation between predicted ratings and actual ratings is: 0.6813
# Spearman Correlation between predicted ratings and actual ratings is: 0.6688
# ****************************************************************************************
# emotUnstable
# mean rating:  3.63361718849
# Correlation:  0.620277777947
# num of features:  181
# Spearman Correlation:  0.513779138255
# num of features:  61
# R^2 score:  0.381616692102
# num of features:  181
# MSE:  0.552336007767
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 181
# On test set:
# Residual sum of squares: 0.49
# Variance score is: 0.39
# Correlation between predicted ratings and actual ratings is: 0.6314
# Spearman Correlation between predicted ratings and actual ratings is: 0.5252
#
# On training set:
# Residual sum of squares: 0.39
# Variance score is: 0.53
# Correlation between predicted ratings and actual ratings is: 0.7263
# Spearman Correlation between predicted ratings and actual ratings is: 0.6558
# ****************************************************************************************
# forgettable
# mean rating:  4.54602870412
# Correlation:  0.410956298321
# num of features:  590
# Spearman Correlation:  0.35632698551
# num of features:  590
# R^2 score:  0.131320911094
# num of features:  175
# MSE:  0.416815253844
# num of features:  175
# **************************Result of train and test**************************************
# number of features: 590
# On test set:
# Residual sum of squares: 0.54
# Variance score is: -0.07
# Correlation between predicted ratings and actual ratings is: 0.3584
# Spearman Correlation between predicted ratings and actual ratings is: 0.3489
#
# On training set:
# Residual sum of squares: 0.23
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7484
# Spearman Correlation between predicted ratings and actual ratings is: 0.7349
# ****************************************************************************************
# intelligent
# mean rating:  5.83579811962
# Correlation:  0.53792752989
# num of features:  187
# Spearman Correlation:  0.425012865549
# num of features:  281
# R^2 score:  0.271376750318
# num of features:  187
# MSE:  0.407985980906
# num of features:  187
# **************************Result of train and test**************************************
# number of features: 187
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.33
# Correlation between predicted ratings and actual ratings is: 0.5788
# Spearman Correlation between predicted ratings and actual ratings is: 0.4996
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.45
# Correlation between predicted ratings and actual ratings is: 0.6748
# Spearman Correlation between predicted ratings and actual ratings is: 0.6005
# ****************************************************************************************
# introverted
# mean rating:  3.9278672696
# Correlation:  0.630968220366
# num of features:  187
# Spearman Correlation:  0.589733141499
# num of features:  87
# R^2 score:  0.387425675029
# num of features:  184
# MSE:  0.48367534931
# num of features:  184
# **************************Result of train and test**************************************
# number of features: 187
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.43
# Correlation between predicted ratings and actual ratings is: 0.6601
# Spearman Correlation between predicted ratings and actual ratings is: 0.6576
#
# On training set:
# Residual sum of squares: 0.38
# Variance score is: 0.57
# Correlation between predicted ratings and actual ratings is: 0.7554
# Spearman Correlation between predicted ratings and actual ratings is: 0.7434
# ****************************************************************************************
# kind
# mean rating:  5.67934660807
# Correlation:  0.793533693646
# num of features:  190
# Spearman Correlation:  0.735506465793
# num of features:  49
# R^2 score:  0.628317677245
# num of features:  190
# MSE:  0.467340744283
# num of features:  190
# **************************Result of train and test**************************************
# number of features: 190
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.61
# Correlation between predicted ratings and actual ratings is: 0.7846
# Spearman Correlation between predicted ratings and actual ratings is: 0.7323
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.74
# Correlation between predicted ratings and actual ratings is: 0.8604
# Spearman Correlation between predicted ratings and actual ratings is: 0.8158
# ****************************************************************************************
# responsible
# mean rating:  5.86209432941
# Correlation:  0.640748354272
# num of features:  187
# Spearman Correlation:  0.505719776278
# num of features:  102
# R^2 score:  0.407681351017
# num of features:  187
# MSE:  0.475249336161
# num of features:  187
# **************************Result of train and test**************************************
# number of features: 187
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.49
# Correlation between predicted ratings and actual ratings is: 0.7020
# Spearman Correlation between predicted ratings and actual ratings is: 0.5473
#
# On training set:
# Residual sum of squares: 0.34
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7504
# Spearman Correlation between predicted ratings and actual ratings is: 0.6723
# ****************************************************************************************
# trustworthy
# mean rating:  5.60918211192
# Correlation:  0.736160272119
# num of features:  105
# Spearman Correlation:  0.688857197285
# num of features:  25
# R^2 score:  0.538237395001
# num of features:  105
# MSE:  0.416260807902
# num of features:  105
# **************************Result of train and test**************************************
# number of features: 105
# On test set:
# Residual sum of squares: 0.44
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7080
# Spearman Correlation between predicted ratings and actual ratings is: 0.6163
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7688
# Spearman Correlation between predicted ratings and actual ratings is: 0.7133
# ****************************************************************************************
# unattractive
# mean rating:  4.26128344314
# Correlation:  0.741189111242
# num of features:  255
# Spearman Correlation:  0.738273973654
# num of features:  490
# R^2 score:  0.548663865484
# num of features:  255
# MSE:  0.579749168326
# num of features:  255
# **************************Result of train and test**************************************
# number of features: 255
# On test set:
# Residual sum of squares: 0.63
# Variance score is: 0.48
# Correlation between predicted ratings and actual ratings is: 0.7007
# Spearman Correlation between predicted ratings and actual ratings is: 0.7038
#
# On training set:
# Residual sum of squares: 0.45
# Variance score is: 0.67
# Correlation between predicted ratings and actual ratings is: 0.8171
# Spearman Correlation between predicted ratings and actual ratings is: 0.8174
# ****************************************************************************************
# unemotional
# mean rating:  3.81009778659
# Correlation:  0.769263264582
# num of features:  96
# Spearman Correlation:  0.765003463677
# num of features:  96
# R^2 score:  0.584962989152
# num of features:  96
# MSE:  0.399258834598
# num of features:  96
# **************************Result of train and test**************************************
# number of features: 96
# On test set:
# Residual sum of squares: 0.42
# Variance score is: 0.56
# Correlation between predicted ratings and actual ratings is: 0.7521
# Spearman Correlation between predicted ratings and actual ratings is: 0.7417
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.64
# Correlation between predicted ratings and actual ratings is: 0.7992
# Spearman Correlation between predicted ratings and actual ratings is: 0.7788
# ****************************************************************************************
# unfamiliar
# mean rating:  4.39983614454
# Correlation:  0.46956128975
# num of features:  22
# Spearman Correlation:  0.447189481162
# num of features:  22
# R^2 score:  0.205859048757
# num of features:  22
# MSE:  0.42468029058
# num of features:  22
# **************************Result of train and test**************************************
# number of features: 22
# On test set:
# Residual sum of squares: 0.36
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4288
# Spearman Correlation between predicted ratings and actual ratings is: 0.4357
#
# On training set:
# Residual sum of squares: 0.40
# Variance score is: 0.17
# Correlation between predicted ratings and actual ratings is: 0.4159
# Spearman Correlation between predicted ratings and actual ratings is: 0.4002
# ****************************************************************************************
# unfriendly
# mean rating:  3.61636378885
# Correlation:  0.807647580413
# num of features:  102
# Spearman Correlation:  0.73250981724
# num of features:  72
# R^2 score:  0.645851011508
# num of features:  102
# MSE:  0.601441905554
# num of features:  102
# **************************Result of train and test**************************************
# number of features: 102
# On test set:
# Residual sum of squares: 0.54
# Variance score is: 0.63
# Correlation between predicted ratings and actual ratings is: 0.7946
# Spearman Correlation between predicted ratings and actual ratings is: 0.7544
#
# On training set:
# Residual sum of squares: 0.47
# Variance score is: 0.69
# Correlation between predicted ratings and actual ratings is: 0.8299
# Spearman Correlation between predicted ratings and actual ratings is: 0.7780
# ****************************************************************************************
# unhappy
# mean rating:  3.60946439556
# Correlation:  0.833818883782
# num of features:  102
# Spearman Correlation:  0.747649138311
# num of features:  99
# R^2 score:  0.69067395838
# num of features:  181
# MSE:  0.530173477119
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 102
# On test set:
# Residual sum of squares: 0.54
# Variance score is: 0.66
# Correlation between predicted ratings and actual ratings is: 0.8114
# Spearman Correlation between predicted ratings and actual ratings is: 0.7716
#
# On training set:
# Residual sum of squares: 0.48
# Variance score is: 0.71
# Correlation between predicted ratings and actual ratings is: 0.8445
# Spearman Correlation between predicted ratings and actual ratings is: 0.7924
# ****************************************************************************************
# weird
# mean rating:  3.63519592705
# Correlation:  0.518369236024
# num of features:  231
# Spearman Correlation:  0.453023502097
# num of features:  217
# R^2 score:  0.238043977123
# num of features:  217
# MSE:  0.675182122082
# num of features:  217
# **************************Result of train and test**************************************
# number of features: 231
# On test set:
# Residual sum of squares: 0.64
# Variance score is: 0.22
# Correlation between predicted ratings and actual ratings is: 0.5190
# Spearman Correlation between predicted ratings and actual ratings is: 0.4987
#
# On training set:
# Residual sum of squares: 0.49
# Variance score is: 0.50
# Correlation between predicted ratings and actual ratings is: 0.7049
# Spearman Correlation between predicted ratings and actual ratings is: 0.6831
# ****************************************************************************************
# aggressive
# mean rating:  3.68722056094
# Correlation:  0.719220893777
# num of features:  181
# Spearman Correlation:  0.629732995569
# num of features:  93
# R^2 score:  0.512713620548
# num of features:  181
# MSE:  0.637158797059
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 181
# On test set:
# Residual sum of squares: 0.65
# Variance score is: 0.49
# Correlation between predicted ratings and actual ratings is: 0.7058
# Spearman Correlation between predicted ratings and actual ratings is: 0.6327
#
# On training set:
# Residual sum of squares: 0.45
# Variance score is: 0.65
# Correlation between predicted ratings and actual ratings is: 0.8056
# Spearman Correlation between predicted ratings and actual ratings is: 0.7339
# ****************************************************************************************
# attractive
# mean rating:  4.93915489035
# Correlation:  0.87722471459
# num of features:  193
# Spearman Correlation:  0.857303577735
# num of features:  193
# R^2 score:  0.767936420497
# num of features:  193
# MSE:  0.343263139742
# num of features:  193
# **************************Result of train and test**************************************
# number of features: 193
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.72
# Correlation between predicted ratings and actual ratings is: 0.8515
# Spearman Correlation between predicted ratings and actual ratings is: 0.8453
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.82
# Correlation between predicted ratings and actual ratings is: 0.9086
# Spearman Correlation between predicted ratings and actual ratings is: 0.9063
# ****************************************************************************************
# caring
# mean rating:  5.54517054055
# Correlation:  0.786680587331
# num of features:  199
# Spearman Correlation:  0.704031605461
# num of features:  231
# R^2 score:  0.617772201755
# num of features:  199
# MSE:  0.46410458699
# num of features:  199
# **************************Result of train and test**************************************
# number of features: 199
# On test set:
# Residual sum of squares: 0.49
# Variance score is: 0.57
# Correlation between predicted ratings and actual ratings is: 0.7632
# Spearman Correlation between predicted ratings and actual ratings is: 0.7143
#
# On training set:
# Residual sum of squares: 0.27
# Variance score is: 0.75
# Correlation between predicted ratings and actual ratings is: 0.8702
# Spearman Correlation between predicted ratings and actual ratings is: 0.8259
# ****************************************************************************************
# emotStable
# mean rating:  5.72743004531
# Correlation:  0.712200876564
# num of features:  181
# Spearman Correlation:  0.588389822704
# num of features:  255
# R^2 score:  0.502097894169
# num of features:  181
# MSE:  0.356482701073
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 181
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.44
# Correlation between predicted ratings and actual ratings is: 0.6702
# Spearman Correlation between predicted ratings and actual ratings is: 0.5759
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.59
# Correlation between predicted ratings and actual ratings is: 0.7684
# Spearman Correlation between predicted ratings and actual ratings is: 0.7080
# ****************************************************************************************
# emotional
# mean rating:  4.8545259343
# Correlation:  0.669301462623
# num of features:  25
# Spearman Correlation:  0.670140474532
# num of features:  25
# R^2 score:  0.423440769009
# num of features:  25
# MSE:  0.33752425065
# num of features:  25
# **************************Result of train and test**************************************
# number of features: 25
# On test set:
# Residual sum of squares: 0.29
# Variance score is: 0.35
# Correlation between predicted ratings and actual ratings is: 0.5940
# Spearman Correlation between predicted ratings and actual ratings is: 0.6004
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.39
# Correlation between predicted ratings and actual ratings is: 0.6227
# Spearman Correlation between predicted ratings and actual ratings is: 0.6350
# ****************************************************************************************
# familiar
# mean rating:  4.82427548618
# Correlation:  0.50135611211
# num of features:  196
# Spearman Correlation:  0.418952857349
# num of features:  199
# R^2 score:  0.245959588464
# num of features:  196
# MSE:  0.340223834716
# num of features:  196
# **************************Result of train and test**************************************
# number of features: 196
# On test set:
# Residual sum of squares: 0.38
# Variance score is: 0.12
# Correlation between predicted ratings and actual ratings is: 0.4232
# Spearman Correlation between predicted ratings and actual ratings is: 0.3761
#
# On training set:
# Residual sum of squares: 0.28
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6297
# Spearman Correlation between predicted ratings and actual ratings is: 0.6049
# ****************************************************************************************
# friendly
# mean rating:  5.82372672542
# Correlation:  0.834449995016
# num of features:  184
# Spearman Correlation:  0.769256447696
# num of features:  49
# R^2 score:  0.694180782785
# num of features:  184
# MSE:  0.494750282798
# num of features:  184
# **************************Result of train and test**************************************
# number of features: 184
# On test set:
# Residual sum of squares: 0.45
# Variance score is: 0.71
# Correlation between predicted ratings and actual ratings is: 0.8454
# Spearman Correlation between predicted ratings and actual ratings is: 0.8049
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.79
# Correlation between predicted ratings and actual ratings is: 0.8908
# Spearman Correlation between predicted ratings and actual ratings is: 0.8518
# ****************************************************************************************
# happy
# mean rating:  5.76725519665
# Correlation:  0.845421377047
# num of features:  184
# Spearman Correlation:  0.798500480183
# num of features:  93
# R^2 score:  0.712802898871
# num of features:  181
# MSE:  0.556740125911
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 184
# On test set:
# Residual sum of squares: 0.43
# Variance score is: 0.78
# Correlation between predicted ratings and actual ratings is: 0.8820
# Spearman Correlation between predicted ratings and actual ratings is: 0.8704
#
# On training set:
# Residual sum of squares: 0.35
# Variance score is: 0.82
# Correlation between predicted ratings and actual ratings is: 0.9045
# Spearman Correlation between predicted ratings and actual ratings is: 0.8738
# ****************************************************************************************
# humble
# mean rating:  5.26263057771
# Correlation:  0.631509495591
# num of features:  143
# Spearman Correlation:  0.557679195289
# num of features:  99
# R^2 score:  0.3985203464
# num of features:  143
# MSE:  0.516971861466
# num of features:  143
# **************************Result of train and test**************************************
# number of features: 143
# On test set:
# Residual sum of squares: 0.47
# Variance score is: 0.38
# Correlation between predicted ratings and actual ratings is: 0.6236
# Spearman Correlation between predicted ratings and actual ratings is: 0.5473
#
# On training set:
# Residual sum of squares: 0.36
# Variance score is: 0.52
# Correlation between predicted ratings and actual ratings is: 0.7192
# Spearman Correlation between predicted ratings and actual ratings is: 0.6725
# ****************************************************************************************
# interesting
# mean rating:  5.19165798958
# Correlation:  0.613133035705
# num of features:  173
# Spearman Correlation:  0.571305300941
# num of features:  175
# R^2 score:  0.374904182621
# num of features:  173
# MSE:  0.370316656187
# num of features:  173
# **************************Result of train and test**************************************
# number of features: 173
# On test set:
# Residual sum of squares: 0.31
# Variance score is: 0.41
# Correlation between predicted ratings and actual ratings is: 0.6449
# Spearman Correlation between predicted ratings and actual ratings is: 0.6451
#
# On training set:
# Residual sum of squares: 0.26
# Variance score is: 0.52
# Correlation between predicted ratings and actual ratings is: 0.7240
# Spearman Correlation between predicted ratings and actual ratings is: 0.7037
# ****************************************************************************************
# irresponsible
# mean rating:  3.49263116855
# Correlation:  0.68261879976
# num of features:  84
# Spearman Correlation:  0.543862621743
# num of features:  43
# R^2 score:  0.434783588942
# num of features:  84
# MSE:  0.50760703717
# num of features:  84
# **************************Result of train and test**************************************
# number of features: 84
# On test set:
# Residual sum of squares: 0.48
# Variance score is: 0.40
# Correlation between predicted ratings and actual ratings is: 0.6346
# Spearman Correlation between predicted ratings and actual ratings is: 0.5171
#
# On training set:
# Residual sum of squares: 0.42
# Variance score is: 0.47
# Correlation between predicted ratings and actual ratings is: 0.6904
# Spearman Correlation between predicted ratings and actual ratings is: 0.6028
# ****************************************************************************************
# mean
# mean rating:  3.5064195034
# Correlation:  0.772568315375
# num of features:  184
# Spearman Correlation:  0.683135894884
# num of features:  25
# R^2 score:  0.58518091951
# num of features:  184
# MSE:  0.599269908192
# num of features:  184
# **************************Result of train and test**************************************
# number of features: 184
# On test set:
# Residual sum of squares: 0.55
# Variance score is: 0.57
# Correlation between predicted ratings and actual ratings is: 0.7618
# Spearman Correlation between predicted ratings and actual ratings is: 0.6744
#
# On training set:
# Residual sum of squares: 0.41
# Variance score is: 0.69
# Correlation between predicted ratings and actual ratings is: 0.8296
# Spearman Correlation between predicted ratings and actual ratings is: 0.7560
# ****************************************************************************************
# memorable
# mean rating:  4.9651826126
# Correlation:  0.44265362051
# num of features:  173
# Spearman Correlation:  0.403420849758
# num of features:  173
# R^2 score:  0.174497201977
# num of features:  173
# MSE:  0.352809837805
# num of features:  173
# **************************Result of train and test**************************************
# number of features: 173
# On test set:
# Residual sum of squares: 0.35
# Variance score is: 0.22
# Correlation between predicted ratings and actual ratings is: 0.4761
# Spearman Correlation between predicted ratings and actual ratings is: 0.4750
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.36
# Correlation between predicted ratings and actual ratings is: 0.5998
# Spearman Correlation between predicted ratings and actual ratings is: 0.5818
# ****************************************************************************************
# normal
# mean rating:  6.00765605256
# Correlation:  0.676008862814
# num of features:  220
# Spearman Correlation:  0.537799438856
# num of features:  220
# R^2 score:  0.451868460251
# num of features:  220
# MSE:  0.362521681833
# num of features:  220
# **************************Result of train and test**************************************
# number of features: 220
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.35
# Correlation between predicted ratings and actual ratings is: 0.6231
# Spearman Correlation between predicted ratings and actual ratings is: 0.5557
#
# On training set:
# Residual sum of squares: 0.29
# Variance score is: 0.57
# Correlation between predicted ratings and actual ratings is: 0.7536
# Spearman Correlation between predicted ratings and actual ratings is: 0.7027
# ****************************************************************************************
# sociable
# mean rating:  5.82178301767
# Correlation:  0.795692896768
# num of features:  181
# Spearman Correlation:  0.713970334467
# num of features:  93
# R^2 score:  0.626103797605
# num of features:  181
# MSE:  0.456862592693
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 181
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.67
# Correlation between predicted ratings and actual ratings is: 0.8189
# Spearman Correlation between predicted ratings and actual ratings is: 0.8019
#
# On training set:
# Residual sum of squares: 0.31
# Variance score is: 0.75
# Correlation between predicted ratings and actual ratings is: 0.8671
# Spearman Correlation between predicted ratings and actual ratings is: 0.8284
# ****************************************************************************************
# typical
# mean rating:  5.28990378885
# Correlation:  0.473310217225
# num of features:  93
# Spearman Correlation:  0.481398507793
# num of features:  93
# R^2 score:  0.222383843291
# num of features:  93
# MSE:  0.375179901448
# num of features:  93
# **************************Result of train and test**************************************
# number of features: 93
# On test set:
# Residual sum of squares: 0.32
# Variance score is: 0.18
# Correlation between predicted ratings and actual ratings is: 0.4341
# Spearman Correlation between predicted ratings and actual ratings is: 0.3734
#
# On training set:
# Residual sum of squares: 0.33
# Variance score is: 0.26
# Correlation between predicted ratings and actual ratings is: 0.5110
# Spearman Correlation between predicted ratings and actual ratings is: 0.4814
# ****************************************************************************************
# uncertain
# mean rating:  3.71752754508
# Correlation:  0.65703526283
# num of features:  99
# Spearman Correlation:  0.58854192064
# num of features:  128
# R^2 score:  0.411214375426
# num of features:  108
# MSE:  0.366063118811
# num of features:  108
# **************************Result of train and test**************************************
# number of features: 99
# On test set:
# Residual sum of squares: 0.37
# Variance score is: 0.39
# Correlation between predicted ratings and actual ratings is: 0.6274
# Spearman Correlation between predicted ratings and actual ratings is: 0.6338
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.46
# Correlation between predicted ratings and actual ratings is: 0.6825
# Spearman Correlation between predicted ratings and actual ratings is: 0.6607
# ****************************************************************************************
# uncommon
# mean rating:  3.8728980956
# Correlation:  0.410861119227
# num of features:  252
# Spearman Correlation:  0.368145262596
# num of features:  252
# R^2 score:  0.0998846502657
# num of features:  252
# MSE:  0.387091348802
# num of features:  252
# **************************Result of train and test**************************************
# number of features: 252
# On test set:
# Residual sum of squares: 0.40
# Variance score is: 0.05
# Correlation between predicted ratings and actual ratings is: 0.3496
# Spearman Correlation between predicted ratings and actual ratings is: 0.3309
#
# On training set:
# Residual sum of squares: 0.30
# Variance score is: 0.33
# Correlation between predicted ratings and actual ratings is: 0.5752
# Spearman Correlation between predicted ratings and actual ratings is: 0.5420
# ****************************************************************************************
# unintelligent
# mean rating:  3.41826166923
# Correlation:  0.599388835767
# num of features:  52
# Spearman Correlation:  0.48800089561
# num of features:  49
# R^2 score:  0.340996387769
# num of features:  52
# MSE:  0.403955321406
# num of features:  52
# **************************Result of train and test**************************************
# number of features: 52
# On test set:
# Residual sum of squares: 0.39
# Variance score is: 0.27
# Correlation between predicted ratings and actual ratings is: 0.5273
# Spearman Correlation between predicted ratings and actual ratings is: 0.4769
#
# On training set:
# Residual sum of squares: 0.42
# Variance score is: 0.32
# Correlation between predicted ratings and actual ratings is: 0.5637
# Spearman Correlation between predicted ratings and actual ratings is: 0.4821
# ****************************************************************************************
# untrustworthy
# mean rating:  3.65110533077
# Correlation:  0.691449309781
# num of features:  181
# Spearman Correlation:  0.589070361902
# num of features:  99
# R^2 score:  0.47212766033
# num of features:  181
# MSE:  0.577677373369
# num of features:  181
# **************************Result of train and test**************************************
# number of features: 181
# On test set:
# Residual sum of squares: 0.52
# Variance score is: 0.49
# Correlation between predicted ratings and actual ratings is: 0.7080
# Spearman Correlation between predicted ratings and actual ratings is: 0.6220
#
# On training set:
# Residual sum of squares: 0.37
# Variance score is: 0.63
# Correlation between predicted ratings and actual ratings is: 0.7982
# Spearman Correlation between predicted ratings and actual ratings is: 0.7315
# ****************************************************************************************

# %%
# Make sure that caffe is on the python path:
#homePath = '/raid/linjieli/'
homePath = '/home/lli-ms/'
caffe_root = homePath+'caffe/'
pretrained_model_root = homePath+'caffe/'

# run this line one time only!
import sys
caffePython = pretrained_model_root + 'python'
if caffePython not in sys.path:
    sys.path.insert(0, caffePython)


import caffe
# Load mean
mu = np.load(caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy')
mu = mu.mean(1).mean(1)  # average over pixels to obtain the mean (BGR) pixel values
print 'mean-subtracted values:', zip('BGR', mu)

# Load the trained net
MODEL = 'vgg16' #'caffeNet','vgg16','vggFace' or 'faceSNN'

saveFigPath = '../Result/'+Dataset+'/'+MODEL
if not os.path.exists(saveFigPath):
    os.makedirs(saveFigPath)
    
if MODEL == 'vgg16':
    MODEL_FILE = caffe_root +'models/VGG16/VGG_ILSVRC_16_layers_deploy.prototxt'
    PRETRAINED_FILE = caffe_root + 'models/VGG16/VGG_ILSVRC_16_layers.caffemodel'
elif MODEL == 'caffeNet':
    MODEL_FILE = caffe_root + 'models/bvlc_reference_caffenet/deploy.prototxt'
    PRETRAINED_FILE = caffe_root + 'models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel'
elif MODEL == 'vggFace':
    MODEL_FILE = caffe_root + 'models/VGGFACE/VGG_CNN_F_deploy.prototxt'
    PRETRAINED_FILE = caffe_root + 'models/VGGFACE/VGG_CNN_F.caffemodel'
    MEAN_FILE = caffe_root + 'models/VGGFACE/VGG_mean.binaryproto'
else:
    MODEL = 'faceSNN'
    MODEL_FILE = caffe_root +'models/sraonet/siamese_lecun_deploy.prototxt'
    PRETRAINED_FILE = caffe_root + 'models/sraonet/snapshots/sraonet_lecun_gd_sub2_iter_100000.caffemodel'
    
caffe.set_device(1)
caffe.set_mode_gpu()
if not os.path.isfile(PRETRAINED_FILE):
    print("No caffemodel!!!")
elif not os.path.isfile(MODEL_FILE):
    print("No MODEL !!!")
else:
    print "Defining the net!"
    net = caffe.Net(MODEL_FILE,
                PRETRAINED_FILE,
                caffe.TEST)
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
if MODEL != 'faceSNN':
    # subtract the dataset-mean value in each channel
    transformer.set_mean('data', mu)
for layer_name, param in net.params.iteritems():
    print layer_name + '\t' + str(param[0].data.shape), str(param[1].data.shape)
transformer.set_transpose('data', (2,0,1))
# the reference model operates on images in [0,255] range instead of [0,1]
transformer.set_raw_scale('data', 255) 
# the reference model has channels in BGR order instead of RGB
transformer.set_channel_swap('data', (2,1,0))
# Out:
# mean-subtracted values: [('B', 104.0069879317889), ('G', 116.66876761696767), ('R', 122.6789143406786)]
# Defining the net!
# conv1_1	(64, 3, 3, 3) (64,)
# conv1_2	(64, 64, 3, 3) (64,)
# conv2_1	(128, 64, 3, 3) (128,)
# conv2_2	(128, 128, 3, 3) (128,)
# conv3_1	(256, 128, 3, 3) (256,)
# conv3_2	(256, 256, 3, 3) (256,)
# conv3_3	(256, 256, 3, 3) (256,)
# conv4_1	(512, 256, 3, 3) (512,)
# conv4_2	(512, 512, 3, 3) (512,)
# conv4_3	(512, 512, 3, 3) (512,)
# conv5_1	(512, 512, 3, 3) (512,)
# conv5_2	(512, 512, 3, 3) (512,)
# conv5_3	(512, 512, 3, 3) (512,)
# fc6	(4096, 25088) (4096,)
# fc7	(4096, 4096) (4096,)
# fc8	(1000, 4096) (1000,)

# %%
if MODEL == 'vgg16' or MODEL == 'vggFace':
    imgeReshape = [224,224]
    featureLayer = 'conv5_2' 
elif MODEL == 'caffeNet':
    imgeReshape = [227,227]
    featureLayer = 'fc6'
else:
    imgeReshape = [56,46]
    featureLayer = 'fc6'
if 'fc' in featureLayer:
    featureNum = net.params[featureLayer][1].data.shape[0]
else:
    featureNum = net.blobs[featureLayer].data.flatten().shape[0]/net.blobs[featureLayer].data.shape[0]
    
if Dataset == 'twin':
    features = np.zeros([4,len(imList)/4,featureNum])
    perImNum = len(imList)/4
    img_type_num = {}
    img_type_index = {}
    img_type_list = {}
    type_index = 0
else:
    features = np.zeros([len(imList),featureNum])
print featureNum
# Out:
# 100352

# %%
totalNum = 0

# print len(imList)
for img in imList:
    imgName = os.path.basename(img)
    if imgName.endswith(('.jpg','.png')):
        input_image = caffe.io.load_image(img)
        net.blobs['data'].reshape(1,3,imgeReshape[0],imgeReshape[1])
        net.blobs['data'].data[...] = transformer.preprocess('data', input_image)
        out = net.forward()
        feat = net.blobs[featureLayer].data
        if Dataset =='twin':
            img_type = int(imgName[7:-4])/perImNum
            img_index = int(imgName[7:-4])%perImNum
            #print 'img_type:',img_type
            if img_type in img_type_num.keys():
                img_type_num[img_type] = img_type_num[img_type] + 1
                img_type_list[img_type][img_index] = img
            else:
                img_type_num[img_type] = 0
                img_type_list[img_type] = [None]*perImNum
                img_type_index[img_type] = type_index
                type_index +=1
            #print 'img_type_index:',img_type_index[img_type]
            features[img_type_index[img_type],img_type_num[img_type]] = feat.flatten()
        else:
            # need to be further revised!
            features[totalNum] = feat.flatten()
            #print features[totalNum]
        totalNum +=1
    else:
        print img
#print len(img_type_num)
print totalNum
#print img_type_list

if Dataset == 'twin':
    featureMat = np.zeros((totalNum,featureNum))
    k = 0
    for i in range(features.shape[0]):
        for j in range(features[i].shape[0]):
            if sum(features[i,j,:])!=0:
                featureMat[k,:] = features[i,j,:]
                k +=1
else:
    featureMat = features
np.savetxt(homePath+'/features/'+MODEL+'_'+featureLayer+'_'+Dataset+\
           'totalFeatures_2207.csv', featureMat, delimiter=',')
# Out:
# 2207

# %%
#print featureMat
featureMat = featureMat[randomInd,:]
nSamples = featureMat.shape[0]
testRatio = 0.2
valiRatio = 0.1
testFeatures = featureMat[:int(nSamples*testRatio),:]
trainFeatures = featureMat[int(nSamples*testRatio):,:]
valiFeatures = featureMat[-int(trainFeatures.shape[0]*valiRatio):,:]
trainFeatures = trainFeatures[:-int(trainFeatures.shape[0]*valiRatio),:]
print valiFeatures.shape, trainFeatures.shape, testFeatures.shape
radomImlist = np.asarray(imList)[randomInd]
testIm = radomImlist[:int(nSamples*testRatio)]
trainIm = radomImlist[int(nSamples*testRatio):]
print testIm.shape, trainIm.shape

# %%
if MODEL != 'faceSNN':
    explained_variance = 0.95
else:
    explained_variance = featureNum

sklearn_pca = sklearnPCA(n_components=explained_variance, whiten  = True)
trainfeature_transf = sklearn_pca.fit_transform(trainFeatures)
print 'The number of PCs needed to retain %.3f variance is %d.' \
      % (explained_variance, trainfeature_transf.shape[1])

# %%
print sklearn_pca.components_.shape
print trainfeature_transf.shape
testfeature_tansf = sklearn_pca.transform(testFeatures)
print testfeature_tansf.shape
valifeature_transf = sklearn_pca.transform(valiFeatures)
#component_std = np.std(sklearn_pca.components_,axis = 0,dtype=np.float32)
# import scipy
# u,s,v = scipy.sparse.linalg.svds(featureMat, k =sklearn_pca.components_.shape[0], which = 'LM')
np.savetxt(homePath+'/features/'+MODEL+'_'+featureLayer+'_'+Dataset+\
           'other_trainFeatures.csv', trainfeature_transf, delimiter=',')
np.savetxt(homePath+'/features/'+MODEL+'_'+featureLayer+'_'+Dataset+\
           'other_testFeatures.csv', testfeature_tansf, delimiter=',')
np.savetxt(homePath+'/features/'+MODEL+'_'+featureLayer+'_'+Dataset+\
           'other_valiFeatures.csv', valifeature_transf, delimiter=',')
whiten_component = sklearn_pca.components_
#print whiten_component
newMat = trainFeatures.dot(whiten_component.T)
bias = np.mean(newMat,axis = 0)
# print bias
newNewMat = newMat - bias
np.savetxt(homePath+'/features/'+MODEL+'_'+featureLayer+'_'+Dataset+\
           'other_weights.csv', whiten_component, delimiter=',')
np.savetxt(homePath+'/features/'+MODEL+'_'+featureLayer+'_'+Dataset+\
           'other_biases.csv', bias, delimiter=',')

# %%
def writeFile(imList, rating,fName):
    text_file = open(fName, "w")
    for i in range(imList.shape[0]):
        d = homePath+'attractiveness_datamining/'+imList[i][6:]+' '+str(rating[i])+'\n'
        text_file.write(d)
    text_file.close()
modelList = []
optFeaNumList = []
import sys
#print sys.path
# local
# PkgPath = '/Users/Olivialinlin/Documents/Github/attractiveness_datamining/linjieCode/code'
# server
PkgPath = homePath+'attractiveness_datamining/linjieCode/code'

if PkgPath not in sys.path:
    sys.path.insert(0, PkgPath)
#print sys.path
from xVal_train_test import Train_Test

import sklearn
import numpy as np
for attr in social2Attr:
    print attr
    #attr= social2Attr[9]
    mean_rating = socialMeasures.loc[:,attr].tolist()
    mean_rating = map(float, mean_rating)
    mean_rating = np.array(mean_rating)
    radomRating = mean_rating[randomInd]
    testRating = radomRating[:int(nSamples*testRatio)]
    trainRating = radomRating[int(nSamples*testRatio):]
    valiRating = radomRating[-int(trainRating.shape[0]*valiRatio):]
    trainSubRating = trainRating[:-int(trainRating.shape[0]*valiRatio)]
    #writeFile(trainIm,trainRating,'../list/'+attr+'_train.txt')
    #writeFile(testIm,testRating,'../list/'+attr+'_test.txt')
    writeFile(trainIm,trainRating,'../data_list/'+attr+'_train.txt')
    writeFile(testIm,testRating,'../data_list/'+attr+'_test.txt')
    baseLine = mean_rating.mean()
    print 'mean rating: ', baseLine

    predictionModel = sklearn.linear_model.RidgeCV(alphas=np.logspace(-3,2,num=20), fit_intercept=True)
    myModel,optFeaNum = Train_Test(trainSubRating,testRating,valiRating,trainfeature_transf, \
                                   testfeature_tansf,valifeature_transf,xVal = True,numTrain = 1,\
                                   pModel = predictionModel,getMaxMin = False,MODEL= MODEL, \
                                   plotPredActual = False,returnModel = True)
    modelList.append(myModel)
    optFeaNumList.append(optFeaNum)

# %%
np.savetxt(homePath+'/features/'+MODEL+'_'+featureLayer+'_'+Dataset+\
           'optNumF.csv', np.asarray(optFeaNumList), delimiter=',', fmt='%d')
print optFeaNumList
