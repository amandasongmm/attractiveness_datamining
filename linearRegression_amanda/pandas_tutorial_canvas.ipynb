# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import linear_model
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# %matplotlib inline


feature_arr = pd.read_csv('allFeatures.csv')

# %%
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
# Look at some rows
feature_arr[:3]
# Out:
#   dataset  img_num  nose_width  nose_length  lip_thickness  face_length  \
# 0     mit        0   39.012818    69.000000      21.524938   269.007435
# 1     mit        1   38.052595    75.059976      30.000000   279.016129
# 2     mit        2   37.013511    77.006493      24.035669   280.000000
#
#    eye_height  eye_width  face_width_prom  face_width_mouth       ...        \
# 0   14.258772  37.067467       204.022058        165.027270       ...
# 1   14.792855  41.157973       202.299283        162.249807       ...
# 2   13.152946  35.850451       201.009950        170.026469       ...
#
#    lip_fullness  eye_shape  eye_size  upper_head_len  midface_len  chin_size  \
# 0      0.080016   0.384671  0.053005        0.349749     0.355243   0.230507
# 1      0.107521   0.359417  0.053018        0.387671     0.353154   0.165487
# 2      0.085842   0.366884  0.046975        0.382143     0.360548   0.178607
#
#    forehead_height  cheek_height  cheek_prominence  face_roundness
# 0         0.262397      0.527478          0.144958        0.613467
# 1         0.278737      0.525156          0.143538        0.581507
# 2         0.278571      0.540370          0.110655        0.607237
#
# [3 rows x 31 columns]

# %%
# Plot a column
feature_arr.plot(figsize=(15,10))
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1292: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
pd.__version__
# Out:
# u'0.17.1'
